# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Привет, Игорь :)
#
# Спасибо за все исправления 🤝
#
# Осталось поправить последний вывод
#
# Основные навыки, тестируемые на проекте:
#
#  + внимательное чтение технического задания проекта
#  + объединение разных таблиц в единый датасет, — на рабочих проектах стоит уделить особое внимание на способы объединения (left или inner, можно кого-нить забыть, значение параметра how по умолчанию), на пропуски и возможные дубликаты
#  + формирование, чтение и сравнение показателей на графике двух выборок,
#  + формирование выводов о данных по статистическим показателям,
#  + формулирование и проверку односторонних и двусторонних гипотез, <b>интерпретацию значения p-value - можно повторить недели через две </b>(для профилактики :) )
#  + формирование рекомендаций для бизнеса
#
#
# <b>Поздравляю со сданным проектом на факультете дата-аналитики Я.Практикум</b>
#
# <div class="alert alert-success">
#     <font size="5", color= "seagreen"><b>Успехов в дальнейшей учебе 🤝</b></font><br />
#
#
#
# добавил бонус
#
# и одну ссылку [Функции в Python](https://www.codecamp.ru/blog/python-functions/?ysclid=loyw96tz7822158015)

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />   Привет, Игорь :) Спасибо за доработки 🤝
#
# Критические ❌ комментарии:
#
#  + в разделе проверки гипотез поправить 4-й стат тест
#  + поправить итоговый вывод
#
# добавил новые подсказки

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />   Привет, Игорь :) Спасибо за доработки 🤝
#
# Критические ❌ комментарии:
#
#  + в разделе проверки гипотез поправить Н0 и Н1, выборки и выводы
#  + дополнить итоговый вывод
#
# добавил новые подсказки
#
# Стоит повторить теорию и примеры с тренажера про выполнение стат тестов
#
# Если ты не понимаешь, как выполнить эти шаги, тогда стоит задать вопрос преподавателю по проектам в чате «пачки». Также ты можешь написать вопрос в проекте (оптимальнее пример с твоим кодом) и опять отправить его на проверку — так я смогу тебе ответить.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Игорь :) Спасибо, что прислал задание 🤝  Твой старый знакомый, Ринат Хисамов будет проверять проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# Поехали 🚀
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев </b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br />
#         <font size="3", color = "black">
# <br />
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")  <br /><br />
#         <a href="https://devpractice.ru/matplotlib-book/">“Библиотека Matplotlib” доступна для скачивания БЕСПЛАТНО!</a>
#         На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)
#
#
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-danger">
# <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# # Для твоих вопросов или комментариев оставлю такую ячейку, чтобы было удобнее взаимодействовать на проекте

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> ... , вот мой вопрос ...

# %% [markdown]
# # Исследование изменения прибыли компании, которая предлагает арендовать электросамокаты

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> На проекте изучается не только изменение прибыли

# %% [markdown]
# # Введение

# %% [markdown]
# Компания GoFast просит исследовать как изменится прибыль если увеличить количество пользователей с подпиской. Необходимо предобработать данные и проверить гипотезы как изменится количество пользователей с подпиской после проведения некоторых акций.

# %% [markdown]
# План:
# 1. Загрузка данных и изучение общей информации.
# 2. Предобработка данных
# 3. Исследовательский анализ данных
# 4. Объединение данных
# 5. Подсчёт выручки
# 6. Проверка гипотез

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит добавлять еще больше подробностей к плану проекта, это позволит избежать многих ошибок на будущих проектах

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Название придаст вес проекту
#
# а подробности выполнения проекта дадут возможность вспомнить через полгода — что мы тут делали

# %% [markdown]
# #### Шаг 1. Загрузка данных

# %%
import pandas as pd
import numpy as np
from scipy import stats as st
import matplotlib.pyplot as plt
import datetime

# %%
def head_and_info(df):
    print(df.head(10))
    print(df.info())

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ <b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br /> display() вместо print(), поможет навести красоту на проекте
#
#      print(df.head(10))

# %%
data_users = pd.read_csv('/datasets/users_go.csv')
head_and_info(data_users)
# Out:
#    user_id        name  age            city subscription_type
# 0        1        Кира   22          Тюмень             ultra
# 1        2   Станислав   31            Омск             ultra
# 2        3     Алексей   20          Москва             ultra
# 3        4  Константин   26  Ростов-на-Дону             ultra
# 4        5       Адель   28            Омск             ultra
# 5        6      Регина   25       Краснодар             ultra
# 6        7       Игорь   23            Омск             ultra
# 7        8        Юрий   23       Краснодар             ultra
# 8        9          Ян   21       Пятигорск             ultra
# 9       10     Валерий   18    Екатеринбург             ultra
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1565 entries, 0 to 1564
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            1565 non-null   int64
# ...

# %%
data_rides = pd.read_csv('/datasets/rides_go.csv', parse_dates=['date'])
head_and_info(data_rides)
# Out:
#    user_id     distance   duration       date
# 0        1  4409.919140  25.599769 2021-01-01
# 1        1  2617.592153  15.816871 2021-01-18
# 2        1   754.159807   6.232113 2021-04-20
# 3        1  2694.783254  18.511000 2021-08-11
# 4        1  4028.687306  26.265803 2021-08-28
# 5        1  2770.890808  16.650138 2021-10-09
# 6        1  3039.020292  14.927879 2021-10-19
# 7        1  2842.118050  23.117468 2021-11-06
# 8        1  3412.690668  15.238072 2021-11-14
# 9        1   748.690645  15.041884 2021-11-22
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18068 entries, 0 to 18067
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   18068 non-null  int64
#  1   distance  18068 non-null  float64
#  2   duration  18068 non-null  float64
#  3   date      18068 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1)
# memory usage: 564.8 KB
# None

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Если при загрузке данных добавить параметр `parse_dates: parse_dates=['date']` то тип данных автоматически переведется в даты. Подробнее про это можно прочитать по ссылке ниже
#
# https://newtechaudit.ru/gruzi-daty-krasivo/

# %%
data_subscriptions = pd.read_csv('/datasets/subscriptions_go.csv')
head_and_info(data_subscriptions)
# Out:
#   subscription_type  minute_price  start_ride_price  subscription_fee
# 0              free             8                50                 0
# 1             ultra             6                 0               199
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   subscription_type  2 non-null      object
#  1   minute_price       2 non-null      int64
#  2   start_ride_price   2 non-null      int64
#  3   subscription_fee   2 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 192.0+ bytes
# None

# %% [markdown]
# Датафреймы отображаются без проблем.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Все  методы можно собрать в функцию и оптимизировать код вывода первичной информации
#
#         def ...:
#             ... dataset.head()
#             ... dataset.info()

# %% [markdown]
# #### Шаг 2. Предобработка данных

# %% [markdown]
# Проверим, за какое время собраны данные

# %%
print('Данные собраны за период с ', data_rides['date'].dt.year.min(), 'года по', data_rides['date'].dt.year.max(), 'год.')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_94/2389949082.py in <module>
# ----> 1 print('Данные собраны за период с ', data_rides['date'].dt.year.min(), 'года по', data_rides['date'].dt.year.max(), 'год.')
#
# NameError: name 'data_rides' is not defined

# %%
print('Данные собраны за', data_rides['date'].dt.year.min(), 'c месяца', data_rides['date'].dt.month.min(), 'по месяц',
      data_rides['date'].dt.month.max())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_94/1767461607.py in <module>
# ----> 1 print('Данные собраны за', data_rides['date'].dt.year.min(), 'c месяца', data_rides['date'].dt.month.min(), 'по месяц',
#       2       data_rides['date'].dt.month.max())
#
# NameError: name 'data_rides' is not defined

# %% [markdown]
# <div style>
# <font size="4"><b></b></font>
# <font size="5", color = "black">
# 👍

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />   Кажется, в этот раз весь код на проекте запускался вручную ... 105-я строка кода в начале проекта
#
# ![image-3.png](attachment:image-3.png)
#
#
# ![image-2.png](attachment:image-2.png)
#
#
#
# Проверить работоспособность кода — можно нажав на панели Jupiter Hub Kernel и Restart & Run All (см скриншот ниже).
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Добавим столбец с названием месяца.

# %%
data_rides['month'] = data_rides['date'].dt.month
data_rides['month']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_94/1947938399.py in <module>
# ----> 1 data_rides['month'] = data_rides['date'].dt.month
#       2 data_rides['month']
#
# NameError: name 'data_rides' is not defined

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит проверить — за какой период (год или несколько лет) у нас собраны данные

# %% [markdown]
# Проверим на наличие дубликатов.

# %%
duplicates = data_users[data_users.duplicated()]
duplicates
# Out:
#       user_id        name  age            city subscription_type
# 1534      293       Агата   26       Краснодар             ultra
# 1535       16      Амалия   27       Краснодар             ultra
# 1536      909  Константин   20    Екатеринбург              free
# 1537      403      Полина   19            Сочи             ultra
# 1538      908      Рустам   30          Тюмень              free
# 1539       43    Стефания   22            Омск             ultra
# 1540      127       Павел   25       Пятигорск             ultra
# 1541      659       Злата   27  Ростов-на-Дону             ultra
# 1542      204      Руслан   30       Пятигорск             ultra
# 1543      153      Герман   23          Москва             ultra
# 1544     1245      Регина   27       Пятигорск              free
# 1545      807   Александр   28    Екатеринбург              free
# 1546      924       Мария   23       Пятигорск              free
# ...

# %% [markdown]
# Избавимся от дубликатов.

# %%
data_users = data_users.drop_duplicates()
data_users = data_users.reset_index(drop=True)

# %%
duplicates = data_users[data_users.duplicated()]
duplicates
# Out:
# Empty DataFrame
# Columns: [user_id, name, age, city, subscription_type]
# Index: []

# %%
duplicates = data_rides[data_rides.duplicated()]
duplicates
# Out:
# Empty DataFrame
# Columns: [user_id, distance, duration, date, month]
# Index: []

# %% [markdown]
# Дубликатов нет.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Проверка на поиск дубликатов выполнена, молодец
#
# Особенно это станет важным, когда мы перейдем к более сложным задачам на втором модуле курса

# %% [markdown]
# Исследуем пропущенные значения.

# %%
data_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1534 entries, 0 to 1533
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            1534 non-null   int64
#  1   name               1534 non-null   object
#  2   age                1534 non-null   int64
#  3   city               1534 non-null   object
#  4   subscription_type  1534 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 60.0+ KB

# %%
data_users.isna().sum()
# Out:
# user_id              0
# name                 0
# age                  0
# city                 0
# subscription_type    0
# dtype: int64

# %%
data_rides.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18068 entries, 0 to 18067
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   18068 non-null  int64
#  1   distance  18068 non-null  float64
#  2   duration  18068 non-null  float64
#  3   date      18068 non-null  datetime64[ns]
#  4   month     18068 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2)
# memory usage: 705.9 KB

# %%
data_rides.isna().sum()
# Out:
# user_id     0
# distance    0
# duration    0
# date        0
# month       0
# dtype: int64

# %% [markdown]
# Пропущенных значений нет.

# %% [markdown]
# #### Шаг 3. Исследовательский анализ данных

# %% [markdown]
# Рассмотрим частоту встречающихся городов.

# %%
cities = data_users.groupby('city').count().sort_values(by='user_id', ascending=False)['user_id']
cities
# Out:
# city
# Пятигорск         219
# Екатеринбург      204
# Ростов-на-Дону    198
# Краснодар         193
# Сочи              189
# Омск              183
# Тюмень            180
# Москва            168
# Name: user_id, dtype: int64

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Более привычная форма
#
#         data_users.groupby('city')['user_id'].count().sort_values(ascending=False)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит поправить код группировки, можно не выводить на экран все колонки — они дублируют информацию
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Чаще всего самокатами пользуются в Пятигорске, реже всего в Москве.

# %% [markdown]
# Рассмотрим на сколько процентов отличаются количество пользователей в разных городах.

# %%
print(round(cities / len(data_users) * 100))
# Out:
# city
# Пятигорск         14.0
# Екатеринбург      13.0
# Ростов-на-Дону    13.0
# Краснодар         13.0
# Сочи              12.0
# Омск              12.0
# Тюмень            12.0
# Москва            11.0
# Name: user_id, dtype: float64

# %% [markdown]
# Разница незначительна, можно сказать пользователи в разных городах примерно сопоставимы.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />В этой гипотезе мы оцениваем влияние на затраты, если подписчик в среднем проезжает не более 3130 метров, то техническая служба компании не испытывает лишней нагрузки, самокаты используются оптимальным образом, значит затраты не растут

# %% [markdown]
# Построим график пользователей по городам

# %%
fig = cities.plot(
    figsize=(12,7),
    grid=True,
    legend=False
)

fig.set_xlabel('Города')
fig.set_ylabel('Количество пользователей');

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит поменять тип графика на бары, на линейных показывают динамику изменения параметра

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит указать на сколько %-ов отличается кол-во пользователей в разных городах, стоит ли говорить о такой разнице?

# %% [markdown]
# Найдём соотношение пользователей с подпиской и без подписки.

# %% [markdown]
# Для начала найдём количество пользователей с подпиской и без подписки по городам

# %%
print('Соотношение пользователей с подпиской :', \
     round(len(data_users[data_users['subscription_type'] == 'free']) / len(data_users) * 100), '%')
print('Соотношение пользователей без подписки :', \
     round( len(data_users[data_users['subscription_type'] == 'ultra']) / len(data_users) * 100), '%')
# Out:
# Соотношение пользователей с подпиской : 54 %
# Соотношение пользователей без подписки : 46 %

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит добавить график для этой информации
#
#         Соотношение пользователей с подпиской : 54 %
#         Соотношение пользователей без подписки : 46 %

# %% [markdown]
# Найдём соотношение пользователей с подпиской и без подписки по городам и построим график.

# %%
cities_persent = data_users[data_users['subscription_type'] == 'ultra'].groupby('city').count().sort_values(
    by='user_id', ascending=False)['user_id']

cities_persent = round(cities_persent / data_users.groupby('city').count()['user_id'] * 100)

fig = cities_persent.plot(
    figsize=(12,7),
    grid=True,
    legend=False
)

fig.set_xlabel('Города')
fig.set_ylabel('Процент людей с подпиской')
plt.title('Количество людей с подпиской по городам')
# Out:
# Text(0.5, 1.0, 'Количество людей с подпиской по городам')

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Скрыть служ. информацию поможет точка с запятой на посл. строке кода
#
#         Text(0.5, 1.0, 'Количество людей с подпиской по городам')
#
#     plt.title('Количество людей с подпиской по городам');

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит  добавить графики для первых двух задач
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Рассмотрим возраст пользователей.

# %%
ax = data_users['age'].hist(bins=50,
                           figsize=(12,7),
                           grid=True)

ax.set_xlabel('Возраст')
ax.set_ylabel('Количество пользоватетелй с этим возрастом')
plt.title('Распределение пользователей по возрасту');

# %% [markdown]
# Чаше всего возраст пользователя около 25 лет, реже встречается возраст до 20 и после 30 лет, мало пользователей с возрастом меньше 15 лет и больше 30.

# %% [markdown]
# Оценим расстояние пользователя за одну поездку.

# %%
ax = data_rides['distance'].hist(bins=50,
                           figsize=(12,7),
                           grid=True)

ax.set_xlabel('Расстояние в метрах')
ax.set_ylabel('Количество поездок с этим расстоянием')
plt.title('Распределение пользователей по расстоянию за одну поездку');

# %% [markdown]
# Чаще всего пользователи преодолевают расстояние в 3000 м, реже больше 5000 и от 1000 до 2000, также виднеется пик около 500 м.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
# <font size="3", color = "black">
# <br />Интересно, какая группа пользователей чаще совершает короткие поездки?

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
# <font size="3", color = "black">
# <br />Можно добавить свои предположения, по какой причине у нас пользователи разделились на две части: совершают короткие и длинные поездки, с пиками около 700-а и 3100-а метров

# %% [markdown]
# Оценим время в минутах за одну поездку.

# %%
ax = data_rides['duration'].hist(bins=50,
                           figsize=(12,7),
                           grid=True)

ax.set_xlabel('Время в минутах')
ax.set_ylabel('Количество пользоватетелй с этим временем')
plt.title('Распределение пользователей по времени за одну поездку');

# %% [markdown]
# Видно, что чаще всего поездка длится от 15 до 21 минуты, редкие значения наблюдаются до 10 и больше 30 минут. Виднеется пик около двух минут, что согласуется с тем что есть поездки по 500 метров.

# %% [markdown]
# Исследуем данные по возрасту с помощью ящика с усами.

# %%
fig = data_users.boxplot(
    column='age',
    figsize=(12,7),
)

plt.title('Ящик с усами для возраста пользователей');

# %% [markdown]
# На ящике с усами видно, что медиана возраста пользователей 25 лет, межквартильный размах с 22 по 28 лет, 25% пользователи имеют возраст с 14 до 22 лет, другие 25% с 28 до 36 лет.

# %% [markdown]
# Исследуем данные по расстоянию за одну поездку.

# %% [markdown]
# Воспользуемся методом describe() для выявления аномалий.

# %%
data_rides['distance'].describe()
# Out:
# count    18068.000000
# mean      3070.659976
# std       1116.831209
# min          0.855683
# 25%       2543.226360
# 50%       3133.609994
# 75%       3776.222735
# max       7211.007745
# Name: distance, dtype: float64

# %% [markdown]
# Видно, что есть аномалии с расстоянием менее метра за одну поездку, это меньше первого квартиля. Максимальное значение в 7 км нельзя назвать аномалией, возможно какой-то из пользователей действительно преодолел это расстояние за одну поездку.

# %%
fig = data_rides.boxplot(
    column='distance',
    figsize=(12,7),
)

plt.title('Ящик с усами для расстояния пользователей за одну поездку');

# %% [markdown]
# Диаграмма размаха показывает, что медиана около 3100 м, межквартильный размах от 2500 м до 3700 м, расстояние менее 300 м можно считать аномалиями, однако как сказано выше расстояния больше 5600 м нельзя назвать аномалиями.

# %% [markdown]
# Исследуем данные по времени за одну поездку.

# %%
data_rides['duration'].describe()
# Out:
# count    18068.000000
# mean        17.805011
# std          6.091051
# min          0.500000
# 25%         13.597563
# 50%         17.678395
# 75%         21.724800
# max         40.823963
# Name: duration, dtype: float64

# %% [markdown]
# Проемлилмым временем можно считать поездку около 1 минуты, минимальное значение же меньше минуты, это аномалия.

# %% [markdown]
# Построим ящик с усами для времени за одну поездку.

# %%
fig = data_rides.boxplot(
    column='duration',
    figsize=(12,7),
)

plt.title('Ящик с усами для времени пользователей за одну поездку');

# %% [markdown]
# Диаграмма размаха показывает, что медианное время около 17 минут, межквартильный размах от 13 до 21 минуты, минимальное значение около 30 секунд нельзя назвать выбросом, возможно пользователи действительно используют самокат даже для такого времени.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
# <font size="3", color = "black">
# <br />
# Можно описать вид распределения (данных) на гистограммах

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />    Стоит больше кода посвятить изучению самих данных, возможных аномалий, редких значений ... Например проверить колонку длительности на наличие аномалий

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит  добавить промежуточный вывод о результатах выполнения исследовательских задач и сведения о межквартильном размахе в данных:
#
# + по возрасту, длительности и пройденному расстоянию
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Межквартильный размах является мерой разброса данных, которая особенно полезна в анализе данных из-за следующих преимуществ:
#
# 1. Устойчивость к выбросам. В отличие от среднего арифметического, межквартильный размах менее чувствителен к выбросам в данных. Это делает его более надежной мерой разброса по сравнению со средним арифметическим, особенно в случаях, когда данные содержат необычные значения или аномалии.
# 2. Простота понимания и интерпретации. Межквартильный диапазон легко понять и интерпретировать, так как он показывает расстояние между 25% наименьших и 25% наибольших значений в наборе данных.
# 3. Разделение среднего и дисперсии. Межквартильный размах отделяет среднее значение от дисперсии, что может быть полезно для анализа данных, так как позволяет изучать эти два аспекта отдельно.
# 4. Более высокая эффективность в некоторых случаях. В некоторых ситуациях использование межквартильного диапазона вместо среднего арифметического может быть более эффективным, например, при анализе данных с тяжелыми хвостами распределения или асимметричными
#
# В маркетинге межквартильный размах может использоваться для анализа следующих аспектов:
#
# 1. Поведение пользователей: IQR может помочь маркетологам определить, как пользователи взаимодействуют с продуктом или услугой, например, как часто они используют продукт, на какие функции они чаще всего нажимают и т.д.
# 2. Эффективность рекламы: IQR можно использовать для анализа эффективности рекламных кампаний, чтобы определить, какие рекламные сообщения привлекают наибольшее внимание и какие не вызывают интереса у аудитории.

# %% [markdown]
# #### Шаг 4. Объединение данных

# %% [markdown]
# Объединим данные методом merge()

# %%
merge_data = data_rides.merge(data_users, how='outer')
merge_data
# Out:
#        user_id     distance   duration       date  month     name  age  \
# 0            1  4409.919140  25.599769 2021-01-01      1     Кира   22
# 1            1  2617.592153  15.816871 2021-01-18      1     Кира   22
# 2            1   754.159807   6.232113 2021-04-20      4     Кира   22
# 3            1  2694.783254  18.511000 2021-08-11      8     Кира   22
# 4            1  4028.687306  26.265803 2021-08-28      8     Кира   22
# ...        ...          ...        ...        ...    ...      ...  ...
# 18063     1534  3781.098080  19.822962 2021-11-04     11  Альберт   25
# 18064     1534  2840.423057  21.409799 2021-11-16     11  Альберт   25
# 18065     1534  3826.185507  18.435051 2021-11-18     11  Альберт   25
# 18066     1534  2902.308661  16.674362 2021-11-27     11  Альберт   25
# 18067     1534  2371.711192  15.893917 2021-12-29     12  Альберт   25
#
#             city subscription_type
# 0         Тюмень             ultra
# 1         Тюмень             ultra
# ...

# %%
merge_data = merge_data.merge(data_subscriptions, how='outer')
merge_data.head(10)
# Out:
#    user_id     distance   duration       date  month  name  age    city  \
# 0        1  4409.919140  25.599769 2021-01-01      1  Кира   22  Тюмень
# 1        1  2617.592153  15.816871 2021-01-18      1  Кира   22  Тюмень
# 2        1   754.159807   6.232113 2021-04-20      4  Кира   22  Тюмень
# 3        1  2694.783254  18.511000 2021-08-11      8  Кира   22  Тюмень
# 4        1  4028.687306  26.265803 2021-08-28      8  Кира   22  Тюмень
# 5        1  2770.890808  16.650138 2021-10-09     10  Кира   22  Тюмень
# 6        1  3039.020292  14.927879 2021-10-19     10  Кира   22  Тюмень
# 7        1  2842.118050  23.117468 2021-11-06     11  Кира   22  Тюмень
# 8        1  3412.690668  15.238072 2021-11-14     11  Кира   22  Тюмень
# 9        1   748.690645  15.041884 2021-11-22     11  Кира   22  Тюмень
#
#   subscription_type  minute_price  start_ride_price  subscription_fee
# 0             ultra             6                 0               199
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> На этих данных — объединение прошло по плану.
#
#
#
# Обрати внимание на параметры, которые пандас выставляет по умолчанию при merge (для справки в join такая же «засада» по характеру, но другая по исполнению)
#
# Использование параметров по умолчанию может привести к потере данных при объединении
#
#
# [Примеры объединения таблиц, merge](https://pandas.pydata.org/pandas-docs/version/1.5/reference/api/pandas.DataFrame.merge.html?highlight=merge#pandas.DataFrame.merge)
#
# [Примеры объединения таблиц, join](https://pandas.pydata.org/pandas-docs/version/1.5/reference/api/pandas.DataFrame.join.html?highlight=join#pandas.DataFrame.join)

# %%
merge_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18068 entries, 0 to 18067
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            18068 non-null  int64
#  1   distance           18068 non-null  float64
#  2   duration           18068 non-null  float64
#  3   date               18068 non-null  datetime64[ns]
#  4   month              18068 non-null  int64
#  5   name               18068 non-null  object
#  6   age                18068 non-null  int64
#  7   city               18068 non-null  object
#  8   subscription_type  18068 non-null  object
#  9   minute_price       18068 non-null  int64
#  10  start_ride_price   18068 non-null  int64
#  11  subscription_fee   18068 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(6), object(3)
# memory usage: 1.8+ MB

# %% [markdown]
# Значений столько же, сколько было в data_rides, следовательно слияние прошло успешно.

# %% [markdown]
# Проверим на пустые значения

# %%
merge_data.isna().sum()
# Out:
# user_id              0
# distance             0
# duration             0
# date                 0
# month                0
# name                 0
# age                  0
# city                 0
# subscription_type    0
# minute_price         0
# start_ride_price     0
# subscription_fee     0
# dtype: int64

# %% [markdown]
# Пропусков в новой таблице не появилось.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Молодец — проверил размерность таблиц и общую информацию, в отчете стоит отметить, что пропусков в данных после объединения не появилось

# %% [markdown]
# Создадим два датафрейма пользователей с подпиской и без.

# %%
data_free = merge_data.query('subscription_type == "free"')
data_free.head(10)
# Out:
#       user_id     distance   duration       date  month   name  age  city  \
# 6500      700  2515.690719  14.944286 2021-01-02      1  Айдар   22  Омск
# 6501      700   846.932642  16.234663 2021-02-01      2  Айдар   22  Омск
# 6502      700  4004.434142  20.016628 2021-02-04      2  Айдар   22  Омск
# 6503      700  1205.911290   9.782872 2021-02-10      2  Айдар   22  Омск
# 6504      700  3047.379435  17.427673 2021-02-14      2  Айдар   22  Омск
# 6505      700  4342.002254  22.368009 2021-02-23      2  Айдар   22  Омск
# 6506      700  3798.334905  18.243756 2021-03-03      3  Айдар   22  Омск
# 6507      700  2984.551206  15.424899 2021-04-09      4  Айдар   22  Омск
# 6508      700  3360.107141  16.765497 2021-06-12      6  Айдар   22  Омск
# 6509      700  2567.543847  11.312160 2021-06-23      6  Айдар   22  Омск
#
#      subscription_type  minute_price  start_ride_price  subscription_fee
# 6500              free             8                50                 0
# ...

# %%
data_ultra = merge_data.query('subscription_type == "ultra"')
data_ultra.head(10)
# Out:
#    user_id     distance   duration       date  month  name  age    city  \
# 0        1  4409.919140  25.599769 2021-01-01      1  Кира   22  Тюмень
# 1        1  2617.592153  15.816871 2021-01-18      1  Кира   22  Тюмень
# 2        1   754.159807   6.232113 2021-04-20      4  Кира   22  Тюмень
# 3        1  2694.783254  18.511000 2021-08-11      8  Кира   22  Тюмень
# 4        1  4028.687306  26.265803 2021-08-28      8  Кира   22  Тюмень
# 5        1  2770.890808  16.650138 2021-10-09     10  Кира   22  Тюмень
# 6        1  3039.020292  14.927879 2021-10-19     10  Кира   22  Тюмень
# 7        1  2842.118050  23.117468 2021-11-06     11  Кира   22  Тюмень
# 8        1  3412.690668  15.238072 2021-11-14     11  Кира   22  Тюмень
# 9        1   748.690645  15.041884 2021-11-22     11  Кира   22  Тюмень
#
#   subscription_type  minute_price  start_ride_price  subscription_fee
# 0             ultra             6                 0               199
# ...

# %% [markdown]
# Визуализируем информацию о времени поездок и расстояния для пользователей обеих категорий.

# %% [markdown]
# Рассмотрим время одной поездки для людей с подписккой и без.

# %%
fig = plt.figure(figsize=(12,7))
ax = fig.add_subplot()
plt.grid()
plt.hist(data_free['duration'], bins=50)
plt.hist(data_ultra['duration'], bins=50)
plt.legend(('free', 'ultra'))
ax.set_xlabel('Время поездки в минутах')
ax.set_ylabel('Количество поездок')
plt.title('Гистограмма времени одной поезки для пользователей с подпиской и без')
plt.show()

# %% [markdown]
# Гистограмма показывает, что средная продолжительность времени одной поездки у пользователей с подпиской и без примерно одинаковая.

# %% [markdown]
# Рассмотрим расстояние одной поездки для людей с подписккой и без.

# %%
fig = plt.figure(figsize=(12,7))
ax = fig.add_subplot()
plt.grid()
plt.hist(data_free['distance'], bins=50)
plt.hist(data_ultra['distance'], bins=50)
plt.legend(('free', 'ultra'))
ax.set_xlabel('Расстояние за одну поездку в минутах')
ax.set_ylabel('Количество поездок')
plt.title('Гистограмма расстояния одной поезки для пользователей с подпиской и без')
plt.show()

# %% [markdown]
# Гистограммы показывают, что в среднем расстояние за одну поездку у пользователей без подписки меньше, чем у пользователей с подпиской, для пользователей без подписки есть второй пик с расстоянием около 500 м, также есть пик у пользователей с подпиской около 1 км.

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит полностью оформить все графики на проекте
#
# Подписи осей на графиках и название добавят ясности и читабельности.
# Это важные элементы любой визуализации. Как добавить подписи и названия, смотри [здесь](https://proproprogs.ru/modules/matplotlib-razmeshchaem-standartnye-tekstovye-elementy-na-grafike?ysclid=l6agtioc6f299002507)
#
# Осталось добавить название

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит совместить гистограммы на одном виде, по две гистограммы для каждого параметра, чтобы появилась возможность визуально сравнить параметры у двух разных групп клиентов

# %% [markdown]
# Применем метод describe() для описание статистик

# %%
data_free['duration'].describe()
# Out:
# count    11568.000000
# mean        17.390909
# std          6.326803
# min          0.500000
# 25%         12.958437
# 50%         17.326890
# 75%         21.594071
# max         34.948498
# Name: duration, dtype: float64

# %%
data_ultra['duration'].describe()
# Out:
# count    6500.000000
# mean       18.541985
# std         5.572048
# min         3.760353
# 25%        14.524654
# 50%        18.178153
# 75%        21.884129
# max        40.823963
# Name: duration, dtype: float64

# %% [markdown]
# Значении времени за одну поездку у пользователей с подпиской выше.

# %%
data_free['distance'].describe()
# Out:
# count    11568.000000
# mean      3045.495282
# std       1246.173806
# min          0.855683
# 25%       2366.562689
# 50%       3114.648465
# 75%       3905.697894
# max       7211.007745
# Name: distance, dtype: float64

# %%
data_ultra['distance'].describe()
# Out:
# count    6500.000000
# mean     3115.445388
# std       836.895330
# min       244.210438
# 25%      2785.444017
# 50%      3148.637229
# 75%      3560.574425
# max      5699.769662
# Name: distance, dtype: float64

# %% [markdown]
# Расстояние за одну поездку выше у пользователей с подпиской, это говорит о том что пользователи с подпиской преодолевают большее расстояние за одну поездку.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> на проектах стоит снижать размерность выводимой информации, где не требуется максимальная точность, до одного или двух знаков после запятой
#
#         max      5699.769662

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит  добавить сравнение статистик у двух групп пользователей при помощи метода
#
#         .describe()

# %% [markdown]
# #### Шаг 5. Подсчёт выручки

# %% [markdown]
# Найдём суммарное расстояние, количество поездок и суммарное время для каждого пользователя.

# %%
merge_data.head(10)
# Out:
#    user_id     distance   duration       date  month  name  age    city  \
# 0        1  4409.919140  25.599769 2021-01-01      1  Кира   22  Тюмень
# 1        1  2617.592153  15.816871 2021-01-18      1  Кира   22  Тюмень
# 2        1   754.159807   6.232113 2021-04-20      4  Кира   22  Тюмень
# 3        1  2694.783254  18.511000 2021-08-11      8  Кира   22  Тюмень
# 4        1  4028.687306  26.265803 2021-08-28      8  Кира   22  Тюмень
# 5        1  2770.890808  16.650138 2021-10-09     10  Кира   22  Тюмень
# 6        1  3039.020292  14.927879 2021-10-19     10  Кира   22  Тюмень
# 7        1  2842.118050  23.117468 2021-11-06     11  Кира   22  Тюмень
# 8        1  3412.690668  15.238072 2021-11-14     11  Кира   22  Тюмень
# 9        1   748.690645  15.041884 2021-11-22     11  Кира   22  Тюмень
#
#   subscription_type  minute_price  start_ride_price  subscription_fee
# 0             ultra             6                 0               199
# ...

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Стоит выполнить округление длительности до агрегации данных
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Выполним округление по времени

# %%
merge_data['duration'] = np.ceil(merge_data['duration'])
data_free['duration'] = np.ceil(data_free['duration'])
data_ultra['duration'] = np.ceil(data_ultra['duration'])
# Out:
# /tmp/ipykernel_169/2916174741.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_free['duration'] = np.ceil(data_free['duration'])
# /tmp/ipykernel_169/2916174741.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_ultra['duration'] = np.ceil(data_ultra['duration'])

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит исключить предупреждения. Иногда их бывает слишком много, поэтому важно уметь их скрывать. В этом тебе поможет библиотека warnings. Попробуй найти подходящий метод и убрать предупреждения.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Широкие строки кода рекомендуется делить на всем проекте
#
# <a href="https://qastack.ru/programming/53162/how-can-i-do-a-line-break-line-continuation-in-python">Перенос длинных строк кода</a>.
#
# </div>

# %%
one_user_data = merge_data.pivot_table(index=['user_id', 'month'], \
                                       values=['distance', 'duration', 'minute_price', 'start_ride_price','subscription_fee'], \
                                      aggfunc={'distance': ['sum', 'count'], 'duration': 'sum', 'minute_price': 'first', \
                                              'start_ride_price': 'first', 'subscription_fee': 'first'})
one_user_data
# Out:
#               distance               duration minute_price start_ride_price  \
#                  count           sum      sum        first            first
# user_id month
# 1       1            2   7027.511294     42.0            6                0
#         4            1    754.159807      7.0            6                0
#         8            2   6723.470560     46.0            6                0
#         10           2   5809.911100     32.0            6                0
#         11           3   7003.499363     56.0            6                0
# ...                ...           ...      ...          ...              ...
# 1534    6            2   3409.468534     26.0            8               50
#         8            2   7622.453034     48.0            8               50
#         9            1   4928.173852     23.0            8               50
#         11           4  13350.015305     78.0            8               50
# ...

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Стоит проверить агрегированные данные на пропуски

# %% [markdown]
# Проверим агрегированные данные на пропуски.

# %%
one_user_data.isna().sum()
# Out:
# distance          count    0
#                   sum      0
# duration          sum      0
# minute_price      first    0
# start_ride_price  first    0
# subscription_fee  first    0
# dtype: int64

# %% [markdown]
# Пропусков нет.

# %%
one_user_data.columns
# Out:
# MultiIndex([(        'distance', 'count'),
#             (        'distance',   'sum'),
#             (        'duration',   'sum'),
#             (    'minute_price', 'first'),
#             ('start_ride_price', 'first'),
#             ('subscription_fee', 'first')],
#            )

# %%
one_user_data.columns = ['count', 'distance', 'duration', 'minute_price', 'start_ride_price', 'subscription_fee']

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Переименование оптимальнее выполнять в автоматическом режиме, склеивая строки мультииндекса → join(), чтобы не совершить ошибку с порядком очередности колонок в сводной таблице
#
# ![image.png](attachment:image.png)

# %%
one_user_data
# Out:
#                count      distance  duration  minute_price  start_ride_price  \
# user_id month
# 1       1          2   7027.511294      42.0             6                 0
#         4          1    754.159807       7.0             6                 0
#         8          2   6723.470560      46.0             6                 0
#         10         2   5809.911100      32.0             6                 0
#         11         3   7003.499363      56.0             6                 0
# ...              ...           ...       ...           ...               ...
# 1534    6          2   3409.468534      26.0             8                50
#         8          2   7622.453034      48.0             8                50
#         9          1   4928.173852      23.0             8                50
#         11         4  13350.015305      78.0             8                50
#         12         1   2371.711192      16.0             8                50
#
# ...

# %% [markdown]
# Добавим выручку за месяц.

# %%
def get_proceeds(data):
    return data['start_ride_price'] * data['count'] + data['minute_price'] * data['duration'] + data['subscription_fee']

# %%
one_user_data['proceeds'] = one_user_data.apply(get_proceeds, axis=1)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#  Стоит использовать функцию для расчета выручки

# %%
one_user_data['proceeds']
# Out:
# user_id  month
# 1        1        451.0
#          4        241.0
#          8        475.0
#          10       391.0
#          11       535.0
#                   ...
# 1534     6        308.0
#          8        484.0
#          9        234.0
#          11       824.0
#          12       178.0
# Name: proceeds, Length: 11331, dtype: float64

# %%
# check
one_user_data['proceeds'].sum()
# Out:
# 3878641.0

# %% [markdown]
# <div style>
# <font size="4"><b></b></font>
# <font size="5", color = "black">
# 🤝

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Выручка немного вырастет после изменения округления
#
#         3853677.0 - старый вариант

# %% [markdown]
# #### Шаг 6. Проверка гипотез

# %% [markdown]
# Создадим две таблицы с пользователями с подпиской и без.

# %%
one_user_data_subscription = one_user_data.query('subscription_fee == 199')
one_user_data_non_subscription = one_user_data.query('subscription_fee == 0')

# %%
one_user_data_subscription.reset_index()
one_user_data_subscription.head(10)
# Out:
#                count      distance  duration  minute_price  start_ride_price  \
# user_id month
# 1       1          2   7027.511294      42.0             6                 0
#         4          1    754.159807       7.0             6                 0
#         8          2   6723.470560      46.0             6                 0
#         10         2   5809.911100      32.0             6                 0
#         11         3   7003.499363      56.0             6                 0
#         12         2   6751.629942      28.0             6                 0
# 2       3          3  10187.723006      63.0             6                 0
#         4          2   6164.381824      40.0             6                 0
#         6          1   3255.338202      14.0             6                 0
#         7          2   6780.722964      48.0             6                 0
#
#                subscription_fee  proceeds
# user_id month
# 1       1                   199     451.0
# ...

# %%
one_user_data_non_subscription.reset_index()
one_user_data_non_subscription.head(10)
# Out:
#                count      distance  duration  minute_price  start_ride_price  \
# user_id month
# 700     1          1   2515.690719      15.0             8                50
#         2          5  13446.659764      89.0             8                50
#         3          1   3798.334905      19.0             8                50
#         4          1   2984.551206      16.0             8                50
#         6          2   5927.650988      29.0             8                50
#         7          2   4399.206279      21.0             8                50
#         8          1   4071.654669      17.0             8                50
#         10         2   6322.578618      44.0             8                50
#         11         3   8735.782625      32.0             8                50
# 701     1          1   2676.472894      18.0             8                50
#
#                subscription_fee  proceeds
# user_id month
# 700     1                     0     170.0
# ...

# %% [markdown]
# Введём уровень статистической значимости.

# %%
alpha = 0.05

# %% [markdown]
# Проверим, тратят ли пользователи с подпиской больше времени на поездки.

# %% [markdown]
# Построим две гипотезы. $H_0$ - в среднем пользователи с подпиской тратят время за одну поездку, равное времени пользователей без подписки, $H_1$ - в среднем пользователи с подпиской тратят больше времени, чем пользователи без подписки.

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит поправить Н0
#
#             𝐻0 - в среднем пользователи с подпиской тратят больше времени,
#
# Нулевая гипотеза, обозначаемая Н0, формулируется как гипотеза об отсутствии отличий: о сходстве двух распределений, о равенстве средних арифметических двух выборок и т.п. Нулевой она называется потому, что содержит 0: Х1 -Х2 =0, где Х1 и Х2 - значения признаков. Нулевая гипотеза утверждает, к примеру, что результаты выполнения задания экспериментальной группой и контрольной не различаются.

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит посмотреть на все примеры стат тестов в спринте и поправить формулировки гипотез
#
#         Построим две гипотезы.  𝐻0  - пользователи с подпиской тратят больше времени,  𝐻1  - пользователи с подпиской тратят меньше времени

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ <b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br /> Из формулировок Н0 и Н1, и из вывода пропало слово среднее
#
# ![image.png](attachment:image.png)

# %%
results_subscription = st.ttest_ind(data_ultra['duration'], data_free['duration'],
                                   alternative='greater')

print('p-value', results_subscription.pvalue)

if results_subscription.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не отвергаем нулевую гипотезу')
# Out:
# p-value 2.4959453720736625e-34
# Отвергаем нулевую гипотезу

# %% [raw]
# P-value много меньше \alpha следовательно в среднем пользователи с подпиской тратят больше времени на одну поездку.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит поправить опечатку в выборках
#
#         results_subscription = st.ttest_ind(data_ultra['duration'], data_ultra['duration'],
#                                    alternative='greater')
#
# Всегда, когда мы видим в результатах стат теста ровные и красивые значения: 0, 0.5, 1 → это повод 10 раз перепроверить свои расчеты, выборки, доп. параметры, т.к. высока вероятность ошибки

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит поменять выборки
#
#        ...one_user_data_subscription['duration'], one_user_data_non_subscription['duration'],
#                                    alternative='greater')
#
# на сырые
#
#         ...
#         data_ultra
#
# Стат тест на агрегированных данных может исказить реальные результаты сравнения

# %% [markdown]
# Проверим, преодолевают ли пользователи с подпиской расстояние больше чем 3130 м. $H_0$ - пользователи с подпиской преодолевают расстояние меньшее или равное 3130 м, $H_1$ - пользователи с подпиской преодолевают большее расстояние

# %%
value = 3130

results_subscription_distance = st.ttest_1samp(data_ultra['distance'], value, alternative='greater')

print('p-value', results_subscription_distance.pvalue)

if results_subscription.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не отвергаем нулевую гипотезу')
# Out:
# p-value 0.9195368847849785
# Отвергаем нулевую гипотезу

# %% [markdown]
# P-value больше $\alpha$, следовательно пользователи с подпиской в среднем преодолевают расстояние меньшее или равное 3130 м, следовательно меньше вероятность износа самоката, это выгодно бизнесу.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит дополнить вывод
#
#          следовательно пользователи с подпиской в среднем преодолевают расстояние меньшее или равное 3130 м.
#
# выгодно ли это бизнесу или нет

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит поменять выборку
#
#       one_user_data_subscription['distance']
#
# на
#
#         data_ultra

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Проверка стат теста выполнена с опечаткой
#
#         results_subscription_distance = st.ttest_1samp(one_user_data_subscription['distance'], value, alternative='greater')
#
#         if results_subscription.pvalue < alpha:
#             print('Отвергаем нулевую гипотезу')
#         else:
#             print('Не отвергаем нулевую гипотезу')
#
# стоит поправить и вывод
#
#         P-value много меньше alpha, следовательно

# %% [markdown]
# Проверим, будет ли помесячная выручка от пользователей с подпиской по месяцам выше, чем выручка от пользователей без подписки. $H_0$ - в среднем пользователи с подпиской тратят денег, равное пользователям с подпиской, $H_1$ - в среднем пользователи с подпиской тратят больше денег на поездки в месяц, чем пользователи без подписки.

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит поправить  гипотезы
#
#         𝐻0 - в среднем пользователи с подпиской тратят больше денег в месяц на поездки,
#
# здесь исправляем также как в первом стат тесте
#
# в гипотезах важен порядок выборок, в Н1 исправляем выборку про которую говорим
#
#         𝐻1 - в среднем пользователи без подписки тратят больше денег на поездки в месяц.
#
# т.к. сейчас стат тест не соответствует тому, что мы говорим в Н1
#
#         st.ttest_ind(one_user_data_subscription['proceeds'], one_user_data_non_subscription['proceeds'],
#                                    alternative='greater')
#
# если выполнять стат тест, как написано в Н1, то код будет таким
#
#         st.ttest_ind(one_user_data_non_subscription['proceeds'],
#                             one_user_data_subscription['proceeds'],
#                                    alternative='greater')

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит поправить  гипотезы
#
#         𝐻0 - пользователи с подпиской тратят больше денег в месяц на поездки,
#         𝐻1 - пользователи без подписки тратят больше денег на поездки в месяц.

# %%
results_subscription_proceeds = st.ttest_ind(one_user_data_subscription['proceeds'], one_user_data_non_subscription['proceeds'],
                                   alternative='greater')

print('p-value', results_subscription_proceeds.pvalue)

if results_subscription_proceeds.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не отвергаем нулевую гипотезу')
# Out:
# p-value 1.8850394384715216e-31
# Отвергаем нулевую гипотезу

# %% [markdown]
# P-value много меньше alpha, следовательно пользователи в среднем с подпиской тратят больше денег в месяц чем пользователи без подписки.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит поправить вывод, после исправления гипотез
#
#         p-value 1.8850394384715216e-31
#         Отвергаем нулевую гипотезу
#         P-value много меньше alpha, следовательно пользователи в среднем с подпиской тратят меньше или равное количество денег в месяц чем пользователи без подписки.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Что означает на языке статистики p-value 2.8130926188487286e-35

# %% [markdown]
# Среднее значение первой выборки лежит в области много большей или меньшей трёх сигм относительно распределения второй выборки.

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит поправить вывод, после исправления гипотез
#
#         p-value 2.8130926188487286e-35
#         Отвергаем нулевую гипотезу
#
#         P-value много меньше alpha, следовательно пользователи с подпиской тратят меньше или равное количество денег в месяц чем пользователи без подписки.

# %% [markdown]
# Рассмотрим обращение людей в техподдержку. Запишем количество обращений до обновления как before_update, соответственно после как after_update. Построем две гипотезы, $H_0$ - в среднем количество обращений до обновления осталось равным количеству обращений до обновления, $H_1$ - в среднем количество обращений стало меньше. Так как данные до обращения и после зависимы, к ним нужно применить метод
# st.ttest_rel(after_update, before_update, alternative='less').

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌  Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Т.е. мы будем проверять гипотезу о том, что среднее кол-во обращений было меньше ДО технических работ на сервере, а ПОСЛЕ тех.работ таких обращений стало больше?
#
#         Запишем количество обращений до обновления как before_update, соответственно после как after_update. Так как данные до обращения и после зависимы, к ним нужно применить метод
#
#         st.ttest_rel(before_update, after_update, alternative='less').
#
# __подсвечу, что для стат теста важен порядок выборок, которые мы подаем на расчет__
#
# Стоит добавить и формулировки Н0 и Н1

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Осталось поправить формулировки Н0 и Н1 под стат тест
#
#         𝐻0  - в среднем количество обращений до обновления стало меньше,
#         𝐻1  - в среднем количество обращений стало таким же или больше.
#
#
# Сейчас Н0 и Н1 не соответствуют стат тесту
#
#          t.ttest_rel(before_update, after_update, alternative='greater')
#
# Можно использовать примеры формулировки Н0 и Н1 из второго стат теста, но не сам код второго стат теста
#
#         𝐻0 - пользователи с подпиской преодолевают расстояние меньшее или равное 3130 м,
#         𝐻1 - пользователи с подпиской преодолевают большее расстояние

# %% [markdown]
# Рассмотрим обращение людей в техподдержку.
#
# Запишем количество обращений до обновления как before_update,
#
# соответственно после как after_update.
#
# Построем две гипотезы,
#
# $H_0$ - в среднем количество обращений до обновления осталось равным количеству обращений до обновления,
# $H_1$ - в среднем количество обращений стало меньше.
#
# Так как данные до обращения и после зависимы, к ним нужно применить метод
#
#     st.ttest_rel(after_update, before_update, alternative='less').

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌  Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# ![image.png](attachment:image.png)
#
# В твоей постановке стат теста - мы будем фактически проверять гипотезу о том, что среднее кол-во обращений было меньше ДО технических работ на сервере, а ПОСЛЕ тех.работ таких обращений стало больше.
#
#
#         st.ttest_rel(before_update, after_update, alternative='less').
#
# __подсвечу, что для стат теста важен порядок выборок, которые мы подаем на расчет__
#
# Стоит поправить 4-й стат тест. Исправления похожи на исправления в 3-м стат тесте

# %% [markdown]
# #### Шаг 7. Распределения

# %% [markdown]
# # Вывод

# %% [markdown]
# Найдём выручку пользователей с подпиской и без.

# %%
print('Общий доход пользователей без подписки составил', one_user_data_non_subscription['proceeds'].sum())
print('Общий доход пользователей с подпиской составил', (one_user_data_subscription['proceeds'].sum()))
# Out:
# Общий доход пользователей без подписки составил 2234104.0
# Общий доход пользователей с подпиской составил 1644537.0

# %% [markdown]
# Найдём среднюю выручку по каждому пользователю в месяц.

# %%
print('Средняя месячная выручка пользователей без подписки составила', 
      round(one_user_data_non_subscription.groupby('month')['proceeds'].mean().mean()),'рублей')
# Out:
# Средняя месячная выручка пользователей без подписки составила 329 рублей

# %%
print('Средняя месячная выручка пользователей с подпиской составила', 
      round(one_user_data_subscription.groupby('month')['proceeds'].mean().mean()),'рублей')
# Out:
# Средняя месячная выручка пользователей с подпиской составила 363 рублей

# %%
# check
one_user_data_subscription['proceeds'].mean().round()
# Out:
# 363.0

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️  Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Такой расчет может привести к ошибкам, ты рассчитываешь среднее значение от средних значений 12-ти месяцев, вместо того, чтобы сразу рассчитать среднее у выборки
#
#         print('Средняя месячная выручка пользователей с подпиской составила',
#       round(one_user_data_subscription.groupby('month')['proceeds'].mean().mean()),'рублей')
#
# сорри, если мой совет ⬇⬇⬇ увел тебя в сторону от корректного расчета

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Суммарная годовая выручка рассчитана корректно, молодец
#
#         Общий доход пользователей без подписки составил 2234104.0
#
#
# Стоит поправить расчет
#
#         Общий доход пользователей без подписки в месяц составил 203100
#
#         print('Общий доход пользователей без подписки в месяц составил', round(one_user_data_non_subscription['proceeds'].sum() / 11))
#
# не обязательно все пользователи использовали подписку 11 месяцев (и почему 11, а не 12?)
#
# Мы ищем сколько один средний пользователь приносил выручки в месяц — выполняется при помощи простой группировки данных

# %% [markdown]
# Было проведено исследование, которое должно было выявить как различаются некоторые параметры пользователей с подпиской и без. Число участников с подпиской в целом составило 54%, без подписки 46%.
#
# Исследовательский анализ данных показал, что в среднем пользователи с подпиской преодолевают относительно немного большее расстояние, чем пользователи без подписки, так же и со временем поездки. Это видно на гистограммах распределения по группам. Гистограммы показывают, что пик расстояния за одну поездку примерно на одном уровне у пользователй с подпиской и без, около 3100 м, однако дисперсия пользователей с подпиской больше. Также есть локальный пик у пользователей с подпиской около 1 км, у пользователей без подписки он около 500 м. Время продолжительности одной поездки примерно одинаковые, однако как и в случае с расстоянием дисперсия пользователей с подпиской больше. Были обнаружены некоторые аномалии, но они незначительны.
#
# Статистический анализ данных должен был проверить некоторые гипотезы. Первая - пользователи с подпиской тратят время на одну поездку, равное времени пользователей без подписки, эта гипотеза была опровергнута, что говорит о том что время одной поездки пользователей с подпиской выше, однако p-value этой гипотезы не сильно превышает порог. Вторая - в среднем пользователи с подпиской преодолевают расстояние, большее чем 3130 м эта гипотеза была не отвергнута, то есть износ самоката в среднем будет незначительным. Третья - в среднем по пользователям с подпиской доход, равный пользователям без подписки- эта гипотеза была отвергнута, то есть пользователи с подпиской в среднем приносят большее количество денег в месяц, что видно выше.
#
# Исследование должно было выявить, стоит ли увеличивать количество пользователей с подпиской, на основе полученных данных можно сказать, что стоит.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит   поправить
#
# + выводы по гипотезам
#
#         Вторая - в среднем пользователи с подпиской преодолевают расстояние, большее чем 3130 м эта гипотеза была не отвергнута, то есть износ самоката в среднем будет незначительным.
#
# у нас Н0 не была отвергнута
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит   поправить
#
# + выводы по гипотезам
#
#         Статистический анализ данных должен был проверить некоторые гипотезы. Первая - пользователи с подпиской тратят время на одну поездку, равное времени пользователей без подписки, эта гипотеза не была опровергнута, что говорит о том что время одной поездки пользователей без подписки в среднем ниже, однако p-value этой гипотезы не сильно превышает порог. Вторая - в среднем пользователи с подпиской преодолевают расстояние, большее чем 3130 м эта гипотеза была не отвергнута, то есть износ самоката в среднем будет значительным.

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит добавить и поправить
#
# + выводы по гипотезам
# + сравнение показателей суммарной годовой выручки для каждого тарифа и среднемесячной выручки для среднего пользователя, также для каждого тарифа
#  + условно, 1 млн. руб. за год мы заработали на пользователях с подпиской и 2 млн. руб. на пользователях без подписки
#  + условно, 300 руб. в среднем в месяц нам приносит один пользователь с подпиской и 200 рублей пользователь без подписки
#
# + итоговую рекомендацию бизнесу

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит добавить и поправить
#
# + стат. показатели по двум группам пользователей
# + выводы по гипотезам
# + сравнение показателей суммарной годовой выручки для каждого тарифа и среднемесячной выручки для среднего пользователя, также для каждого тарифа
#  + условно, 1 млн. руб. за год мы заработали на пользователях с подпиской и 2 млн. руб. на пользователях без подписки
#  + условно, 300 руб. в среднем в месяц нам приносит один пользователь с подпиской и 200 рублей пользователь без подписки
#
# + итоговую рекомендацию бизнесу

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Ты выполнил практически все пункты проекта, молодец! Проведен значительный объем исследования деятельности компании
#
# Критические ❌ комментарии:
#
#  + добавить название проекту
#  + поправить и добавить графики
#  + в разделе проверки гипотез поправить Н0 и Н1, выборки и выводы
#  + добавить статистики в промежуточные выводы
#  + прочие
#
# Стоит обратить внимание на ⚠️ комментарии...
#
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5", color= "seagreen"><b>Жду твой проект и твои комментарии 🤝</b></font><br />

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [Подробное руководство по группировке и агрегированию с помощью pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%B4%D1%80%D0%BE%D0%B1%D0%BD%D0%BE%D0%B5%20%D1%80%D1%83%D0%BA%D0%BE%D0%B2%D0%BE%D0%B4%D1%81%D1%82%D0%B2%D0%BE%20%D0%BF%D0%BE%20%D0%B3%D1%80%D1%83%D0%BF%D0%BF%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B5%20%D0%B8%20%D0%B0%D0%B3%D1%80%D0%B5%D0%B3%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8E%20%D1%81%20%D0%BF%D0%BE%D0%BC%D0%BE%D1%89%D1%8C%D1%8E%20pandas.html)
#
# [Примеры объединения таблиц, общая справка](https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html)
#
# [Примеры объединения таблиц, Федоров Д.](https://dfedorov.spb.ru/pandas/08.%20%D0%9A%D0%B0%D0%BA%20%D0%BE%D0%B1%D1%8A%D0%B5%D0%B4%D0%B8%D0%BD%D0%B8%D1%82%D1%8C%20%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D0%B5%20%D0%B8%D0%B7%20%D0%BD%D0%B5%D1%81%D0%BA%D0%BE%D0%BB%D1%8C%D0%BA%D0%B8%D1%85%20%D1%82%D0%B0%D0%B1%D0%BB%D0%B8%D1%86_.html?ysclid=lklv5hyic8790467123)
#
#
#
# [Искусство статистики](https://www.mann-ivanov-ferber.ru/books/iskusstvo-statistiki/)
#
#
# В помощь — как реализовать интерактивный план проекта вручную, смотри по <a href="https://stackoverflow.com/questions/49535664/how-to-hyperlink-in-a-jupyter-notebook/49717704">ссылке</a>
#
# пара ссылок и по разделам проекта можно будет переходить без пролистывания всего кода, особенно актуально на проектах длина которых >  10 страниц (и там где не установлен плагин TOC)
#
#
# [Базовый обзор распределений в статистике](https://qwertybox.ru/articles/242302/)
#
# [Как использовать биномиальное распределение в Python](https://www.codecamp.ru/blog/binomial-distribution-python/?ysclid=lmjbdt49de135513011)
#
# [Объяснение P-значений и статистической значимости](https://www.codecamp.ru/blog/p-values-statistical-significance/?ysclid=lm88qnc76l397155692)

# %% [markdown]
# #### Бонус

# %% [markdown]
# ##### Задача 7.1 — декомпозиция
#
# + Отделу маркетинга GoFast поставили задачу: нужно провести акцию с раздачей промокодов на один бесплатный месяц подписки, в рамках которой как минимум 100 существующих клиентов должны продлить эту подписку.
#
# + То есть по завершении периода действия подписки пользователь может либо отказаться от неё, либо продлить, совершив соответствующий платёж.
#
# + Эта акция уже проводилась ранее и по итогу выяснилось, что после бесплатного пробного периода подписку продлевают 10 % пользователей.
#
# + Выясните, какое минимальное количество промокодов нужно разослать, чтобы вероятность не выполнить план была примерно 5 %.
#
# + Подберите параметры распределения, описывающего эту ситуацию, постройте график распределения и сформулируйте ответ на вопрос о количестве промокодов.

# %% [markdown]
# + 100 существующих клиентов должны продлить эту подписку.
#  + т.е. мы ищем х - кол-во промокодов, которое мы раздадим, чтобы сохранить 100 клиентов

# %% [markdown]
# + может либо отказаться от неё, либо продлить
#  + т.е. два исхода

# %% [markdown]
# + подписку продлевают 10 % пользователей
#  + т.е. из кол-ва Х, которое мы найдем и по которому разошлем промокоды, полагаясь на предыдущий опыт, продлят подписку 10%

# %% [markdown]
# + вероятность не выполнить план была примерно 5 %
#  + т.е. мы должны найти вероятность успеха нашей акции 1-0,05 = 95%
#  + этот план будет иметь свою вероятность исполнения при разном кол-ве Х, т.е. если мы выберем Х = 1000, вероятность успеха будет равна А, при 2000 промокодах, вероятность будет равна В. Но, увеличивая кол-во промокодов, мы увеличиваем трудозатраты ... По этой причине нас устроит вероятность успеха 95%, для которой и предстоит рассчитать кол-во промокодов Х

# %% [markdown]
# Получается задача делиться на две части
#
# + число положительных исходов должно быть равно 100-ам
#
# + но вероятность такого события должна быть равна 95%

# %% [markdown]
# Урок
#
# Percent Point Function для нормального распределения
# + Ранее вы познакомились с функцией распределения, или кумулятивной функцией распределения.

# %% [markdown]
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />    меняем norm на binom
#
# https://www.statology.org/binompdf-vs-binomcdf/
#
# немного перефразируем известный сайт
#
#     binom.cdf(k, n, p):
#
# Кумулятивная функция распределения - это функция, которая показывает вероятность того, __что случайная величина будет меньше или равна некоторому значению.__
#
#
#
#
# [примеры решения задач](https://www.codecamp.ru/blog/binomial-distribution-python/?ysclid=lskfouc2d4788619343)

# %%
for i in range (1, 13):
    trials = 100 * i
    print(f"i: {i, trials}\tprobability: {(st.binom.cdf(99, trials, 0.1)).round(3)}")
# Out:
# i: (1, 100)	probability: 1.0
# i: (2, 200)	probability: 1.0
# i: (3, 300)	probability: 1.0
# i: (4, 400)	probability: 1.0
# i: (5, 500)	probability: 1.0
# i: (6, 600)	probability: 1.0
# i: (7, 700)	probability: 1.0
# i: (8, 800)	probability: 0.987
# i: (9, 900)	probability: 0.854
# i: (10, 1000)	probability: 0.485
# i: (11, 1100)	probability: 0.145
# i: (12, 1200)	probability: 0.022

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> При 100-а розданных промокодов, вероятность того, что успешно продлят подписку менее или равно 99 пользователей будет равна 1-ке, или по другому можно сказать, что это может быть или 5 продливших подписку пользователей, или 99 пользователей
#
# т.е. это нулевой для маркетологов результат, который никого не устраивает
#
# А чем больше промокодов мы раздаем, тем вероятность получить такой результат уменьшается, например при 900-а розданных промокодов уже только с 0,856 вероятностью мы получим или 5 продливших подписку пользователей, или 99 пользователей
#
# т.е. с вероятностью 0,144 мы получим 100 или более пользователей продливших подписку, но нам надо 95%

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />   Для того чтобы построить нужный нам график, придется из формулы вычесть 1-ку
#
# 1 - значение кумулятивной функции распределения `binom.cdf(k, n, p)` покажет вероятность того, что случайная величина примет значение, которое будет не меньше заданной, т.к. нам необходимо выйти на уровень 95%
#
# ![image.png](attachment:image.png)
#
# почему выбираем значение 99, т.к. по определению функции → меньше или равно

# %%
for i in range (1, 13):
    trials = 100 * i
    print(f"i: {i, trials}\ttarget_probability: {(1 - st.binom.cdf(99, trials, 0.1)).round(3)}");    
   
print(f"i: {13, 1161}\ttarget_probability: {(1 - st.binom.cdf(99, 1161, 0.1)).round(3)}")
# Out:
# i: (1, 100)	target_probability: 0.0
# i: (2, 200)	target_probability: 0.0
# i: (3, 300)	target_probability: 0.0
# i: (4, 400)	target_probability: 0.0
# i: (5, 500)	target_probability: 0.0
# i: (6, 600)	target_probability: 0.0
# i: (7, 700)	target_probability: 0.0
# i: (8, 800)	target_probability: 0.013
# i: (9, 900)	target_probability: 0.146
# i: (10, 1000)	target_probability: 0.515
# i: (11, 1100)	target_probability: 0.855
# i: (12, 1200)	target_probability: 0.978
# i: (13, 1161)	target_probability: 0.95

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### check

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Примеры особенности объединения, в т.ч. с параметрами по умолчанию при merge (для справки в join такая же «засада» по характеру, но другая по исполнению)
#
# Использование параметров по умолчанию может привести к потере данных при объединении

# %%
dfg1 = pd.DataFrame(
    {
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
        "C": ["C0", "C1", "C2", "C3"],
        "D": ["D0", "D1", "D2", "D3"],
    },
    index=[0, 1, 2, 3],
)

dfr4 = pd.DataFrame(
    {
        "B": ["B2", "B3", "B6", "B7"],
        "D": ["D2", "D3", "D6", "D7"],
        "F": ["F2", "F3", "F6", "F7"],
        "E": [np.nan, np.nan, np.nan, np.nan]
    },
    index=[2, 3, 6, 0],
)

# %%
display(dfg1, dfr4)
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
#     B   D   F   E
# 2  B2  D2  F2 NaN
# 3  B3  D3  F3 NaN
# 6  B6  D6  F6 NaN
# 0  B7  D7  F7 NaN

# %%
dfg1.merge(dfr4, left_on=dfg1.index, right_on=dfr4.index, how='outer')
# Out:
#    key_0    A  B_x    C  D_x  B_y  D_y    F   E
# 0      0   A0   B0   C0   D0   B7   D7   F7 NaN
# 1      1   A1   B1   C1   D1  NaN  NaN  NaN NaN
# 2      2   A2   B2   C2   D2   B2   D2   F2 NaN
# 3      3   A3   B3   C3   D3   B3   D3   F3 NaN
# 4      6  NaN  NaN  NaN  NaN   B6   D6   F6 NaN

# %%
dfg1.merge(dfr4, 'outer')
# Out:
#      A   B    C   D    F   E
# 0   A0  B0   C0  D0  NaN NaN
# 1   A1  B1   C1  D1  NaN NaN
# 2   A2  B2   C2  D2   F2 NaN
# 3   A3  B3   C3  D3   F3 NaN
# 4  NaN  B6  NaN  D6   F6 NaN
# 5  NaN  B7  NaN  D7   F7 NaN

# %%
dfg1.merge(dfr4)
# Out:
#     A   B   C   D   F   E
# 0  A2  B2  C2  D2  F2 NaN
# 1  A3  B3  C3  D3  F3 NaN

# %%
dfg1.merge(dfr4, 'inner')
# Out:
#     A   B   C   D   F   E
# 0  A2  B2  C2  D2  F2 NaN
# 1  A3  B3  C3  D3  F3 NaN

# %% [markdown]
# ##### check при объединении без пропусков получаем пропуски

# %%
dfg1 = pd.DataFrame(
    {
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
        "C": ["C0", "C1", "C2", "C3"],
        "D": ["D0", "D1", "D2", "D3"],
    },
    index=[0, 1, 2, 3],
)

dfr4 = pd.DataFrame(
    {
        "B": ["B2", "B3", "B6", "B7"],
        "D": ["D2", "D3", "D6", "D7"],
        "F": ["F2", "F3", "F6", "F7"],
        
        
    },
    index=[2, 3, 6, 0],
)

# %%
dfg1.merge(dfr4, how='outer')
# Out:
#      A   B    C   D    F
# 0   A0  B0   C0  D0  NaN
# 1   A1  B1   C1  D1  NaN
# 2   A2  B2   C2  D2   F2
# 3   A3  B3   C3  D3   F3
# 4  NaN  B6  NaN  D6   F6
# 5  NaN  B7  NaN  D7   F7

# %% [markdown]
# ##### check

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Пример Закона больших чисел в действии (обратном), удалим 20 процентов (больше общепринятых 10%) всех данных из таблицы, где мы рассчитали выручку

# %%
dfg_first = one_user_data.copy()
dfg_first.columns
# Out:
# Index(['count', 'distance', 'duration', 'minute_price', 'start_ride_price',
#        'subscription_fee', 'proceeds'],
#       dtype='object')

# %%
x = 'subscription_fee'
y = dfg_first.columns[-1]
y
# Out:
# 'proceeds'

# %%
dfg_first.groupby(x)[y].mean().round(1).to_frame()
# Out:
#                   proceeds
# subscription_fee
# 0                    328.6
# 199                  362.8

# %%
dfg_first.groupby(x)[y].hist(bins=200, figsize=(15,3), legend=True)
plt.title('Гистограммы ежесячной выручки двух групп пользователей')
plt.xlabel('руб.')
plt.ylabel('кол-во');

# %%
# копируем таблицу
dfg = dfg_first.copy()

# %%
dfg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 11331 entries, (1, 1) to (1534, 12)
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   count             11331 non-null  int64
#  1   distance          11331 non-null  float64
#  2   duration          11331 non-null  float64
#  3   minute_price      11331 non-null  int64
#  4   start_ride_price  11331 non-null  int64
#  5   subscription_fee  11331 non-null  int64
#  6   proceeds          11331 non-null  float64
# dtypes: float64(3), int64(4)
# memory usage: 697.3 KB

# %%
# удаляем данные, 20%
for col in dfg.columns:
    dfg.loc[dfg.sample(frac=0.2).index, col] = np.nan

# %%
dfg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 11331 entries, (1, 1) to (1534, 12)
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   count             9065 non-null   float64
#  1   distance          9065 non-null   float64
#  2   duration          9065 non-null   float64
#  3   minute_price      9065 non-null   float64
#  4   start_ride_price  9065 non-null   float64
#  5   subscription_fee  9065 non-null   float64
#  6   proceeds          9065 non-null   float64
# dtypes: float64(7)
# memory usage: 955.7 KB

# %%
dfg.groupby(x)[y].mean().round(1).to_frame()
# Out:
#                   proceeds
# subscription_fee
# 0.0                  329.3
# 199.0                362.8

# %%
dfg.groupby(x)[y].hist(bins=200, figsize=(15,3), legend=True)
plt.title('Гистограммы ежесячной выручки двух групп пользователей')
plt.xlabel('руб.')
plt.ylabel('кол-во');

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Если сравнить средние значения выручки, даже после удаления 20-ти процентов данных (но одно важное условие — данные удалялись случайным образом), они изменились незначительно, как и характер распределения самих данных (кол-во данных уменьшилось, безусловно).
#
# Для сравнения представлен рисунок первой гистограммы
#
# Закон больших чисел действует и в обратном направлении — у нас нет необходимости собирать 100% данных, чтобы проверить основные гипотезы, при условии, что выборка достаточно большая
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ##### check

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в4</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Приведу пример и теорию для понимания формулировок и интерпретации итогов проведения гипотез</b>
#
#
# Задача. Приведены два датасета: сумма покупок, совершённых за месяц посетителями, привлечёнными по двум разным каналам. В вашем распоряжении случайная выборка из 30 покупок для каждого канала.
#
# H0 - средние чеки равны
#
#
# H1 - средние чеки НЕ равны
#
# Да сама формулировка нулевой и альтернативной гипотезы звучит именно так, но результат теста интерпретируется другими словами
#
#
# Формулирование двусторонних гипотез. <br>
#
# <b>Никакие экспериментально полученные данные никогда не подтвердят какую-либо гипотезу. Это наше фундаментальное ограничение. </b>Данные могут лишь не противоречить ей или, наоборот, показывать крайне маловероятные результаты (при условии, что гипотеза верна). Но и в том, и в другом случае нет оснований утверждать, что выдвинутая гипотеза доказана.
# Допустим, данные гипотезе не противоречат, тогда мы её не отвергаем. Если же мы приходим к выводу, что получить такие данные в рамках этой гипотезы вряд ли возможно, у нас появляется основание отбросить эту гипотезу.

# %%
# Приведены два датасета: сумма покупок, совершённых за месяц посетителями ...

sample_1 = [3071, 3636, 3454, 3151, 2185, 3259, 1727, 2263, 2015,
2582, 4815, 633, 3186, 887, 2028, 3589, 2564, 1422, 1785,
3180, 1770, 2716, 2546, 1848, 4644, 3134, 475, 2686,
1838, 3352]
sample_2 = [1211, 1228, 2157, 3699, 600, 1898, 1688, 1420, 5048, 3007,
509, 3777, 5583, 3949, 121, 1674, 4300, 1338, 3066,
3562, 1010, 2311, 462, 863, 2021, 528, 1849, 255,
1740, 2596]
alpha = .05 # критический уровень статистической значимости
# если p-value окажется меньше него - отвергнем гипотезу
results = st.ttest_ind(
sample_1,
sample_2)
print('p-значение:', results.pvalue)
if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.1912450522572209
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в4</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Интерпретация результата:
#
# Полученное значение p-value говорит о том, что хотя средний чек пришедших из разных каналов и неодинаков, <b>с вероятностью в почти 19% такое или большее различие можно получить случайно. </b>Это явно слишком большая вероятность, чтобы делать вывод о значимом различии между средними чеками.
#
# А если p-value  будет равно 0,9999, то это значит, что с вероятностью почти 100% <u>такое различие</u> можно получить случайно — то есть почти никогда :)  (но учитываем, что тест проводится на выборке из генеральной совокупности, все может поменяться)
