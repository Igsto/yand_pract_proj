# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color = "seagreen"><b>✔️ Комментарий ревьюера в5</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Привет, Игорь :)
#
# Спасибо за всю работу на проекте, за все исправления и комментарии (комментарии, особенно новые, стоит подсвечивать цветом 🤝)
#
# Стоит немного поправить фильтрацию данных - подсказку добавил 🤝
#
# Подведем итоги, мы научились и повторили на проекте каким образом:
#
# + читать тех. задание проекта
# + исследовать неочищенные данные
# + выдвигать гипотезы о пропусках данных и заполнять их значениями
# + принимать решения об удалении некачественных данных
# + находить аномалии в данных и отделять редкие значения
# + соглашаться с наличием пропусков в данных и не забывать об их наличии при фильтрации
# + строить информативные визуализации
# + делить одну выборку на две части
# + находить зависимости и распределения в данных
# + формировать выводы
#
# Навыки отработаны, проект принят
#
# <b>Поздравляю с успешно сданным третьим проектом на факультете дата-аналитики Я.Практикум</b>
#
# <div class="alert alert-success">
#     <font size="5", color = "seagreen"><b>Успехов в дальнейшей учебе 🤝</b></font><br />

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Привет, Игорь :) Спасибо за доработки 🤝
#
# Критические ❌ комментарии
#
#
# + завершить фильтрацию редких значений, должно остаться не менее 21 000 записи после всех фильтраций
#
#
# добавил бонус и новые подсказки с пометкой в4

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Привет, Игорь :) Спасибо за доработки 🤝
#
# Критические ❌ комментарии
#
#
# + настроить фильтрацию редких значений, должно остаться не менее 21 000 записи после всех фильтраций
# + исследовать аномалии в п.4.5
#
# добавил новые подсказки с пометкой в3
#
# если пропустил твои вопросы, просьба скопировать

# %%
# вопросы Игоря:

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Игорь :) Добавил новых подсказок на второй версии проверки

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Игорь :) Спасибо, что прислал задание 🤝 Меня зовут Ринат Хисамов и я буду проверять твой проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# Поехали 🚀
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев </b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br />
#         <font size="3", color = "black">
# <br />
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")  <br /><br />
#         <a href="https://devpractice.ru/matplotlib-book/">“Библиотека Matplotlib” доступна для скачивания БЕСПЛАТНО!</a>
#         На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)
#
#
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-danger">
# <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# # Для твоих вопросов или комментариев оставлю такую ячейку, чтобы было удобнее взаимодействовать на проекте

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> ... , вот мой вопрос ...

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> это неполная версия проекта, у меня есть некоторые вопросы, но я не знаю как с тобой связаться,
# вопрос будет там где есть такой же шаблон

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Договорились, на проекте так и работаем, если появляется вопрос задаем его там, где что-то не получается

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Вам нужно научиться определять рыночную стоимость объектов недвижимости. Для этого проведите исследовательский анализ данных и установите параметры, влияющие на цену объектов. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта и других объектов — эти данные автоматически получены из геосервисов. Количество парков и водоёмов также заполняется без участия пользователя.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Название, краткое вступление в работу и главная задача зафиксированы.
#
#
# Четкий план работ и перечень основных задач позволит коллегам быстрее вникнуть в суть проекта, + будет легче  идти к главной цели проекта

# %% [markdown]
# План:
# 1. Открытие файл с данными и изучение общей информации.
# 2. Предобработка данных
#     - Обработка дубликатов в названии населённых пунктов
#     - Обработка пропущенных значений и замена типов данных
# 3. Добавление новых столбцов
# 4. Исследовательский анализ данных
#     - Построение гистограмм
#     - Изучение того как продавались квартиры
#     - Определения факторов, которые больше всего влияют на полную стоимость объекта
#     - Подсчёт средней цены за квадратный метр в 10 пунктах с наибольшим числом объявлений
#     - Подсчёт средней цены в Санкт-Петербурге в зависимости от удаления от центра
# 5. Общий вывод

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит добавлять еще больше подробностей к плану проекта, это позволит избежать многих ошибок на будущих проектах

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию

# %%
import pandas as pd
#import matpro
import numpy as np
import datetime
import re
import matplotlib.pyplot as plt

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />   Кажется, в этот раз весь код на проекте запускался вручную ... 58-я строка кода в начале проекта
#
# ![image-3.png](attachment:image-3.png)
#
#
# ![image-2.png](attachment:image-2.png)
#
#
#
# Проверить работоспособность кода — можно нажав на панели Jupiter Hub Kernel и Restart & Run All (см скриншот ниже).
#
# ![image.png](attachment:image.png)

# %%
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />стоит делить блок загрузки библиотек и код загрузки датасета, в случае необходимости добавления новых библиотек не придется загружать весь датасет заново и перезапускать проект целиком

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит познакомиться с данными сразу после загрузки при помощи
#
#         .head()
#
# для исключения некорректной загрузки

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %%
data.hist(bins=50, figsize=(15,20));

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Убрать служ. информацию поможет точка с запятой на посл. строке кода
#
#     array([[<AxesSubplot:title={'center':'total_images'}>,
#         <AxesSubplot:title={'center':'last_price'}>,
#         <AxesSubplot:title={'center':'total_area'}>,
#         <AxesSubplot:title={'center':'rooms'}>],
#        [<AxesSubplot:title={'center':'ceiling_height'}>,
#         <AxesSubplot:title={'center':'floors_total'}>,
#         <AxesSubplot:title={'center':'living_area'}>,
#         <AxesSubplot:title={'center':'floor'}>],
#        [<AxesSubplot:title={'center':'kitchen_area'}>,
#         <AxesSubplot:title={'center':'balcony'}>,
#         <AxesSubplot:title={'center':'airports_nearest'}>,
#         <AxesSubplot:title={'center':'cityCenters_nearest'}>],
#        [<AxesSubplot:title={'center':'parks_around3000'}>,
#         <AxesSubplot:title={'center':'parks_nearest'}>,
#         <AxesSubplot:title={'center':'ponds_around3000'}>,
#         <AxesSubplot:title={'center':'ponds_nearest'}>],
#        [<AxesSubplot:title={'center':'days_exposition'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)
#
# data.hist(figsize=(15, 20));

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> не помешает добавить вывод после первого знакомства с данными

# %% [markdown]
# По гистограммам по необработанным данным видно, что присутствуют много аномальных значений, например в столбце ceiling_height высота потолков доходит до 100 метров. В некоторых столбцах пик гистограммы находится на удалении от центра, что говорит о том, что аномальных значений относительно малою

# %% [markdown]
# ### Выполните предобработку данных

# %% [markdown]
# Кратко оценим таблицу методом .info()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# Найдём количество пропусков в каждом столбце

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# Пропуски необходимо обработать, то есть либо удалить, либо заменить на какое-то значение, либо оставить. Так же необходимо перевести каждый столбец к правильному типу данных, займёмся этим параллельно обрабатыванию пропусков.

# %%
# check
# пропущенные значения бары

def pass_value_barh(df):
    try:
        (
            (df.isna().mean()*100)
            .to_frame()
            .rename(columns = {0:'space'})
            .query('space > 0')
            .sort_values(by = 'space', ascending = True)
            .plot(kind = 'barh', figsize = (19,6), rot = -5, legend = False, fontsize = 16)
            .set_title('Пример' + "\n", fontsize = 22, color = 'SteelBlue')    
        );    
    except:
        print('пропусков не осталось :) или произошла ошибка в первой части функции ')

# %%
pass_value_barh(data)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br /> Наглядность представления информации одна из важных составляющих работы дата-аналитика или дата-сайентиста
#
# __мой график оформлен не совсем корректно, сможешь отметить, что стоило бы исправить в графике?__

# %% [markdown]
# На графике не показаны абсолютные значения.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Принимается
#
# Цвет у шрифта заголовка почти совпадает с цветом у баров
#
# За поворот текста на оси `У` отвечает параметр `rot`, можно добавить обозначение оси `Х` (процент записей с пропусками)
#
#         df.isna().mean()*100 — для расчета процента пропусков в колонке
#
# На графике мы оцениваем масштаб проблемы с пропусками и возможное совпадение % пропущенных значений в колонках
#
# добавить подписи к осям мешает строка кода
#
#         .set_title('Пример' + "\n", fontsize = 22, color = 'SteelBlue')
#
# её можно заменить на
#
#         ;
#         plt.title('Пропущенные значения, %' + "\n", fontsize=22, color='SteelBlue')
#         plt.xlabel('Процент пропусков', fontsize=22)
#         plt.ylabel('Столбцы с пропусками')
#
# плюс можно установить шкалу от 0 до 100
#
#         plt.xlim(0, 100)
#
# часть моих новых шрифтов оформлена не совсем корректно 🤝😉

# %% [markdown]
# Для начала рассмотрим столбец locality_name. Всего 49 пропущенных значений, относительно количества всех строк эти значения можно убрать.

# %%
data = data.dropna(subset=['locality_name'])
data['locality_name'].isna().sum()
# Out:
# 0

# %% [markdown]
# Посмотрим на уникальные значения столбца методом unique()

# %%
data['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'поселок городского типа Ефимовский', 'посёлок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
# ...

# %% [markdown]
# Необходимо оставить только названия населённых пунктов, убрав наименования "деревня", "посёлок" и т.д. Можно заметить, что названия всегда с заглавной буквы, поэтому в каждом значении уберём всё кроме названия, для чего реализуем следующую функцию. Для проверки этой гипотизы напишем цикл, в котором проверяется есть ли заглавная буква для каждого уникального имени, если есть - посчитаем их количество.

# %%
name_counter = 0
names_literal = []

for name in data['locality_name'].unique():
    if name.islower():
        name_counter += 1
        names_literal.appedn(name)
        
print(name_counter)
names_literal
# Out:
# 0
# []

# %% [markdown]
# В уникальных значениях имён нет имён только со строчными буквами, напишем функцию, которая будет возвращать часть строки которая начинается с заглавной буквы.

# %%
def return_name(name):
    return re.findall(r'[А-Я].*', name)[0]

# %%
data['locality_name'] = data['locality_name'].apply(return_name)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит оптимизировать код
#
#         for i in name:
#                 if 'А' <= i <= 'Я':
#                     return name[name.find(i):]
#
# Анти-паттерн №2: применение циклов for при работе с объектами pandas DataFrame
#
#
# [4 анти-паттерна pandas и способы борьбы с ними](https://habr.com/ru/companies/wunderfund/articles/682388/)

# %% [markdown]
# Причина пропусков является человеческим фактором, скорее всего тот кто заполнял таблицу просто забыл ввести название населённого пункта.

# %%
data['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'Шушары', 'Янино-1', 'Парголово', 'Мурино',
#        'Ломоносов', 'Сертолово', 'Петергоф', 'Пушкин', 'Кудрово',
#        'Коммунар', 'Колпино', 'Красный Бор', 'Гатчина', 'Фёдоровское',
#        'Выборг', 'Кронштадт', 'Кировск', 'Новое Девяткино',
#        'Металлострой', 'Лебяжье', 'Сиверский', 'Молодцово',
#        'Кузьмоловский', 'Новая Ропша', 'Павловск', 'Пикколово',
#        'Всеволожск', 'Волхов', 'Кингисепп', 'Приозерск', 'Сестрорецк',
#        'Куттузи', 'Аннино', 'Ефимовский', 'Плодовое', 'Заклинье',
#        'Торковичи', 'Первомайское', 'Красное Село', 'Понтонный',
#        'Сясьстрой', 'Старая', 'Лесколово', 'Новый Свет', 'Сланцы',
#        'Путилово', 'Ивангород', 'Шлиссельбург', 'Никольское',
#        'Зеленогорск', 'Сосновый Бор', 'Оржицы', 'Кальтино', 'Романовка',
#        'Бугры', 'Рощино', 'Кириши', 'Луга', 'Волосово', 'Отрадное',
#        'Павлово', 'Оредеж', 'Копорье', 'Молодёжное', 'Тихвин', 'Победа',
# ...

# %% [markdown]
# #### check name

# %%
# check
data.locality_name.nunique()
# Out:
# 305

# %% [markdown]
# В населённых пункиах типа "деревня Кудрово" и "Кудрово" я избавился от слов "деревня", "посёлок" и т.д. и объединил их с названиями без этих строк.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Хорошая работа по избавлению от неявных дубликатов
#
#
# Можно отметить в отчете — стоит ли объединять нас. пункты
#
#         'деревня Кудрово'
#         'Кудрово'

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# Для того, __чтобы изменить лишь часть строки,__ можно добавить к коду — .str
#
#         .str.replace('посёлок','поселок')
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.replace.html

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит исследовать выборку
#
#
# + __на простое дублирование записей__
#  + __особенно это станет важным, когда мы перейдем к более сложным задачам на втором модуле курса__
#
# <br />
#
# + дополнительно — на рабочих проектах стоит искать дубликаты по сумме ключевых параметров (подмножеству), для примера:
#
#  + общ. площадь квартиры,
#  + этаж,
#  + общая этажность дома,
#  + расстояние до центра
#  + название населенного пункта
#  + кол-во комнат
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html?highlight=duplicat#pandas.DataFrame.duplicated
#
# https://www.codecamp.ru/blog/pandas-find-duplicates/

# %% [markdown]
# Исследуем на дублировании записей.

# %%
duplicates = data[data.duplicated()]
duplicates
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# Дубликатов нет.

# %% [markdown]
# Рассмотрим столбец balcony. Когда заполнялась таблица вероятно отсутствие балконов никак не заполнялось, поэтому заполним пустые значения цифрой 0, после найдём количество пропусков.

# %%
data['balcony'] = data['balcony'].fillna(0)
data['balcony'].isna().sum()
# Out:
# 0

# %% [markdown]
# Заменим тип столбца на int.

# %%
data['balcony'] = data['balcony'].astype('int')

# %% [markdown]
# Рассмотрим столбец is_apartment.

# %%
data['is_apartment'].unique()
# Out:
# array([nan, False, True], dtype=object)

# %% [markdown]
# В списке уникальных значений только True и False, однако столбец имеет тип object. Большинство квартир не апартаменты, скорее всего не апартаменты никак не отмечались, поэтому заменим пропущенные значения на False, а потом заменим тип столбца на bool.

# %%
data['is_apartment'] = data['is_apartment'].fillna(False)

# %%
data['is_apartment'] = data['is_apartment'].astype('bool')

# %% [markdown]
# Найдём количество пропусков.

# %%
data['is_apartment'].isna().sum()
# Out:
# 0

# %% [markdown]
# Аналогично поступим со столбцами open_plan и studio. Большинство квартир имеют несвободную планировку и их тип не студая, поэтому заменим пропуски значением False. Тип данных булевый, поэтому дополнительно приводить столбцы к нужному типу нереально.

# %%
data['open_plan'] = data['open_plan'].fillna(False)
data['studio'] = data['studio'].fillna(False)

# %% [markdown]
# Посчитаем количество пропущенных значений:

# %%
data['open_plan'].isna().sum()
# Out:
# 0

# %%
data['studio'].isna().sum()
# Out:
# 0

# %% [markdown]
# Рассмотрим столбцы parks_around3000 и ponds_around3000. Пропущенные значения скорее всего не заполнялись, поэтому заменим их на 0.

# %%
data['parks_around3000'] = data['parks_around3000'].fillna(0)
data['ponds_around3000'] = data['ponds_around3000'].fillna(0)

# %% [markdown]
# Приведём типы столбцов к int.

# %%
data['parks_around3000'] = data['parks_around3000'].astype(int)
data['ponds_around3000'] = data['ponds_around3000'].astype(int)

# %% [markdown]
# Посчитаем количество пропущенных значений:

# %%
print(data['parks_around3000'].isna().sum())
data['ponds_around3000'].isna().sum()
# Out:
# 0
# 0

# %% [markdown]
# Рассмотрим столбцы parks_nearest и ponds_nearest. Пропущенных значений много относительно всех строк в таблице, поэтому нельзя каждый пропуск заменить на конкретное значение. Можно проверить количество парков и прудов в радиусе 3 км., если их 0 - заменить пропуск на значение 3001 (как максимальное значение расстояния), для остальных значений найти медиану расстояния для каждого значения и заменить пропуск на него.

# %% [markdown]
# Рассмотрим столбцы parks_nearest и ponds_nearest. Пропущенных значений много относительно всех строк в таблице, поэтому нельзя каждый пропуск заменить на конкретное значение. Можно посчитать медиану значений расстояния до ближайшего парка относительно населённого пункта, если данных нет - заменить пропуски на медиану в целом. Также надо учесть количество парков в радиусе 3 км.

# %%
parks_pivot = data.pivot_table(index=['locality_name', 'parks_around3000'], values='parks_nearest', aggfunc='median', dropna=False)

# %% [markdown]
# Создадим сводную таблицу для медианы относительно количества парков в целом, с её помощью будем заполнять пропущенные значения в первой таблице.

# %%
parks_pivot_all = data.pivot_table(index='parks_around3000', values='parks_nearest', aggfunc='median')

# %% [markdown]
# Заменим пустые значения в сводной таблице значениями в целом.

# %%
data['parks_around3000'].unique()
# Out:
# array([1, 0, 2, 3])

# %%
for name in data['locality_name'].unique():
    for i in data['parks_around3000'].unique():
        if np.isnan(parks_pivot['parks_nearest'][name][i]):
            parks_pivot['parks_nearest'][name][i] = parks_pivot_all['parks_nearest'][i]

# %% [markdown]
# Теперь занесём полученные результаты в таблицу

# %%
for name in data['locality_name'].unique():
    for i in data['parks_around3000'].unique():
        data.loc[(data['locality_name'] == name) & (data['parks_around3000'] == i), 'parks_nearest'] = \
        data.loc[(data['locality_name'] == name) & (data['parks_around3000'] == i), 'parks_nearest'] \
        .fillna(parks_pivot['parks_nearest'][name][i])

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Для красоты («продаваемости») всего проекта не стоит выходить за видимую ширину тетради юпитер ноутбука, коллеги ценят удобство прочтения кода. Широкие строки кода рекомендуется — делить <a href="https://qastack.ru/programming/53162/how-can-i-do-a-line-break-line-continuation-in-python">Перенос длинных строк кода</a>.
#
# </div>

# %% [markdown]
# Посчитаем количество пропущенных значений

# %%
data['parks_nearest'].isna().sum()
# Out:
# 0

# %% [markdown]
# Заполним значения для ponds_nearest аналогично park_nearest. Здесь нет значений ponds_nearest если ponds_around3000 = 0, поэтому заполним его значением 3001

# %%
ponds_pivot = data.pivot_table(index=['locality_name', 'ponds_around3000'], values='ponds_nearest', aggfunc='median', dropna=False)

# %%
ponds_pivot_all = data.pivot_table(index='ponds_around3000', values='ponds_nearest', aggfunc='median')

# %%
for name in data['locality_name'].unique():
    for i in data['ponds_around3000'].unique():
        if np.isnan(ponds_pivot['ponds_nearest'][name][i]):
            if i == 0:
                ponds_pivot['ponds_nearest'][name][i] = 3001
            else:
                ponds_pivot['ponds_nearest'][name][i] = ponds_pivot_all['ponds_nearest'][i]

# %%
for name in data['locality_name'].unique():
    for i in data['ponds_around3000'].unique():
        data.loc[(data['locality_name'] == name) & (data['ponds_around3000'] == i), 'ponds_nearest'] = \
        data.loc[(data['locality_name'] == name) & (data['ponds_around3000'] == i), 'ponds_nearest'] \
        .fillna(ponds_pivot['ponds_nearest'][name][i])

# %% [markdown]
# Посчитаем количество пропущенных значений

# %%
data['ponds_nearest'].isna().sum()
# Out:
# 0

# %% [markdown]
# Рассмотрим столбцы ceiling_height, living_area и kitchen_area. Всего пустых значений достаточно чтобы они повлияли на результат исследования, поэтому пропущенные значения следует заменить медианным значением по населённому пункту.

# %% [markdown]
# Рассмотрим столбцы living_area и kitchen_area. Однозначно определить пропуски в этих данных сложно, поэтому нужно строить логические выводы для каждого случая. Для начала пропуски в столбце kitchen_area заменим на 0 если квартира является квартирой-студией.

# %%
data['kitchen_area'].isna().sum()
# Out:
# 2269

# %%
data.loc[(data['studio'] == True) & (data['kitchen_area'].isna())]['kitchen_area'] = 0
# Out:
# /tmp/ipykernel_123/513751164.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[(data['studio'] == True) & (data['kitchen_area'].isna())]['kitchen_area'] = 0

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Мы с тобой открыли интересную особенность loc — присвоение значений, когда не выбрана колонка ...
#
#         data.loc[(data['studio'] == True) & (data['kitchen_area'].isna())] = 0
#
# кодом мы заполняем все колонки записей, где выполняются условия
#
#         (data['studio'] == True) & (data['kitchen_area'].isna())
#
# на нули, даже там, где до этого были записи
#
#
# порядок применения loc
#
# https://tonais.ru/library/zamena-odnogo-ili-neskolkih-znacheniy-v-stolbtse-v-dataframe?ysclid=l5jjs9blfj495302948

# %% [markdown]
# ##### check loc

# %%
# check
import matplotlib.pyplot as plt

# %%
# check
data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter',
        y='living_area' , x='total_area', alpha=0.5, subplots=True, figsize=(15,8), c = 'black', s = 4)
plt.title('Диаграмма рассеяния — Общая площадь — Жилая');

# %%
# check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23650 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23650 non-null  int64
#  1   last_price            23650 non-null  float64
#  2   total_area            23650 non-null  float64
#  3   first_day_exposition  23650 non-null  object
#  4   rooms                 23650 non-null  int64
#  5   ceiling_height        14490 non-null  float64
#  6   floors_total          23565 non-null  float64
#  7   living_area           21752 non-null  float64
#  8   floor                 23650 non-null  int64
#  9   is_apartment          23650 non-null  bool
#  10  studio                23650 non-null  bool
#  11  open_plan             23650 non-null  bool
#  12  kitchen_area          21381 non-null  float64
#  13  balcony               23650 non-null  int64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# ##### check

# %%
# check
data[data['kitchen_area'].isna() == True][:4]
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 3              0  64900000.0       159.0  2015-07-24T00:00:00      3
# 30            12   2200000.0        32.8  2018-02-19T00:00:00      1
# 37            10   1990000.0        45.8  2017-10-28T00:00:00      2
# 44            13   5350000.0        40.0  2018-11-18T00:00:00      1
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 3              NaN          14.0          NaN      9         False  ...
# 30             NaN           9.0          NaN      2         False  ...
# 37             2.5           5.0          NaN      1         False  ...
# 44             NaN          22.0          NaN      3         False  ...
#
#     kitchen_area  balcony    locality_name  airports_nearest  \
# 3            NaN        0  Санкт-Петербург           28098.0
# 30           NaN        0         Коммунар               NaN
# 37           NaN        0      Красный Бор               NaN
# ...

# %%
data['kitchen_area'].isna().sum()
# Out:
# 2269

# %% [markdown]
# Заполним пустые значения площади жилой зоны как разницу между значением всей площади и площади кухни, для чего введём новый слотбец, куда будем записывать новые значения.

# %% [markdown]
# <div class="alert alert-dange r">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />После заполнения синтетическими данными столбцов, стоит провести проверку в новых колонках
#
#         ..._area_new
#
# на корректность значений всех наших площадей, т.к. есть коридоры, сан.узлы, балконы — на них отводим условные 10% площади
#
#         total_area*0.9 <= (living_area + kitchen_area)
#
# если алгоритм заполнения пропусков приводит к появлению аномалий, стоит подумать над его содержимым
#
#     Для решения задачи можно использовать запросы с query

# %% [markdown]
# Избавиться от пропусков в колонках с площадями является сложной задачей, следовательно нужно оставить всё как есть (неудачные попытки избавления от дубликатов я закомментировал)

# %%
#data['living_area_new'] = data['living_area']
#data['kitchen_area_new'] = data['kitchen_area']

# %%
#kichen_pivot = data.pivot_table(index='locality_name', values='kitchen_area', aggfunc='median', dropna=False)

# %%
#kichen_pivot.isna().sum()

# %%
#kichen_pivot = kichen_pivot.fillna(data['kitchen_area'].median())

# %%
#kichen_pivot.isna().sum()

# %%
#data['living_area'].corr(data['total_area'])

# %%
#data['living_area'].corr(data['rooms'])

# %%
#kichen_pivot['kitchen_area']['Агалатово']

# %%
#for name in data['locality_name'].unique():
#    data.loc[data['locality_name'] == name, 'kitchen_area_new'] = \
#    data.loc[data['locality_name'] == name, 'kitchen_area_new'].fillna(kichen_pivot['kitchen_area'][name])

# %%
#data['kitchen_area_new'].isna().sum()

# %% [markdown]
# Пропуски в столбце living_area не получится заменить на медианные. Для решения этой задачи можно воспользоваться методом наименьших квадратов, так как total_area линейно зависит от living_area, то есть зависимость выражается в виде $y(x)=kx+b$. Найти $k$ и $b$ можно с помощью метода наименьших квадратов,
# $$
# k=\frac{\alpha_{1,1}-m_xm_y}{\alpha_2-(m_x)^2}, \ b=y_m - kx_m
# $$
#
# где
#
# $$
# \alpha_{1,1} = \frac{1}{N} \sum\limits_i^N y_i x_i, \ \alpha_2 = \frac{1}{N} \sum\limits_i^N x_i^2
# $$
#
# $$
# m_x = \frac{1}{N} \sum\limits_i^N x_i, \ m_y = \frac{1}{N} \sum\limits_i^N y_i,
# $$
# где $N$ - число измерений.
#
# Однако так как надо будет искать среднее на результат могут повлиять аномальные значения.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Здесь я попытался найти зависимость жилой площади от общей площади с помощью метода наименьших квадратов, но суть не совсем в этом. Я создал столбец total_approx как приближение жилой площади через общую и захотел поменять пропуский в жилой площади по этому приближению. Сначала я попытался заменить пропуски с помощью
# data.loc[data['living_area'].isna(), 'living_area'] = data.loc[data['living_area'].isna(), 'total_approx'],
# но у меня ничего не получилось. Потом я заполнил методом fillna все пустые значения на -1 и ввёл функцию new_living_area чтобы заменить все значения с -1 на новые, но опять ничего не вышло. В последний раз я воспользовался методом np.where где заменил значения на другое из другого столбца, но опять ничего не получилось. Каждый раз методом new_data['living_area'].isna().sum() у меня показывало что некоторые строки оказались пустыми. Мой вопрос: стоит ли заменить пропущенные значения living_area методом который я выбрал или так и оставить, и если изменить, то как?

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Подсказки после окончания заполнения пропусков

# %% [markdown]
# Построим сводную таблицу жилой площади по комнатам.

# %%
#total_area_pivot = data.pivot_table(index='rooms', values='total_area', aggfunc=['count','median'])
#total_area_pivot

# %% [markdown]
# До 9 комнат медиана растёт, после чего начинает вести себя непредсказуемо. Всего квартир с 10 комнатами и выше сравнительно мало, следовательно их можно отбросить. Также мало квартир с 0 комнатами, значит избавимся и от них.

# %%
#data = data.query('0 < rooms < 10')

# %%
#data['living_area'].hist(bins=50)

# %%
#new_data = data

# %%
# check
#data[data['kitchen_area'].isna() == True][:4]

# %%
#for i in new_data['rooms'].unique():
#    new_data.loc[new_data['rooms'] == i] = \
#    new_data.loc[(new_data['rooms'] == i) & (new_data['living_area'] <= new_data['living_area'].describe()[6])]
    #data.query('rooms == @i and living_area <= @data.loc[@data["rooms"] == @i, "living_area"].describe()[6]')

# %%
# check
data[data['kitchen_area'].isna() == True][:4]
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 3              0  64900000.0       159.0  2015-07-24T00:00:00      3
# 30            12   2200000.0        32.8  2018-02-19T00:00:00      1
# 37            10   1990000.0        45.8  2017-10-28T00:00:00      2
# 44            13   5350000.0        40.0  2018-11-18T00:00:00      1
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 3              NaN          14.0          NaN      9         False  ...
# 30             NaN           9.0          NaN      2         False  ...
# 37             2.5           5.0          NaN      1         False  ...
# 44             NaN          22.0          NaN      3         False  ...
#
#     kitchen_area  balcony    locality_name  airports_nearest  \
# 3            NaN        0  Санкт-Петербург           28098.0
# 30           NaN        0         Коммунар               NaN
# 37           NaN        0      Красный Бор               NaN
# ...

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Мы с тобой закрепили интересную особенность loc — присвоение значений, когда не выбрана колонка ...
#
#         new_data.loc[new_data['rooms'] == i] = \
#             new_data.loc[(new_data['rooms'] == i) & (new_data['living_area'] <= new_data['living_area'].describe()[6])]
#
# кодом мы заполняем все колонки записей, где выполняются условия
#
#         new_data.loc[new_data['rooms'] == i]
#
# на пропуски, даже там, где до этого были записи
#
#
# порядок применения loc
#
# https://tonais.ru/library/zamena-odnogo-ili-neskolkih-znacheniy-v-stolbtse-v-dataframe?ysclid=l5jjs9blfj495302948

# %% [markdown]
# ##### check

# %%
# check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23650 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23650 non-null  int64
#  1   last_price            23650 non-null  float64
#  2   total_area            23650 non-null  float64
#  3   first_day_exposition  23650 non-null  object
#  4   rooms                 23650 non-null  int64
#  5   ceiling_height        14490 non-null  float64
#  6   floors_total          23565 non-null  float64
#  7   living_area           21752 non-null  float64
#  8   floor                 23650 non-null  int64
#  9   is_apartment          23650 non-null  bool
#  10  studio                23650 non-null  bool
#  11  open_plan             23650 non-null  bool
#  12  kitchen_area          21381 non-null  float64
#  13  balcony               23650 non-null  int64
#  14  locality_name         23650 non-null  object
# ...

# %%
#def return_k_b(x,y):
#    k = ((x * y).sum() / len(x) - x.mean() * y.mean()) / ((x ** 2).sum() / len(x) - (x.mean()) ** 2)
#    return [k, y.mean() - x.mean() * k]

# %%
#[k, b] = return_k_b(new_data.loc[data['living_area'].isna() == False, 'total_area'], new_data['living_area'])

# %%
#[k, b]

# %%
#new_data['total_area'].hist(bins=50)

# %%
#new_data['total_approx'] = new_data['total_area'] * k + b

# %%
#new_data['living_area'] = new_data['living_area'].fillna(-1)

# %%
#new_data['living_area'].isna().sum()

# %%
#def new_living_area(data):
#    if data['living_area'] == -1:
#        return data['total_approx']
#    return data['living_area']

# %%
#new_data['living_area'] = new_data.apply(new_living_area, axis=1)

# %%
#new_data['living_area'].isna().sum()

# %%
#new_data['living_area']

# %%
#new_data['living_area'] = new_data['living_area'].fillna(-1)

# %%
#new_data['living_area'].isna().sum()

# %%
#new_data['living_area_new'] = np.where(new_data['living_area'] == -1, new_data['total_approx'], new_data['living_area'])

# %%
#new_data['living_area_new'].isna().sum()

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> ... , вот мой вопрос ...

# %%
#new_data.query('total_area * 0.9 <= living_area_new + kitchen_area_new')

# %%
#len(data)

# %%
#data.query('total_area * 0.9 <= living_area_new + kitchen_area_new')

# %%
#len(data.loc[data['living_area'].isna() == False, 'living_area'])

# %%
#len(data.loc[data['living_area'].isna(), 'living_area'])

# %%
#len(data['living_area_new'])

# %%
#data.query('total_area * 0.9 <= living_area + kitchen_area')

# %%
#new_data = data.query('total_area * 0.9 > living_area_new + kitchen_area_new')

# %%
#len(data.query('total_area * 0.9 > living_area_new + kitchen_area_new'))

# %%
#len(data.query('total_area * 0.9 < living_area_new + kitchen_area_new'))

# %%
#data['living_area_new'].isna().sum()

# %%
#len(data)

# %%
#len(new_data)

# %%
#data['living_area_new'].hist(bins=50)

# %%
#data['living_area_new'].describe()

# %%
#data.loc[data['rooms'] == 7, 'living_area_new'].describe()

# %%
#data.loc[data['living_area_new'] >= 40.159280].count()

# %%
#new_data['living_area_new'].hist(bins=50)

# %%
#data.loc[data['living_area_new'] < 0, 'living_area_new'].count()

# %%
#data['total_approx']

# %% [markdown]
# ##### check living area

# %%
# check
data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter',
        y='living_area' , x='total_area', alpha=0.5, subplots=True, figsize=(15,8), c = 'black', s = 4)
plt.title('Диаграмма рассеяния — Общая площадь — Жилая');

# %%
# check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23650 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23650 non-null  int64
#  1   last_price            23650 non-null  float64
#  2   total_area            23650 non-null  float64
#  3   first_day_exposition  23650 non-null  object
#  4   rooms                 23650 non-null  int64
#  5   ceiling_height        14490 non-null  float64
#  6   floors_total          23565 non-null  float64
#  7   living_area           21752 non-null  float64
#  8   floor                 23650 non-null  int64
#  9   is_apartment          23650 non-null  bool
#  10  studio                23650 non-null  bool
#  11  open_plan             23650 non-null  bool
#  12  kitchen_area          21381 non-null  float64
#  13  balcony               23650 non-null  int64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Мы исказили всю выборку, заполнили пропусками 8000 записей, исказили значения жилой площади, стоит вернуть пропуски и закомментировать весь код, связанный с заполнением пропусков в любой из трех колонок площадей.
#
# Стоит отменить все манипуляции с данными — исправление или изменение площадей, если квартира вызывает подозрение на аномалию она просто удаляется, или если квартира входит в элитный сегмент она также удаляется
#
# Далее проверку проводить не имеет смысла, т.к. весь набор данных искажен.
#
# Стоит вернуть исходное состояние и исправить текущие комментарии
#
#
# Выборка была такая ⬇⬇⬇
#
# ![image.png](attachment:image.png)
#
# стала такой
#
# ![image-2.png](attachment:image-2.png)
#
# для корректного заполнения пропусков стоит использовать возможности функции transform() и предварительную группировку — оптимальнее это делать после сдачи проекта, чтобы уложиться в сроки

# %% [markdown]
# Рассмотрим столбец ceiling_height. Пропущенные значения можно заменить медианой по городу, для чего построим сводную таблицу

# %%
ceiling_pivot = data.pivot_table(index='locality_name', values='ceiling_height', aggfunc='median', dropna=False)

# %%
ceiling_pivot.isna().sum()
# Out:
# ceiling_height    64
# dtype: int64

# %% [markdown]
# Заменим недостающие значения по городу медианой в целом.

# %%
ceiling_pivot = ceiling_pivot.fillna(data['ceiling_height'].median())

# %%
ceiling_pivot[:2]
# Out:
#                  ceiling_height
# locality_name
# Агалатово                  2.60
# Александровская            2.77

# %% [markdown]
# Заменим пропуски во всех населённых пунктах кроме Санкт-Петербурга, так как высота потолков варьируется относительно центра города.

# %%
for name in data['locality_name'].unique()[1:]:
    data.loc[(data['ceiling_height'].isna()) & (data['locality_name'] == name), 'ceiling_height'] = ceiling_pivot['ceiling_height'][name]

# %%
# check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23650 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23650 non-null  int64
#  1   last_price            23650 non-null  float64
#  2   total_area            23650 non-null  float64
#  3   first_day_exposition  23650 non-null  object
#  4   rooms                 23650 non-null  int64
#  5   ceiling_height        18033 non-null  float64
#  6   floors_total          23565 non-null  float64
#  7   living_area           21752 non-null  float64
#  8   floor                 23650 non-null  int64
#  9   is_apartment          23650 non-null  bool
#  10  studio                23650 non-null  bool
#  11  open_plan             23650 non-null  bool
#  12  kitchen_area          21381 non-null  float64
#  13  balcony               23650 non-null  int64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Код не работает из-за 8000 пропусков
#
#         for name in data['locality_name'].unique():
#             data.loc[(data['ceiling_height'].isna()) & (data['locality_name'] == name), 'ceiling_height'] = ceiling_pivot['ceiling_height'][name]

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит учитывать физическое распределение данных, в разных районах Питера высота потолков разная
#
# ... если рассмотреть районность высоты потолков, т.к. в современных районах Питера высота потолков будет ожидаема ниже, чем в исторических, мы увидим, что заполнение подобного объема пропусков медианой или средним значением «размажет» это отличительное свойство объектов недвижимости в центре Питера
#
# [Обработка пропусков в данных](https://loginom.ru/blog/missing)

# %% [markdown]
# Рассмотрим столбец floors_total. Всего ненулевых значений 85, этого мало относительно таблицы, так что их можно удалить

# %% [markdown]
# <div style>
# <font size="4"><b></b></font>
# <font size="5", color = "black">
# 🤝

# %%
data['floors_total'].isna().sum()
# Out:
# 85

# %%
data = data.dropna(subset=['floors_total'])
data['floors_total'].isna().sum()
# Out:
# 0

# %%
data.isna().sum()
# Out:
# total_images               0
# last_price                 0
# total_area                 0
# first_day_exposition       0
# rooms                      0
# ceiling_height          5555
# floors_total               0
# living_area             1865
# floor                      0
# is_apartment               0
# studio                     0
# open_plan                  0
# kitchen_area            2222
# balcony                    0
# locality_name              0
# airports_nearest        5524
# cityCenters_nearest     5501
# parks_around3000           0
# parks_nearest              0
# ponds_around3000           0
# ponds_nearest              0
# days_exposition         3171
# dtype: int64

# %% [markdown]
# В столбцах cityCenters_nearest и airports_nearest нельзя однозначно установить расстояние до центра города или аэропорта, поэтому пропуски придётся оставить (все попытки до этого я закомментировал).

# %%
#airports_centers_pivot = data.pivot_table(index='locality_name', values=['airports_nearest', 'cityCenters_nearest'], aggfunc='median', dropna=False)

# %% [markdown]
# В таблице 280 незаполненных значений, заполним их медианой в целом.

# %%
#for name in data['locality_name'].unique():
#    if np.isnan(airports_centers_pivot['airports_nearest'][name]):
#        airports_centers_pivot['airports_nearest'][name] = data['airports_nearest'].median()

# %%
#for name in data['locality_name'].unique():
#    if np.isnan(airports_centers_pivot['cityCenters_nearest'][name]):
#        airports_centers_pivot['cityCenters_nearest'][name] = data['cityCenters_nearest'].median()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  float64
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  object
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        18010 non-null  float64
#  6   floors_total          23565 non-null  float64
#  7   living_area           21700 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          23565 non-null  bool
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          21343 non-null  float64
#  13  balcony               23565 non-null  int64
#  14  locality_name         23565 non-null  object
# ...

# %%
#for name in data['locality_name'].unique():
#    data.loc[data['locality_name'] == name, 'airports_nearest'] = \
#    data.loc[data['locality_name'] == name, 'airports_nearest'].fillna(airports_centers_pivot['airports_nearest'][name])
#    data.loc[data['locality_name'] == name, 'cityCenters_nearest'] = \
#    data.loc[data['locality_name'] == name, 'cityCenters_nearest'].fillna(airports_centers_pivot['cityCenters_nearest'][name])

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Мы искажаем расстояния до центра и до аэропорта для 300-т населенных пунктов, которые раскиданы по всей Ленинградской области, а мы им проставляем одно и тоже медианное значение
#
#         ...
#
#         for name in data['locality_name'].unique():
#             data.loc[data['locality_name'] == name, 'airports_nearest'] = \
#             data.loc[data['locality_name'] == name, 'airports_nearest'].fillna(airports_centers_pivot['airports_nearest'][name])
#             data.loc[data['locality_name'] == name, 'cityCenters_nearest'] = \
#             data.loc[data['locality_name'] == name, 'cityCenters_nearest'].fillna(airports_centers_pivot['cityCenters_nearest'][name])

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Не изучено распределение пропусков по городам до заполнения значений в ['city_сenters_nearest']
#
# к каким населенным пунктам относятся пропуски и самое важное — нет оценки степени влияния пропусков на дальнейший анализ (будут мешать выполнить проект или нет )

# %%
data.isna().sum()
# Out:
# total_images               0
# last_price                 0
# total_area                 0
# first_day_exposition       0
# rooms                      0
# ceiling_height          5555
# floors_total               0
# living_area             1865
# floor                      0
# is_apartment               0
# studio                     0
# open_plan                  0
# kitchen_area            2222
# balcony                    0
# locality_name              0
# airports_nearest        5524
# cityCenters_nearest     5501
# parks_around3000           0
# parks_nearest              0
# ponds_around3000           0
# ponds_nearest              0
# days_exposition         3171
# dtype: int64

# %% [markdown]
# Остался только столбец days_exposition. Его не получится заменить медианным значением, так как дата может быть какой угодно

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Все верно, эти квартиры еще не проданы
#
#         Его не получится заменить медианным значением, так как дата может быть какой угодно

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Скажи пожалуйста, какое преимущество ты получаешь от заполнения пропусков на этом проекте, с этой главной задачей?
#
#         В вашем распоряжении данные сервиса Яндекс Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — провести исследовательский анализ данных, который поможет установить параметры, влияющие на цену объектов.

# %% [markdown]
# Преимущество от заполнения пропусков состоит в том что я учусь заполнять очевидные пропуски и понимаю как устроен рынок продажи квартир, что в дальнейшем скажется на моём опыте.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Если заполнять пропуски с целью научиться манипулировать данными (в хорошем смысле), то стоит создавать дубликаты колонок, чтобы можно было проверить качество заполнения пропусков
#
# На этом проекте с текущей главной задачей от самой процедуры заполнения пропусков мы преимуществ не получаем

# %%
# check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  float64
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  object
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        18010 non-null  float64
#  6   floors_total          23565 non-null  float64
#  7   living_area           21700 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          23565 non-null  bool
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          21343 non-null  float64
#  13  balcony               23565 non-null  int64
#  14  locality_name         23565 non-null  object
# ...

# %% [markdown]
# ### Добавьте в таблицу новые столбцы

# %% [markdown]
# Посчитаем цену одного квадратного метра.

# %%
data['one_meter_price'] = data['last_price'] / data['total_area']

# %%
data['one_meter_price']
# Out:
# 0        120370.370370
# 1         82920.792079
# 2         92785.714286
# 3        408176.100629
# 4        100000.000000
#              ...
# 23694     72490.845228
# 23695     52542.372881
# 23696     44091.710758
# 23697    149511.400651
# 23698     41795.665635
# Name: one_meter_price, Length: 23565, dtype: float64

# %%
data['one_meter_price'] = round(data['one_meter_price'], 2)

# %%
data['one_meter_price'].isna().sum()
# Out:
# 0

# %%
data['first_day_exposition_new'] = pd.to_datetime(data["first_day_exposition"], errors='coerce',utc=False)

# %%
data['first_day_exposition_new'].dt.weekday
# Out:
# 0        3
# 1        1
# 2        3
# 3        4
# 4        1
#         ..
# 23694    1
# 23695    0
# 23696    6
# 23697    1
# 23698    4
# Name: first_day_exposition_new, Length: 23565, dtype: int64

# %% [markdown]
# Найдём день публикации

# %%
data['week_day'] = data['first_day_exposition_new'].dt.weekday

# %% [markdown]
# Найдём месяц публикации

# %%
data['month'] = data['first_day_exposition_new'].dt.month

# %% [markdown]
# Найдём год публикации

# %%
data['year'] = data['first_day_exposition_new'].dt.year

# %% [markdown]
# Определим тип этажа, для чего введём вспомогательную функцию.

# %%
def floor_tipe(data):
    if data['floor'] <= 0:
        return 'некорректный тип'
    if data['floor'] == 1:
        return 'первый'
    if data['floor'] == data['floors_total']:
        return 'последний'
    return 'другой'

# %%
data['floor_type'] = data.apply(floor_tipe, axis=1)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Функция хорошая, стоит учесть крайние условия: возможные нулевые и отрицательные значения

# %% [markdown]
# Найдём расстояние до центра в километрах.

# %%
data['cityCenters_nearest_km'] = round(data['cityCenters_nearest'] / 1000)

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> данные добавлены корректно, молодец

# %%
# check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23698
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   total_images              23565 non-null  int64
#  1   last_price                23565 non-null  float64
#  2   total_area                23565 non-null  float64
#  3   first_day_exposition      23565 non-null  object
#  4   rooms                     23565 non-null  int64
#  5   ceiling_height            18010 non-null  float64
#  6   floors_total              23565 non-null  float64
#  7   living_area               21700 non-null  float64
#  8   floor                     23565 non-null  int64
#  9   is_apartment              23565 non-null  bool
#  10  studio                    23565 non-null  bool
#  11  open_plan                 23565 non-null  bool
#  12  kitchen_area              21343 non-null  float64
# ...

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# #### Изучение параметров объектов и построение гистограмм

# %% [markdown]
# Построем гистограмму общей площади.

# %%
ax = data['total_area'].hist(
    bins=100, 
    figsize=(12,7),
    grid=True
)
ax.set_xlabel('Общая площадь')
ax.set_ylabel('Количество предложений');

# %% [markdown]
# В данных встречаются аномальные значения, попробуем их обработать. Найдём медианные значения жилой площади относительно количества комнат, для чего построим сводную таблицу.

# %%
total_area_pivot = data.pivot_table(index='rooms', values='total_area', aggfunc=['count','median'])

# %%
total_area_pivot
# Out:
#            count     median
#       total_area total_area
# rooms
# 0            194     26.075
# 1           8004     36.600
# 2           7897     53.000
# 3           5779     72.800
# 4           1172     99.300
# 5            325    146.000
# 6            104    186.150
# 7             59    214.000
# 8             12    235.700
# 9              8    300.950
# 10             3    272.600
# 11             2    188.900
# 12             1    900.000
# 14             2    304.200
# 15             1    590.000
# 16             1    270.000
# 19             1    374.600

# %% [markdown]
# Больше всего квартир находятся в промежутке от 1 до 6 комнат, можно избавиться от части аномалий если рассмотреть только квартиры в этом промежутке.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Нет таблицы для этого вывода
#
#         Видно, что до 9 комнат общая площадь растёт, после чего ведёт себя непредсказуемо. Квартир с количетсвом комнат больше 9 мало, следовательно их можно отбросить. Также мало значений с 0 комнат, их тоже можно отбросить.

# %%
new_data = data

# %%
new_data_2 = new_data

# %%
new_data = new_data.loc[((new_data['rooms'] > 0) & (new_data['rooms'] < 9)) | \
               ((new_data['rooms'] > 0) & (new_data['rooms'] < 9) & (new_data.isnull().any(axis=1)))]

# %%
len(new_data)
# Out:
# 23352

# %%
len(new_data.loc[(data['rooms'] > 0) & (data['rooms'] < 9) | (data['rooms'].isna())])
# Out:
# 23352

# %%
new_data = new_data.loc[(data['rooms'] > 0) & (data['rooms'] < 9) | (data['rooms'].isna())]

# %%
len(new_data)
# Out:
# 23352

# %% [markdown]
# Рассмотрим гистограмму для новых значений

# %%
ax = new_data['total_area'].hist(
    bins=100, 
    figsize=(12,7),
    grid=True
)
ax.set_xlabel('Общая площадь')
ax.set_ylabel('Количество предложений');

# %% [markdown]
# Найдём квартили для данного столбца

# %%
new_data['total_area'].describe()
# Out:
# count    23352.000000
# mean        60.357641
# std         34.455187
# min         12.000000
# 25%         40.117500
# 50%         52.000000
# 75%         70.000000
# max        631.200000
# Name: total_area, dtype: float64

# %% [markdown]
# Третий квартиль равен 70 $м^2$, однако хвост доходит до 250, следовательно можно отбросить все значения больше 250.

# %%
len(new_data.loc[(new_data['total_area'] <= 150) | (new_data['total_area'].isna())])
# Out:
# 22811

# %%
new_data = new_data.loc[(new_data['total_area'] <= 150) | (new_data['total_area'].isna())]

# %% [markdown]
# Построим гистограмму по новым данным.

# %%
ax = new_data['total_area'].hist(
    bins=100, 
    figsize=(12,7),
    grid=True
)
ax.set_xlabel('Общая площадь')
ax.set_ylabel('Количество предложений');

# %% [markdown]
# Гистограмма показывает, что больше всего предложений с площадью около 35 $м^2$, основная масса квартир находится в промежутке от 0 до 100 $м^2$

# %%
# check
new_data.shape[0]
# Out:
# 22811

# %% [markdown]
# ##### check

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Слишком жесткое условие для фильтрации выборки
#
#         new_data = data.loc[(data['rooms'] == 1) & (data['total_area'] - 5 <= total_area_pivot['median'][1]) & (data['total_area'] + 15 >= total_area_pivot['median'][1])]
#
#         for i in data['rooms'].unique():
#             if i == 1:
#                 continue
#             new_data_i = data.loc[(data['rooms'] == i) & (data['total_area'] - 25 <= total_area_pivot['median'][i]) & (data['total_area'] + 25 >= total_area_pivot['median'][i])]
#             new_data = pd.concat([new_data, new_data_i])
#
#
# __Если при фильтрации одной колонки, на этом проекте, теряем больше одного процента данных от изначального объема, стоит еще раз пересмотреть условия фильтрации__

# %% [markdown]
# Построем гистограмму для новой таблицы.

# %% [markdown]
# В данных встречаются аномальные значения, попробуем их обработать. Найдём медианные значения жилой площади относительно количества комнат, для чего построим сводную таблицу.

# %% [markdown]
# Построим гистограмму для жилой площади и избавимся от аномалий аналогичной действиям выше.

# %%
ax = new_data['living_area'].hist(
    bins=100, 
    figsize=(12,7),
    grid=True
)
ax.set_xlabel('Жилая площадь')
ax.set_ylabel('Количество предложений');

# %%
new_data['living_area'].describe()
# Out:
# count    21023.000000
# mean        32.448936
# std         15.427310
# min          2.000000
# 25%         18.600000
# 50%         30.000000
# 75%         41.800000
# max        128.000000
# Name: living_area, dtype: float64

# %% [markdown]
# ##### check nan

# %%
# check
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22811 entries, 0 to 23698
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   total_images              22811 non-null  int64
#  1   last_price                22811 non-null  float64
#  2   total_area                22811 non-null  float64
#  3   first_day_exposition      22811 non-null  object
#  4   rooms                     22811 non-null  int64
#  5   ceiling_height            17474 non-null  float64
#  6   floors_total              22811 non-null  float64
#  7   living_area               21023 non-null  float64
#  8   floor                     22811 non-null  int64
#  9   is_apartment              22811 non-null  bool
#  10  studio                    22811 non-null  bool
#  11  open_plan                 22811 non-null  bool
#  12  kitchen_area              20850 non-null  float64
# ...

# %%
# new_data = new_data.loc[((data['living_area'] >= 0) & (new_data['living_area'] <= 150)) | \
#                ((new_data['living_area'] >= 0) & (new_data['living_area'] <= 150) & (new_data.isnull().any(axis=1)))]

# %%
len(new_data.loc[(new_data['living_area'] <= 100) | (new_data['living_area'].isna())])
# Out:
# 22780

# %%
new_data = new_data.loc[(new_data['living_area'] <= 100) | (new_data['living_area'].isna())]

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит поправить код, он не сохраняет пропуски в колонке жилой площади, подсказка в разделе → check gap
#
#         new_data = new_data.loc[((data['living_area'] >= 0) & (new_data['living_area'] <= 150)) | \
#                ((new_data['living_area'] >= 0) & (new_data['living_area'] <= 150) & (new_data.isnull().any(axis=1)))]
#
# твой код закомментировал, скриншот с моего примера
#
# ![image.png](attachment:image.png)

# %%
# check
new_data.shape[0]
# Out:
# 22780

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#         data = data.query('0 <= living_area <= 100')
#
# Так мы познакомились с особенностью фильтрации в библиотеке пандас, все NaN убегают вместе со значениями, которые не подходят под нашу фильтрацию, поэтому процент потери записей огромен
#
# Минус 2 000 записей только из-за пропусков
#
# стоит настроить условия фильтрации, чтобы не потерять записи с пропусками
#
# <b>алгоритм фильтрации столбца с пропусками: задаем основное условие фильтрации, + прибавляем условие не трогать записи с пропусками</b>
#
# стоит обратить внимание на весь код фильтрации, т.к. в нескольких колонках встречаются пропуски
#
# Примеры, в которых учитываются пропуски в записях
#
#
# [How to Select Rows with NaN](https://www.statology.org/pandas-select-rows-with-nan/)
#
# Чтобы сохранить записи с пропусками можно воспользоваться функцией drop
#
# [Пример с drop](https://ru.stackoverflow.com/questions/1286043/%D0%9A%D0%B0%D0%BA-%D1%83%D0%B4%D0%B0%D0%BB%D0%B8%D1%82%D1%8C-%D1%81%D1%82%D1%80%D0%BE%D0%BA%D0%B8-%D0%BF%D0%BE-%D1%83%D1%81%D0%BB%D0%BE%D0%B2%D0%B8%D1%8E-%D1%81-%D0%BF%D0%BE%D0%BC%D0%BE%D1%89%D1%8C%D1%8E-%D0%BC%D0%B5%D1%82%D0%BE%D0%B4%D0%B0-drop?ysclid=loraaerc30529283559)

# %%
ax = new_data['living_area'].hist(
    bins=100, 
    figsize=(12,7),
    grid=True
)
ax.set_xlabel('Жилая площадь')
ax.set_ylabel('Количество предложений');

# %% [markdown]
# Гистограмма показывает, что больше всего предложений с жилой площадью около 20 $м^2$, имеется уменьшение количества предложений с площадью 22 $м^2$, после чего есть новый пик с площадью около 30 $м^2$, основная масса предложений находится в промежутке от 15 до 80 $м^2$

# %% [markdown]
# Построим гистограмму для площади кухни.

# %%
ax = new_data['kitchen_area'].hist(
    bins=100, 
    figsize=(12,7),
    grid=True
)
ax.set_xlabel('Площадь кухни')
ax.set_ylabel('Количество предложений');

# %%
new_data['kitchen_area'].describe()
# Out:
# count    20820.000000
# mean        10.193289
# std          4.963901
# min          1.300000
# 25%          7.000000
# 50%          9.000000
# 75%         11.600000
# max         93.000000
# Name: kitchen_area, dtype: float64

# %%
# new_data = new_data.loc[((new_data['kitchen_area'] >= 0) & (new_data['kitchen_area'] <= 80)) | \
#                ((new_data['kitchen_area'] >= 0) & (new_data['kitchen_area'] <= 80) & (new_data.isnull().any(axis=1)))]

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Все дело в логике фильтрации, пример в разделе check gap

# %%
len(new_data.loc[(new_data['kitchen_area'] <= 40) | (new_data['kitchen_area'].isna())])
# Out:
# 22712

# %%
new_data = new_data.loc[(new_data['kitchen_area'] <= 40) | (new_data['kitchen_area'].isna())]

# %%
ax = new_data['kitchen_area'].hist(
    bins=100, 
    figsize=(12,7),
    grid=True
)
ax.set_xlabel('Площадь кухни')
ax.set_ylabel('Количество предложений');

# %% [markdown]
# Гистограмма говорит о том, что большинство значений площади кухни имеют фиксированное значение. Больше всего предложений с площадью от 6 до 10 $м^2$, после чего имеется спад в промежутке от 11 до 15 $м^2$, меньше всего предложений начинается от площади больше 15 $м^2$

# %% [markdown]
# Построим гистограмму для цены объектов.

# %%
#new_data['one_meter_price'].hist(bins=50)

# %%
ax = new_data['one_meter_price'].hist(
    bins=100, 
    figsize=(12,7),
    grid=True
)
ax.set_xlabel('Цена за один квадратный метр')
ax.set_ylabel('Количество предложений');

# %%
new_data['one_meter_price'].describe()
# Out:
# count     22712.000000
# mean      97012.523076
# std       40572.114906
# min        7962.960000
# 25%       75978.840000
# 50%       94444.440000
# 75%      113054.537500
# max      995983.940000
# Name: one_meter_price, dtype: float64

# %% [markdown]
# Значений выше 200000 рублей скорее всего относятся к элитным жилым комплексам, для них нужно дополнительное исследование, отбросим всё до этого значения

# %%
len(new_data.loc[(new_data['one_meter_price'] <= 200000) | (new_data['one_meter_price'].isna())])
# Out:
# 22366

# %%
new_data = new_data.loc[(new_data['one_meter_price'] <= 200000) | (new_data['one_meter_price'].isna())]

# %%
ax = new_data['one_meter_price'].hist(
    bins=100, 
    figsize=(12,7),
    grid=True
)
ax.set_xlabel('Цена за один квадратный метр')
ax.set_ylabel('Количество предложений');

# %% [markdown]
# Аномальных значений сравнительно мало, отбросим всё что меньше 200000.

# %%
# check
#new_data.shape[0]

# %% [markdown]
# Видно, что пик цены около 100000 рублей.

# %% [markdown]
# Построим гистограмму для количетсва комнат.

# %%
ax = new_data['rooms'].hist(
    bins=100, 
    figsize=(12,7),
    grid=True
)
ax.set_xlabel('Количество комнат')
ax.set_ylabel('Количество предложений');

# %% [markdown]
# Гистограмма показывает, что большинство квартир однокомнатные и двухкомнатные, заметное снижение предложений с количеством комнат начинается с трёх.

# %% [markdown]
# Построим гистограмму для высоты потолков.

# %%
ax = new_data['ceiling_height'].hist(
    bins=100, 
    figsize=(12,7),
    grid=True
)
ax.set_xlabel('Высота потолков')
ax.set_ylabel('Количество предложений');

# %% [markdown]
# Аномальные значения выше 25 м скорее всего были умножены на 10, исправим это.

# %%
new_data.loc[new_data['ceiling_height'] >= 20, 'ceiling_height'] = \
new_data.loc[new_data['ceiling_height'] >= 20, 'ceiling_height'] /10

# %%
ax = new_data['ceiling_height'].hist(
    bins=100, 
    figsize=(12,7),
    grid=True
)
ax.set_xlabel('Высота потолков')
ax.set_ylabel('Количество предложений');

# %%
new_data['ceiling_height'].describe()
# Out:
# count    17171.000000
# mean         2.687401
# std          0.266352
# min          1.000000
# 25%          2.520000
# 50%          2.600000
# 75%          2.750000
# max         14.000000
# Name: ceiling_height, dtype: float64

# %%
len(new_data.loc[(new_data['ceiling_height'] <= 4) | (new_data['ceiling_height'].isna())])
# Out:
# 22333

# %%
new_data = new_data.loc[(new_data['ceiling_height'] <= 4) | (new_data['ceiling_height'].isna())]

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> что бы я не делал на данном этапе количество записей равно 20646, почему-то для фильтрации по потолкам значение резко падает до 15989, пока не буду трогать чтобы не исказить статистику

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Все дело в логике фильтрации, пример в разделе check gap
#
#         data = data.loc[(data['ceiling_height'] < 4) | \
#                ((data['ceiling_height'] < 4) & (data.isnull().any(axis=1)))]

# %% [markdown]
# Построим новую гистограмму

# %%
ax = new_data['ceiling_height'].hist(
    bins=100, 
    figsize=(12,7),
    grid=True
)
ax.set_xlabel('Высота потолков')
ax.set_ylabel('Количество предложений');

# %% [markdown]
# Гистограмма показывает, что у большинства предложений высота около 2,5 м, есть пик в 3 м, после чего значения становятся редкими.

# %% [markdown]
# Построим гистограмму для типа этажа квартиры.

# %%
ax = new_data['floor_type'].hist(
    bins=100, 
    figsize=(12,7),
    grid=True
)
ax.set_xlabel('Тип этажа')
ax.set_ylabel('Количество предложений');

# %% [markdown]
# Большинство предложений с типом этажа другой.

# %% [markdown]
# Построим гистограмму для общего количества этажей в доме.

# %%
ax = new_data['floors_total'].hist(
    bins=100, 
    figsize=(12,7),
    grid=True
)
ax.set_xlabel('Количество этажей')
ax.set_ylabel('Количество предложений');

# %% [markdown]
# Отбросим всё что ниже 35 этажей

# %%
len(new_data.loc[(new_data['floors_total'] <= 35) | (new_data['floors_total'].isna())])
# Out:
# 22327

# %%
new_data = new_data.loc[(new_data['floors_total'] <= 35) | (new_data['floors_total'].isna())]

# %% [markdown]
# Построим гистограмму для новых данных.

# %%
ax = new_data['floors_total'].hist(
    bins=100, 
    figsize=(12,7),
    grid=True
)
ax.set_xlabel('Количество этажей')
ax.set_ylabel('Количество предложений');

# %% [markdown]
# Большинство предложений с количеством этажей равным 5 и 9, после чего идёт спад.

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит изменить параметры отображения гистограммы (добавить кол-во корзин), сейчас  трудно определить типовую высотность зданий
#
#         Большинство предложений с количеством этажей равным 5 и 10, меньше всего примерно у 8 и 11.

# %% [markdown]
# Построим гистограмму для расстояния до центра.

# %%
ax = new_data['cityCenters_nearest_km'].hist(
    bins=100, 
    figsize=(12,7),
    grid=True
)
ax.set_xlabel('Расстояние до центра, км')
ax.set_ylabel('Количество предложений');

# %%
# check
#new_data.shape[0]

# %%
#new_data['cityCenters_nearest_km'].hist(bins=20)

# %% [markdown]
# Видно, что большинство предложений имеют расстояние от центра от 11 до 17 км, после чего идёт спад, но появляется новый пик на 30 км.

# %% [markdown]
# Построим гистограмму для расстояния до ближайшего парка.

# %%
#new_data['parks_nearest'].hist(bins=20)

# %%
ax = new_data['parks_nearest'].hist(
    bins=100, 
    figsize=(12,7),
    grid=True
)
ax.set_xlabel('Расстояние до парка')
ax.set_ylabel('Количество предложений');

# %% [markdown]
# Гистограмма показывает, что у большинства предложений расстояние больше 3 км. Рассмотрим расстояния в пределах трёх км.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Верное решение — при отрисовке графиков стоит временно исключать значения-заглушки, которыми мы заполнили пропуски, они мешают рассматривать реальную картину

# %%
ax = new_data['parks_nearest'].hist(
    bins=100, 
    figsize=(12,7),
    grid=True,
    range=(0,2999)
)
ax.set_xlabel('Расстояние до парка')
ax.set_ylabel('Количество предложений');

# %% [markdown]
# У большинства предложений расстояние около 500 м (не считая больше 3 км), однако об этом нельзя однозначно судить так как нет данных у 2/3 объявлений.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> В этой колонке нет данных у 2/3 объявлений, стоит поправить вывод
#
#         У большинства предложений расстояние около 500 м (не считая больше 3 км)

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит полностью отменить код, который вносит изменения в существующие данные — путем замены
#
# Оставляем только код фильтрации

# %% [markdown]
# #### check gap

# %%
# check
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22327 entries, 0 to 23698
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   total_images              22327 non-null  int64
#  1   last_price                22327 non-null  float64
#  2   total_area                22327 non-null  float64
#  3   first_day_exposition      22327 non-null  object
#  4   rooms                     22327 non-null  int64
#  5   ceiling_height            17133 non-null  float64
#  6   floors_total              22327 non-null  float64
#  7   living_area               20587 non-null  float64
#  8   floor                     22327 non-null  int64
#  9   is_apartment              22327 non-null  bool
#  10  studio                    22327 non-null  bool
#  11  open_plan                 22327 non-null  bool
#  12  kitchen_area              20413 non-null  float64
# ...

# %%
new_data['floors_total'] = new_data['floors_total'].astype('int')

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# стоит сменить тип данных в
#
#           6   floors_total              18671 non-null  float64

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __проверим какие аномалии остались__ таблица ниже

# %%
# check

# Показатели о кол-ве объявлений в датасете, минимальных и максимальных значениях 
# в выбранных параметрах о продаже квартир
# сырые данные

(
    new_data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
          'floor', 'floors_total']]
    .apply (['count', 'min', 'max', 'median']) #с помощью функции median я добавил медианное значение 
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_fc362_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fc362_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_fc362_row0_col0" class="data row0 col0" >22,327.00</td>
#                         <td id="T_fc362_row0_col1" class="data row0 col1" >22,327.00</td>
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />принимается, табличка стала твоей собственостью 🤝

# %%
# check
new_data.hist(column = 'days_exposition', bins = 50, figsize = (15,3), range = (0,5));

new_data.hist(column = 'days_exposition', bins = 50, figsize = (15,3), range = (0,5))
plt.ylim(0, 40);

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />остались аномалии и редкости (в т.ч. и хвосты) в колонках:
#
#          'ceiling_height', 'days_exposition',  'living_area',  'kitchen_area'
#
# для определения хвостов, редкостей и аномалий смотрим на минимальные и максимальные значения, строим несколько гистограмм по каждому параметру
#
# например в таблице мы видим аномалию квартиру с жилой площадью в 2 кв. метра, а на гистограмме редкую скорость продаж в один или два дня
#
# стоит учесть наличие пропусков при фильтрации данных

# %% [markdown]
# Отфильтруем слишком малые значения, квартили для некоторых столбцов есть выше.

# %%
len(new_data.loc[(new_data['ceiling_height'] >= 2) | (new_data['ceiling_height'].isna())])
# Out:
# 22325

# %%
new_data = new_data.loc[(new_data['ceiling_height'] >= 2) | (new_data['ceiling_height'].isna())]

# %%
len(new_data.loc[(new_data['living_area'] >= 10) | (new_data['living_area'].isna())])
# Out:
# 22304

# %%
new_data = new_data.loc[(new_data['living_area'] >= 10) | (new_data['living_area'].isna())]

# %%
new_data['days_exposition'].describe()
# Out:
# count    19423.000000
# mean       177.387633
# std        215.936851
# min          1.000000
# 25%         44.000000
# 50%         93.000000
# 75%        226.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
len(new_data.loc[(new_data['days_exposition'] >= 10) | (new_data['days_exposition'].isna())])
# Out:
# 21231

# %%
# check
new_data.hist(column = 'days_exposition', bins = 50, figsize = (15,3), range = (0,15));

# %%
new_data = new_data.loc[(new_data['days_exposition'] >= 10) | (new_data['days_exposition'].isna())]

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в5</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит поправить фильтрацию
#
#         (new_data['days_exposition'] >= 10)
#
# все значения о скорости продаж, начиная с третьего дня выглядят нормальными на гистограмме

# %%
len(new_data.loc[(new_data['kitchen_area'] >= 5) | (new_data['kitchen_area'].isna())])
# Out:
# 21137

# %%
new_data = new_data.loc[(new_data['kitchen_area'] >= 5) | (new_data['kitchen_area'].isna())]

# %%
len(new_data)
# Out:
# 21137

# %% [markdown]
# В отфильтрованных данных количество записей больше 21000

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> со столбцом days_exposition такая же ситуаця как и с ceiling_height

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />У тебя код фильтрации не работает, корректный пример ⬇⬇⬇

# %%
# check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23698
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   total_images              23565 non-null  int64
#  1   last_price                23565 non-null  float64
#  2   total_area                23565 non-null  float64
#  3   first_day_exposition      23565 non-null  object
#  4   rooms                     23565 non-null  int64
#  5   ceiling_height            18010 non-null  float64
#  6   floors_total              23565 non-null  float64
#  7   living_area               21700 non-null  float64
#  8   floor                     23565 non-null  int64
#  9   is_apartment              23565 non-null  bool
#  10  studio                    23565 non-null  bool
#  11  open_plan                 23565 non-null  bool
#  12  kitchen_area              21343 non-null  float64
# ...

# %%
# check
data.loc[(data['kitchen_area'] > 5) | ((data['kitchen_area'] > 5) & (data.isnull().any(axis=1)))].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20882 entries, 0 to 23698
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   total_images              20882 non-null  int64
#  1   last_price                20882 non-null  float64
#  2   total_area                20882 non-null  float64
#  3   first_day_exposition      20882 non-null  object
#  4   rooms                     20882 non-null  int64
#  5   ceiling_height            16148 non-null  float64
#  6   floors_total              20882 non-null  float64
#  7   living_area               20450 non-null  float64
#  8   floor                     20882 non-null  int64
#  9   is_apartment              20882 non-null  bool
#  10  studio                    20882 non-null  bool
#  11  open_plan                 20882 non-null  bool
#  12  kitchen_area              20882 non-null  float64
# ...

# %%
# check
data.loc[((data['kitchen_area'] >= 5) | (data['kitchen_area'].isna()))]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1                 7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2                10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3                 0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4                 2  10000000.0      100.00  2018-06-19T00:00:00      2
# ...             ...         ...         ...                  ...    ...
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Эти условия работают не совсем корректно
#
#
#                ((new_data['kitchen_area'] > 5) & (new_data.isnull().any(axis=1)))
#
# ты говоришь программе оставь мне все квартиры у которых кухня и больше 5-ти кв. метров и одновременно хоть одна колонка имеет пропуск
#
# да, угадать можно и часть данных мы сохраним, но попадет ли в эту фильтрацию записи у которых пропуск в колонке кухни, т.к. первое условие выполнить не получиться
#
# Как мы видим из примера, это не получиться сделать
#
#         data.loc[(data['kitchen_area'] > 5) | ((data['kitchen_area'] > 5) & (data.isnull().any(axis=1)))].info()
#
# 1400 записей с пропусками мы потеряем
#
# Корректный пример кода, который фильтрует значения и оставляет кухни с пропусками ⬇⬇⬇
#
#        ... =  data.loc[((data['kitchen_area'] >= 5) | (data['kitchen_area'].isna()))]
#
# который говорит программе: оставь все кухни у которых площадь более или равна 5-ти кв. метрам и самое главное ИЛИ площадь кухни не заполнена (у меня пример на другой выборке)

# %%
data.isna().sum()
# Out:
# total_images                   0
# last_price                     0
# total_area                     0
# first_day_exposition           0
# rooms                          0
# ceiling_height              5555
# floors_total                   0
# living_area                 1865
# floor                          0
# is_apartment                   0
# studio                         0
# open_plan                      0
# kitchen_area                2222
# balcony                        0
# locality_name                  0
# airports_nearest            5524
# cityCenters_nearest         5501
# parks_around3000               0
# parks_nearest                  0
# ponds_around3000               0
# ponds_nearest                  0
# days_exposition             3171
# one_meter_price                0
# first_day_exposition_new       0
# week_day                       0
# month                          0
# year                           0
# floor_type                     0
# ...

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />остались аномалии и редкости (в т.ч. и хвосты) в колонках:
#
#          'ceiling_height', 'days_exposition',  'living_area',  'kitchen_area', 'floors_total'
#
# стоит обратить внимание на минимальные и максимальные значения в выборке и учесть наличие пропусков при фильтрации данных

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Доп. задание, на твое усмотрение — сможешь добавить в таблицу расчет медианного значения?
#
#         (
#             data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
#                   'floor', 'floors_total']]
#             .apply (['count', 'min', 'max'])
#             .style.format("{:,.2f}")
#         )

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Для выполнения пункта 4.1. (или в старой версии п.2.4) существует два подхода
#
# Можно механически бороться с выбросами (при помощи межквартильного размаха), ...
#
# основная проблема такого подхода — не учитывается неоднородность нашей выборки: у нас здесь и малые поселки, и вторая столица страны, и исторический фонд и массовая застройка, и однушки и довольно большое кол-во многокомнатных квартир, или наоборот одна две квартиры с количеством комнат больше 7-ми ...
#
#
#
# если бы у нас в таблице были бы только однокомнатные квартиры из определенного района массовой застройки, тогда да, мы бы боролись с выбросами традиционными способами, при нашем многообразии населенных пунктов, многокомнатности такие подходы не работают... т.е. они работают, но это усложнит наш проект — придется разбить и объединить записи нашей таблицы по нескольким параметрам (кол-во комнат, район, и т.д.), а затем только выполнять все остальные пункты на каждой отдельной выборке
#
# Остается другой подход — убираем редкие значения и следим за количеством потерь...
#
# Для выборки из 23-х тысяч значений, несколько записей со стоимостью квадратного метра выше 1-го млн. руб., довольно редкое явление
#
# Хороший пример, высота потолков, которую мы отрезаем по нижней и верхней планке, это скорее аномальные записи, посмотрим на другой аспект — на редкости: кол-во комнат
#
# __т.е. мы не говорим о том, что квартир с кол-ом комнат выше 7 не бывает, мы говорим, что для нашего исследования это редкие выбивающиеся из общей картины уникальные объекты, по которым необходимо проводить отдельную работу ...__
#
# подобным образом рассматриваем и остальные параметры
#
# наши помощники
#
# 1. гистограммы, с хорошим масштабом
# 2. метод describe() или облегченная версия, пример выше
# 3. метод value_counts()
#
# плюс жизненный опыт

# %%
# check

try:
    df_check = pd.read_csv('https://code.s3.yandex.net/datasets/real_estate_data.csv', sep='\t')
# если не получилось прочитать файл из локальной папки, то загружаем данные из сети
except:
    df_check = pd.read_csv('real_estate_data.csv', sep='\t')

# %%
# check
df_check.rooms.value_counts().to_frame()
# Out:
#     rooms
# 1    8047
# 2    7940
# 3    5814
# 4    1180
# 5     326
# 0     197
# 6     105
# 7      59
# 8      12
# 9       8
# 10      3
# 11      2
# 14      2
# 19      1
# 16      1
# 12      1
# 15      1

# %%
# check
df_check.total_area.hist(bins = 150, figsize = (15,3));

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />т.е. все квартиры менее 20-ти и более 250-ти квадратных метров можно считать редкостями

# %%
# check
df_check.total_area.hist(bins = 150, figsize = (15,3), range = (180,500));

# %%
# check
df_check.total_area.hist(bins = 15, figsize = (15,3), range = (180,500));

# %%
# check
df_check.total_area.hist(bins = 15, figsize = (15,3), range = (0,25));

# %% [markdown]
#  <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Осталось завершить выполнение пункта 4.1 из брифа проекта (в старой версии п.2.4)
#
# В некоторых параметрах встречаются редкие и выбивающиеся значения. При построении гистограмм удалите их. Например, в столбце ceiling_height может быть указана высота потолков 25 м и 32 м. Логично предположить, что на самом деле это вещественные значения: 2.5 м и 3.2 м. Попробуйте обработать аномалии в этом и других столбцах, если они есть. Если природа аномалии понятна и данные действительно искажены, то восстановите    корректное значение. В противном случае удалите редкие и выбивающиеся значения.
#
# __Критичный уровень потерь записей на этапе предобработки составляет 10%, оптимальный 5%__
#
# Если при фильтрации одной колонки, на этом проекте, теряем больше одного процента данных от изначального объема, стоит еще раз пересмотреть условия фильтрации

# %%
# check

# Значения параметров объектов недвижимости на разных квантилях

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  
        'kitchen_area', 'floor',   'floors_total']]
    .quantile([0.0012, 0.01, .5, .99, .9988]) # выбираем размах в 0,9976 квантилей 
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_49f3f_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_49f3f_level0_row0" class="row_heading level0 row0" >0.0012</th>
#                         <td id="T_49f3f_row0_col0" class="data row0 col0" >0.00</td>
#                         <td id="T_49f3f_row0_col1" class="data row0 col1" >20.00</td>
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Квантили что это такое (первая ссылка иногда не открывается)
#
# https://fin-accounting.ru/cfa/l1/quantitative/cfa-quartiles-quintiles-deciles-percentiles?ysclid=l7gy2kky4i156375632
#
# https://www.codecamp.ru/blog/percentile-vs-quartile-vs-quantile/?ysclid=lg89wjm4zz267333250
#
# они помогают увидеть редкости и аномалии в данных

# %% [markdown]
# #### Изучение как быстро продавались квартиры

# %% [markdown]
# Изучим как быстро продавались квартиры, для этого построим гистограмму столбца days_exposition.

# %%
ax = new_data['days_exposition'].hist(
    bins=100, 
    figsize=(12,7),
    grid=True,
    range=(0,2999)
)
ax.set_xlabel('Количество дней сколько было размещено объявление')
ax.set_ylabel('Количество предложений');

# %% [markdown]
# Посчитаем среднюю и медиану.

# %%
new_data['days_exposition'].mean()
# Out:
# 187.45790914066777

# %%
new_data['days_exposition'].median()
# Out:
# 103.0

# %% [markdown]
# Медиана показывает, что большинство квартир продаются в течение 103 дней, однако средняя учитывает что есть необычно долгие продажи, которые, как показывает гистограмма, могут длится до полутора лет.

# %% [markdown]
# Рассмотрим дни с помощью квартилей.

# %%
new_data['days_exposition'].describe()
# Out:
# count    18270.000000
# mean       187.457909
# std        218.025794
# min         10.000000
# 25%         45.000000
# 50%        103.000000
# 75%        239.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Квартили показывают, что редкие значения наблюдаются до 45 дней и после 235. Пиковые значения составляют 10 дней минимум и 1580 максимум.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#
# __Интересно посмотреть на изменение средней  скорости продаж по годам__

# %% [markdown]
# Изучим скорость изменения продаж по годам.

# %%
mean_speed_by_year = new_data.pivot_table(index='year', values='days_exposition', aggfunc='mean')

# %%
fig = mean_speed_by_year.plot(
    figsize=(12,7),
    grid=True,
    legend=False
)

fig.set_xlabel('Год публикации объявления')
fig.set_ylabel('Среднее количество дней продажи');

# %% [markdown]
# На графике видно, что в среднем квартиры продаются быстрее для каждого года, следовательно средняя скорость возрастает.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Все верно, скорость продаж уменьшается, квартиры продаются быстрее. Только использовать с осторожностью, у нас еще больше 3000 непроданных квартир, которых нет в статистике о средней скорости продаж

# %%
# check
# Моды на сырых данных
 
df_check['days_exposition'].value_counts().to_frame().head(20).plot(kind = 'barh', figsize = (15,6), rot = 0);

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Моды на сырых данных
#
#         Мода (Mo) представляет собой значение изучаемого признака, повторяющееся с наибольшей частотой, т.е. мода – значение признака, встречающееся чаще всего. Медианой (Me) называется значение признака, приходящееся на середину ранжированной (упорядоченной) совокупности, т.е. медиана – центральное значение вариационного ряда.
#
# Выделяются моды на 45 и 60 дней, а значения на 44 и 45 дней, явно имеет техническую причину снятия, из-за формата числа
#
# В нашем проекте — моды, из-за подозрения что это техническое снятие с продаж, могут искажать реальный расчет скорости продажи квартиры
#
# второе предположение о причине появления подобных значений — результат деятельности роботов агентств недвижимости, которые обновляют свои предложения с определенной частотой
#
# полностью из проекта удалять их не стоит, можно временно исключить из расчета скорости продаж

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Не исследованы моды (пиковые значения) в 'days_exposition' и как они влияют на скорость продажи, подсказка на что смотреть
#
# [Условия размещения объявлений](https://yandex.ru/support/realty/owner/home/add-ads-housing.html)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />   Для определения быстрых и долгих продаж оптимальнее ориентироваться на 25-тый и 75-тый квантили

# %% [markdown]
# #### Определение факторов, которые влияют на стоимость объекта

# %% [markdown]
# Определим факторы, которые влияют на стоимость стоимость объекта.

# %% [markdown]
# Изучим зависит ли цена от общей площади. Построим график зависимости общей площади от цены. #one_meter_price.

# %%
fig = new_data.plot.scatter(
    x='total_area', 
    y='last_price',
    figsize=(12,7)
)

fig.set_xlabel('Общая площадь')
fig.set_ylabel('Общая цена')
# Out:
# Text(0, 0.5, 'Общая цена')

# %%
# на всякий случай оставил графики со сводными таблицами
total_plot_pivot = new_data.pivot_table(index='total_area', values = 'last_price', aggfunc=['mean', 'median'])

# %%
total_plot_pivot.columns = ['mean', 'median']

# %%
total_plot_pivot['mean'].plot()
# Out:
# <AxesSubplot:xlabel='total_area'>

# %%
total_plot_pivot['median'].plot()
# Out:
# <AxesSubplot:xlabel='total_area'>

# %% [markdown]
# Посчитаем коэффициент корреляции.

# %%
new_data['last_price'].corr(new_data['total_area'])
# Out:
# 0.7826367830840935

# %% [markdown]
# Графики и коэффициент корреляции показывают, что цена зависит от общей площади квартиры. Диаграмма рассеяния показывает, что некоторые аномальные значения остаются, есть низкие значения цены от большей площади, однако видно, что нет более дорогих квартир относительно общей площади.

# %% [markdown]
# Изучим зависимость цены от жилой площади, для чего создадим сводную таблицу.

# %%
fig = new_data.plot.scatter(
    x='living_area', 
    y='last_price',
    figsize=(12,7)
)

fig.set_xlabel('Жилая площадь')
fig.set_ylabel('Общая цена')
# Out:
# Text(0, 0.5, 'Общая цена')

# %%
living_plot_pivot = new_data.pivot_table(index='living_area', values = 'last_price', aggfunc=['mean', 'median'])
living_plot_pivot.columns = ['mean', 'median']

# %%
living_plot_pivot['mean'].plot()
# Out:
# <AxesSubplot:xlabel='living_area'>

# %%
living_plot_pivot['median'].plot()
# Out:
# <AxesSubplot:xlabel='living_area'>

# %% [markdown]
# Посчитаем коэффициент корреляции

# %%
new_data['last_price'].corr(new_data['living_area'])
# Out:
# 0.6595898974529041

# %% [markdown]
# Диаграмма рассеяния показывает, что корреляция есть, но она слабая, как и в случае с общей площадью цена не переходит за верхнюю границу. Графики также показывают что цена не сильно зависит.

# %% [markdown]
# Изучим зависит ли площадь кухни от цены аналогично действиям выше.

# %%
fig = new_data.plot.scatter(
    x='kitchen_area', 
    y='last_price',
    figsize=(12,7)
)

fig.set_xlabel('Площадь кухни')
fig.set_ylabel('Общая цена')
# Out:
# Text(0, 0.5, 'Общая цена')

# %%
kitchen_plot_pivot = new_data.pivot_table(index='kitchen_area', values = 'last_price', aggfunc=['mean', 'median'])
kitchen_plot_pivot.columns = ['mean', 'median']

# %%
kitchen_plot_pivot['mean'].plot()
# Out:
# <AxesSubplot:xlabel='kitchen_area'>

# %%
kitchen_plot_pivot['median'].plot()
# Out:
# <AxesSubplot:xlabel='kitchen_area'>

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Почему мы не применяем группировку данных для диаграмм рассеяния.
#
# Дело в качестве графика. Если мы сводим данные в таблицу — точечный график не покажет всех нюансов в данных, например выбросы - отдельные точки, или отдельные облака
#
# Пример из датасета про цветы - Ирисы ⬇⬇, три класса Ирисов отличаются по ширине и длине околоцветника, что прекрасно можно наблюдать на точечной диаграмме. Если мы построим сводную таблицу и усредним значения, мы этого разделения не увидим
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Найдём коэффициент корреляции.

# %%
new_data['last_price'].corr(new_data['kitchen_area'])
# Out:
# 0.5780546755428303

# %% [markdown]
# Диаграмма рассеяния показывает, что в среднем цена остаётся одинаковой, корреляция есть, но слабая.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит перерисовать первые три графика без применения сводных таблиц
#
# Можно попробовать настроить вид точечных графиков
#
# [Как сделать диаграмму рассеяния из фрейма данных Pandas](https://www.codecamp.ru/blog/pandas-scatter-plot/?ysclid=lh0tbpkoa9628147030)
#
# Примеры расчета коэф. корреляции и не только
#
# [Исследуем отношение между переменными](https://dfedorov.spb.ru/pandas/downey/%D0%98%D1%81%D1%81%D0%BB%D0%B5%D0%B4%D1%83%D0%B5%D0%BC%20%D0%BE%D1%82%D0%BD%D0%BE%D1%88%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BC%D0%B5%D0%B6%D0%B4%D1%83%20%D0%BF%D0%B5%D1%80%D0%B5%D0%BC%D0%B5%D0%BD%D0%BD%D1%8B%D0%BC%D0%B8.html?ysclid=l9ev0utyg728177057)

# %% [markdown]
# Изучим зависимость цены от количества комнат.

# %%
rooms_plot_pivot = new_data.pivot_table(index='rooms', values = 'last_price')

# %%
rooms_plot_pivot.plot()
# Out:
# <AxesSubplot:xlabel='rooms'>

# %% [markdown]
# Посчитаем коэффициент корреляции.

# %%
new_data['last_price'].corr(new_data['rooms'])
# Out:
# 0.4894279501479433

# %% [markdown]
# График и коэффициент корреляции показывают, что рост цены меняется от количества комнат, однако видно, что цена зависит.

# %% [raw]
# Изучим зависимость цены от типа этажа

# %%
floor_plot_pivot = new_data.pivot_table(index='floor_type', values = 'last_price')

# %%
floor_plot_pivot.plot()
# Out:
# <AxesSubplot:xlabel='floor_type'>

# %% [markdown]
# График показывает, что цены на первом этаже заменто ниже цен на последнем и ещё ниже на другом.

# %% [markdown]
# Изучим зависимость цены от даты продажи.

# %%
#date_plot_pivot_day = data.pivot_table(index=['year', 'month', 'week_day'], values = 'last_price')
date_plot_pivot_day = new_data.pivot_table(index='week_day', values = 'last_price')
date_plot_pivot_month = new_data.pivot_table(index='month', values = 'last_price')
date_plot_pivot_year = new_data.pivot_table(index='year', values = 'last_price')

# %%
# date_plot_pivot.columns

# %%
fig = date_plot_pivot_day.plot(
    figsize=(12,7),
    grid=True,
    legend=False
)

fig.set_xlabel('День недели')
fig.set_ylabel('Общая цена')
# Out:
# Text(0, 0.5, 'Общая цена')

# %% [markdown]
# График показывает, что в будние дни продаж больше всего, пик приходится на среду, начиная с пятницы продажи заметно падают.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#
# Интересно, по какой причине средние цены в выходные настолько отличаются от средних цен в будние дни?

# %%
fig = date_plot_pivot_month.plot(
    figsize=(12,7),
    grid=True,
    legend=False
)

fig.set_xlabel('Месяц')
fig.set_ylabel('Общая цена')
# Out:
# Text(0, 0.5, 'Общая цена')

# %% [markdown]
# На графике видно, что в июне цена меньше всего, в остальные месяцы она колеблется от 4900000 до 5200000 рублей за квадратный метр.

# %%
fig = date_plot_pivot_year.plot(
    figsize=(12,7),
    grid=True,
    legend=False
)

fig.set_xlabel('Год')
fig.set_ylabel('Общая цена')
# Out:
# Text(0, 0.5, 'Общая цена')

# %% [markdown]
# График показывает, что дороже всего квартиры были в 2014 году, цена убывала до 2016 и оставалась на одном уровне с 2017, после чего цена начала медленно повышаться.

# %%
#data['last_price'].corr(data['days_exposition'])

# %% [markdown]
# Учтём остальные факторы, а именно рассмотрим изменение средней цены и средней площади по годам c учётом изменения количества предложений.

# %% [markdown]
# Найдём количество предложений и среднюю общую площадь по годам

# %%
total_area_pivot = new_data.pivot_table(index='year', values='total_area', aggfunc=['count', 'mean'])
total_area_pivot.columns = ['count', 'mean']

# %%
fig = total_area_pivot['count'].plot(
    figsize=(12,7),
    grid=True,
    legend=False
)

fig.set_xlabel('Год')
fig.set_ylabel('Количество предложений');

# %%
fig = total_area_pivot['mean'].plot(
    figsize=(12,7),
    grid=True,
    legend=False
)

fig.set_xlabel('Год')
fig.set_ylabel('Общая площадь');

# %% [markdown]
# На графике количества предложений видно, что количество увеличивается, что влияет на общую цену согласно законам рынка. Средняя общая площадь падает, что тоже влияет на конечную цену. Резкое уменьшение в количестве предложений влияет на цену за 2019 год.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Если смотреть только на изменение средней или медианной цены по годам мы можем сделать некорректный вывод, что цены падали, а на самом деле цена это параметр на который влияет несколько других факторов, по этой причине можно посмотреть на основные из них:
#
# + изменение кол-ва записей — принять решение о достаточности данных для анализа и сравнения (сравнивать 100 объявлений и 8000, а возможно, что они еще и из разных локаций, не совсем корректно)
# + изменение площади, как основного параметра от которого зависит стоимость квартиры, в 2017-2018 гг. на сервис или рынок ИТ-торговли недвижимостью пришел массовый продавец, и средние значения площади упали ..., а за ней и цена
# + изменение кол-ва поданных объявлений из разных локаций, т.к. есть питерские квартиры, а есть выборгские квартиры и стоят они по разному, и в разные годы могло быть больше квартир из определенной локации
# + полнота периода для анализа, 2014 и 2019 гг. неполные, а у нас есть сезонные колебания цен, например летнее снижение цен
#
# и т.д.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Скажи пожалуйста, на подобных данных считается коэффициент корреляции?
#
#         new_data['last_price'].corr(new_data['days_exposition'])

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />    Стоит добавить 3 новых графика
#
#     +	даты размещения (день недели, месяц, год). - это три отдельных графика
#
# Постройте графики, которые покажут зависимость цены от указанных выше параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы.
#
#
#
# Советы по графикам: оптимальнее рассматривать
#
# + динамику — на линейных графиках (это про сравнение цен за год, месяц, день недели), — стоит сгруппировать значения и рассчитать среднее или медианное значение

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит дополнить  вывод об изменении цен по годам, необходимо учесть другие факторы, которые также изменяются с годами: площадь и кол-во объявлений о продаже (стоит добавить или графики, или сводные таблицы и исследовать взаимное влияние параметров: кол-во записей и изменение средней цены и средней площади в течение лет)
#
#         в этом пункте самое главное создать таблицы с сгруппированнами данными, при помощи группировки или сводных таблиц

# %% [markdown]
# #### Рассчёт цены квартиры в населённых пунктах с наибольшим числом объявлений.

# %% [markdown]
# Найдём количество населённых пунктов с наибольшим числом объявлений, для чего создадим новый столбец с числом объявлений, который назовём amount

# %%
amount_pivot = new_data.pivot_table(index='locality_name', values='one_meter_price', aggfunc=['count', 'mean'])
amount_pivot.columns=['count', 'mean']

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит исключить предупреждения. Иногда их бывает слишком много, поэтому важно уметь их скрывать. В этом тебе поможет библиотека warnings. Попробуй найти подходящий метод и убрать предупреждения.

# %%
amount_pivot = amount_pivot.sort_values(by='count', ascending=False)

# %%
amount_pivot.head(10)
# Out:
#                  count           mean
# locality_name
# Санкт-Петербург  13731  108019.584375
# Мурино             523   85540.351377
# Кудрово            426   95089.762911
# Шушары             416   78370.073894
# Всеволожск         378   67251.805344
# Пушкин             333  101472.959700
# Колпино            317   75196.749558
# Парголово          301   90120.462326
# Гатчина            285   68729.429474
# Выборг             226   58048.466549

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Широкие строки кода рекомендуется делить на всем проекте
#
# <a href="https://qastack.ru/programming/53162/how-can-i-do-a-line-break-line-continuation-in-python">Перенос длинных строк кода</a>.
#
# </div>

# %%
amount_pivot.query('count >= 226')
# Out:
#                  count           mean
# locality_name
# Санкт-Петербург  13731  108019.584375
# Мурино             523   85540.351377
# Кудрово            426   95089.762911
# Шушары             416   78370.073894
# Всеволожск         378   67251.805344
# Пушкин             333  101472.959700
# Колпино            317   75196.749558
# Парголово          301   90120.462326
# Гатчина            285   68729.429474
# Выборг             226   58048.466549

# %% [markdown]
# Найдём количество уникальных значений по числу объявлений, после чего уберём всё что ниже.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> на проектах стоит снижать размерность выводимой информации, где не требуется максимальная точность, до одного или двух знаков после запятой
#
#        Кудрово	402.0	95724.922463

# %%
amount_pivot['mean'] = round(amount_pivot['mean'], 2)

# %% [markdown]
# Найдём населённые пункты с самой высокой и самой низкой ценой объявлений.

# %%
amount_pivot = amount_pivot.query('count >= 226').sort_values(by='mean')
amount_pivot
# Out:
#                  count       mean
# locality_name
# Выборг             226   58048.47
# Всеволожск         378   67251.81
# Гатчина            285   68729.43
# Колпино            317   75196.75
# Шушары             416   78370.07
# Мурино             523   85540.35
# Парголово          301   90120.46
# Кудрово            426   95089.76
# Пушкин             333  101472.96
# Санкт-Петербург  13731  108019.58

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Стоит добавить график для этой таблицы

# %% [markdown]
# Видно, что самая высокая цена у Санкт-Петербурга, а самая низкая у Выборга.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />ТОП-10 рассчитан корректно

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Недостаточно найти числа, стоит их показать красиво, удобно и наглядно, чтобы одного взгляда хватило, где самые самые, а где подешевле 📊

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [Постер поможет выбирать вид графиков](https://www.notion.so/6c5ae8ceb8b5411e907c93c9b5e6a44e)

# %% [markdown]
# #### Изучение цены квартиры в Санкт-Петербурге на разном удалении от центра

# %% [markdown]
# Найдём зависимость цен в Санкт-Петербурге от удаления до центра.

# %%
spb_data = new_data.loc[new_data['locality_name'] == 'Санкт-Петербург']

# %%
spb_pivot = spb_data.pivot_table(index=['cityCenters_nearest_km', 'floor_type'], values='last_price', 
                                 aggfunc=['count', 'mean'])

# %%
spb_pivot
# Out:
#                                        count          mean
#                                   last_price    last_price
# cityCenters_nearest_km floor_type
# 0.0                    другой              6  1.009667e+07
#                        первый              2  7.600000e+06
#                        последний           2  6.100000e+06
# 1.0                    другой             85  1.072119e+07
#                        первый             16  9.778062e+06
# ...                                      ...           ...
# 28.0                   первый              2  4.201500e+06
#                        последний           1  5.144000e+06
# 29.0                   другой              1  4.850000e+06
#                        первый              3  4.583333e+06
#                        последний           1  4.370000e+06
#
# [89 rows x 2 columns]

# %%
# check
spb_pivot[9:18]
# Out:
#                                        count          mean
#                                   last_price    last_price
# cityCenters_nearest_km floor_type
# 3.0                    другой            164  9.079115e+06
#                        первый             48  6.900415e+06
#                        последний          70  9.280086e+06
# 4.0                    другой            388  9.442556e+06
#                        первый             73  7.810836e+06
#                        последний          82  9.085683e+06
# 5.0                    другой            529  9.537166e+06
#                        первый             69  7.319928e+06
#                        последний         100  9.664595e+06

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />   Расчет принимается, подправим акценты вывода (сорри за размер графика)
#
# ![image.png](attachment:image.png)
#
# слева график для 3-го км., справа для 5-го км. (цифры для графиков не твои, но это не принципиально)
#
# Две стопки монет: в одной 8 золотых и 2 серебряные, во второй 6 золотых и 4 серебряные. В какой стопке средняя цена одной монеты будет дороже? Точнее соотношение будет таким: на пятом км. 18 золотых и 6 серебряных, а на 3-м 6 золотых и 4 серебряные
#
# Размер доли квартир с более дешевой категорией намного больше на 3-м километре, чем на пятом, что является одной из причин падения и пика...
#
# возможно к этому фактору добавляются и другие

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Для оптимизации кода расчета доли таких квартир стоит обратить внимание на пример из статьи
#
#         Работа с групповыми объектами
#         После группировки и агрегирования данных вы можете выполнять дополнительные вычисления для сгруппированных объектов.
#
#         В следующем примере определим, какой процент от общего количества проданных билетов можно отнести к каждой комбинации embark_town и class.
#
#         Мы используем метод assign() и лямбда-функцию для добавления столбца pct_total:
#
#         df.groupby(['embark_town', 'class']).agg({'fare': 'sum'}).assign(pct_total=lambda x: x / x.sum())
#
#
# [Подробное руководство по группировке и агрегированию с помощью pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%B4%D1%80%D0%BE%D0%B1%D0%BD%D0%BE%D0%B5%20%D1%80%D1%83%D0%BA%D0%BE%D0%B2%D0%BE%D0%B4%D1%81%D1%82%D0%B2%D0%BE%20%D0%BF%D0%BE%20%D0%B3%D1%80%D1%83%D0%BF%D0%BF%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B5%20%D0%B8%20%D0%B0%D0%B3%D1%80%D0%B5%D0%B3%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8E%20%D1%81%20%D0%BF%D0%BE%D0%BC%D0%BE%D1%89%D1%8C%D1%8E%20pandas.html)

# %%
spb_pivot.columns = ['count', 'mean']

# %%
spb_pivot['count'].plot()
# Out:
# <AxesSubplot:xlabel='cityCenters_nearest_km,floor_type'>

# %%
spb_pivot['mean'].plot()
# Out:
# <AxesSubplot:xlabel='cityCenters_nearest_km,floor_type'>

# %% [markdown]
# График показывает, что цена квартир в Санкт-Петербурге уменьшается в зависимости от расстояния до центра.

# %% [markdown]
# Исследуем аномалии на 27-ом километре

# %%
spb_data.query('cityCenters_nearest_km == 27')
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 748             13  14350000.0        74.0  2017-11-28T00:00:00      2
# 5961             6   2250000.0        32.0  2018-02-27T00:00:00      1
#
#       ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 748             3.13             5         30.0      3         False  ...
# 5961             NaN             2         16.5      2         False  ...
#
#       ponds_around3000  ponds_nearest  days_exposition  one_meter_price  \
# 748                  0         3001.0            128.0        193918.92
# 5961                 0         3001.0            178.0         70312.50
#
#      first_day_exposition_new  week_day  month  year  floor_type  \
# 748                2017-11-28         1     11  2017      другой
# 5961               2018-02-27         1      2  2018   последний
#
#       cityCenters_nearest_km
# 748                     27.0
# 5961                    27.0
#
# ...

# %% [markdown]
# Одна квартира имеет довольно высокую цену, скорее всего это относится к элитному жилому комплексу.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />принимается,
#
# __у нас всего 2 записи на 27-м км.__ (на сырых данных), одна из которых с аномально высокой ценой, а другая с аномально низкой
#
# __кол-во наблюдений важный параметр для оценки качества данных__
#
# именно, по этой ⬆⬆⬆ причине мы отвергаем данное наблюдение

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />    Для решения задачи
#
#     Стоит посмотреть на количество квартир разных категорий (первый, последний, другой), которые продаются на 3-м км. и 5-ом ... и какую долю они занимают на каждом километре, чтобы объяснить пик  и провал в центре
#
# стоит выполнить группировку данных на питерских квартирах и подсчитать кол-во
#
# ссылку на статью дублирую (в статье обратить внимание на примеры с двойным индексом)
#
# [Сводная таблица в pandas](https://dfedorov.spb.ru/pandas/%D0%A1%D0%B2%D0%BE%D0%B4%D0%BD%D0%B0%D1%8F%20%D1%82%D0%B0%D0%B1%D0%BB%D0%B8%D1%86%D0%B0%20%D0%B2%20pandas.html?ysclid=lje9wz2vfc28794921)

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# У нас аномалия на питерских квартирах
#
#
# Для решения задачи
#
#         Стоит изучить записи, которые привели к выбросу на 27-м км.
#
# стоит выполнить простую фильтрацию данных: оставить только питерские квартиры и только с 27-го километра

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Молодец, у тебя получилось сгруппировать и построить график изменения средней цены в зависимости от расстояния до центра

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит изучить записи, которые привели к выбросу на 27-м км.

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит посмотреть на количество квартир разных категорий (первый, последний, другой), которые продаются на 3-м км. и 5-ом ... и какую долю они занимают на каждом километре, чтобы объяснить пик  и провал в центре
#
#         выполняется при помощи группировки или свода данных

# %% [markdown]
# ### Напишите общий вывод

# %% [markdown]
# В данном исследовании проводился исследовательский анализ данных продажи квартир в Ленинградской области. Исследование показывает, что общая площадь большинства объявлений около 40 $м^2$, жилая площадь около 15-20 $м^2$ и окло 40 $м^2$, площадь кухни около 10 $м^2$, средняя цена около 100000 рублей за $м^2$, большинство квартир двухкомнатные и трёхкомнатные, расстояние до центра около 10 км, расстояние до центра около 15 км. Общая цена квартиры зависит от количества комнат, жилой площади и общей площади и не зависит от площади кухни. Средняя и медиана для количества дней продажи показывают, что в среднем время продажи около 90 дней. Для Санкт-Петербурга цена квартир зависит от расстояния до центра.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Стоит добавить новых инсайтов в итоговый вывод

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Технически вывод хороший, есть сравнения показателей, инсайты, анализ рынка недвижимости, молодец
#
# Осталось перепроверить итоговый вывод после исправления всех комментариев

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Выполнил исследовательскую работу, молодец, показал хороший уровень навыков программирования
#
# Критические ❌ комментарии
#
#
# + проверить корректность заполнения пропусков синтетическими данными
# + сменить тип данных
# + поменять подход обработки аномалий
# + настроить фильтрацию редких значений
# + подправить гистограммы в п.4.1
# + добавить графики и вывод в п. 4.3
# + добавить график в ТОП-10
# + исследовать аномалии в п.4.5
# + поправить итоговый вывод
#
#
#
# С ними важно поработать и исправить
#
# Стоит обратить внимание и на такие комментарии ⚠️
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5"><b>Жду твой проект и твои комментарии 🤝</b></font><br />
#
# нумерация пунктов из брифа проекта, у тебя они могут быть другие
#
# если не заметил твоих вопросов, просьба выделить цветом
#
#
# __Для успешного исправления комментариев стоит прочитать справочные материалы ⬇⬇⬇__

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [Обработка пропусков в данных](https://loginom.ru/blog/missing)
#
#
# [Подробное руководство по группировке и агрегированию с помощью pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%B4%D1%80%D0%BE%D0%B1%D0%BD%D0%BE%D0%B5%20%D1%80%D1%83%D0%BA%D0%BE%D0%B2%D0%BE%D0%B4%D1%81%D1%82%D0%B2%D0%BE%20%D0%BF%D0%BE%20%D0%B3%D1%80%D1%83%D0%BF%D0%BF%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B5%20%D0%B8%20%D0%B0%D0%B3%D1%80%D0%B5%D0%B3%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8E%20%D1%81%20%D0%BF%D0%BE%D0%BC%D0%BE%D1%89%D1%8C%D1%8E%20pandas.html)
#
# [Сводная таблица в pandas](https://dfedorov.spb.ru/pandas/%D0%A1%D0%B2%D0%BE%D0%B4%D0%BD%D0%B0%D1%8F%20%D1%82%D0%B0%D0%B1%D0%BB%D0%B8%D1%86%D0%B0%20%D0%B2%20pandas.html?ysclid=lje9wz2vfc28794921)
#
# [Понимание функции transform в Pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%BD%D0%B8%D0%BC%D0%B0%D0%BD%D0%B8%D0%B5%20%D1%84%D1%83%D0%BD%D0%BA%D1%86%D0%B8%D0%B8%20transform%20%D0%B2%20Pandas.html)
#
# [Как выбрать определенные столбцы из DataFrame](https://dfedorov.spb.ru/pandas/03.%20%D0%9A%D0%B0%D0%BA%20%D0%B2%D1%8B%D0%B1%D1%80%D0%B0%D1%82%D1%8C%20%D0%BF%D0%BE%D0%B4%D0%BC%D0%BD%D0%BE%D0%B6%D0%B5%D1%81%D1%82%D0%B2%D0%BE%20%D0%B8%D0%B7%20DataFrame_.html?ysclid=l9sps5lt6g576766938)
#
# [How to visualise data using histograms in Pandas](https://practicaldatascience.co.uk/data-science/how-to-visualise-data-using-histograms-in-pandas)
#
# [8 способов фильтрации фреймов данных Pandas](https://questu.ru/articles/85248/)

# %% [markdown]
# ### Бонус

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в4</b></font>
# <br />
# <font size="3", color = "black">
# <br />Диаграмма рассеяния

# %%
# check
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />   Стоит применять «змеиный стиль» в названиях переменных и колонках
#
#        'cityCenters_nearest'
#
#         'city_centers_nearest'
#
# [Для чего придуман PEP8](https://letpy.com/python-guide/pep8/?ysclid=lkvf7o0xjl57413288)

# %%
# check
sns.pairplot(data[['last_price', 'total_area', 'rooms', 'cityCenters_nearest']])
plt.gcf().set_size_inches(12,12);

# %%
# check
data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter',
        y='last_price' , x='total_area', alpha=0.5, subplots=True, figsize=(15,8), c = 'b', s = 4)
plt.title('Диаграмма рассеяния — Общая площадь — цена трешки')


data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter', 
        y='last_price' , x='living_area', alpha=0.5, figsize=(15,8), c = 'r', s = 4)
plt.title('Диаграмма рассеяния — Жилая площадь — цена трешки');

# %%
# check
data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter',
        y='living_area' , x='total_area', alpha=0.5, subplots=True, figsize=(15,8), c = 'MediumSpringGreen', s = 4)
plt.title('Диаграмма рассеяния — Общая площадь — Жилая');

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />пример с двойной сортировкой, у меня пример с общей стоимостью

# %%
# check TOP-10
# способы группировки и сортировки информации

(
    data
    .groupby('locality_name')['last_price']
    .agg({'count', 'mean'})
    .sort_values(by = 'count', ascending = False)
    .head(10)
    
).sort_values(by = 'mean', ascending = False).style.format("{:,.0f}")

# .plot(y = 'mean', kind = 'bar')
# стайл и плот вместе не работают
# Out:
# <style  type="text/css" >
# </style><table id="T_8c5e2_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >mean</th>        <th class="col_heading level0 col1" >count</th>    </tr>    <tr>        <th class="index_name level0" >locality_name</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8c5e2_level0_row0" class="row_heading level0 row0" >Санкт-Петербург</th>
#                         <td id="T_8c5e2_row0_col0" class="data row0 col0" >8,064,895</td>
#                         <td id="T_8c5e2_row0_col1" class="data row0 col1" >15,651</td>
#             </tr>
#             <tr>
#                         <th id="T_8c5e2_level0_row1" class="row_heading level0 row1" >Пушкин</th>
#                         <td id="T_8c5e2_row1_col0" class="data row1 col0" >6,469,036</td>
# ...

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.
