# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Игорь, привет!👋</b>
#
# Меня зовут Кирилл Васильев, я буду ревьюером твоего проекта. Я предлагаю общаться на «ты», но если привычнее на «вы», просто скажи об этом!
#
# Я буду оставлять комментарии в твоем проекте. Пожалуйста, не удаляй их, они могут быть полезны в случае повторной проверки.
#
# Свои комментарии я буду обозначать <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В случае, если решение на отдельном шаге является полностью правильным. Здесь же я могу давать советы и предложения.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В случае, когда решение на отдельном шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#  В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
# <br/>
# <div class="alert alert-info">
# Рекомендую для твоих комментариев использовать синий или любой другой цветной фон. Я постараюсь ничего не пропустить, но если комментарии будут выделены, то это мне очень поможет!
# </div>
#
# Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самостоятельно найти и исправить ее. На реальной работе твой руководитель будет поступать также. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку.

# %% [markdown]
# # Обучение с учителем: самостоятельный проект

# %% [markdown]
# ## Введение

# %% [markdown]
# **Описание исследования**
#
# Интернет-магазин «В один клик» продаёт разные товары: для детей, для дома, мелкую бытовую технику, косметику и даже продукты. Отчёт магазина за прошлый период показал, что активность покупателей начала снижаться. Привлекать новых клиентов уже не так эффективно: о магазине и так знает большая часть целевой аудитории. Возможный выход — удерживать активность постоянных клиентов. Сделать это можно с помощью персонализированных предложений.

# %% [markdown]
# **Цель исследования**
#
# Необходимо создать модель машинного обучения, которая позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность.

# %% [markdown]
# *План исследования:*
#
# ***Часть 1. Загрузка данных и обзор общей информации***
# * 1. Загрузка данных
# * 2. Обзор данных и переименование столбцов
#
# ***Часть 2. Предобработка данных***
# * 1. Поиск и обработка пропусков и дубликатов
# * 2. Преобразование признаков
#
# ***Часть 3. Исследовательский анализ данных***

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Контекст и план проекта понятны.
# </div>

# %% [markdown]
# ## Часть 1. загрузка данных

# %% [markdown]
# ### 1. Загрузка данных

# %% [raw]
# Загрузим нужные библиотеки

# %%
#pandas для работы с датафреймами
import pandas as pd
#математические библиотеки
import phik
import math
import numpy as np
#графики
from scipy import stats as st
import matplotlib.pyplot as plt
import seaborn as sns
#sklearn
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC 
from sklearn.model_selection import train_test_split 
from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import (
    StandardScaler,
    OneHotEncoder,
    LabelEncoder
)
from sklearn.metrics import (
    confusion_matrix,
    accuracy_score,
    recall_score,
    precision_score,
    roc_auc_score
)

from sklearn.preprocessing import (
    OneHotEncoder,
    OrdinalEncoder, 
    StandardScaler, 
    MinMaxScaler, 
    RobustScaler
)
from sklearn.compose import ColumnTransformer

from sklearn.pipeline import Pipeline

from sklearn.impute import SimpleImputer

import shap
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_107/644984411.py in <module>
#       2 import pandas as pd
#       3 #математические библиотеки
# ----> 4 import phik
#       5 import math
#       6 import numpy as np
#
# ModuleNotFoundError: No module named 'phik'

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Отлично по оформлению.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# `#просто чтоб было` - вообще, хорошо бы загружать только то, что пригодится в проекте.
#
#
# </div>

# %% [markdown]
# Введём константы.

# %%
RANDOM_STATE = 42
TEST_SIZE = 0.25

# %% [markdown]
# Загрузим файл market_file

# %%
try:
    df_market_file = pd.read_csv('market_file.csv')
except:
    print('Ошибка чтения файла')
# Out:
# Ошибка чтения файла

# %%
df_market_file.head()
# Out:
#        id Покупательская активность Тип сервиса Разрешить сообщать  \
# 0  215348                 Снизилась     премиум                 да
# 1  215349                 Снизилась     премиум                 да
# 2  215350                 Снизилась   стандартт                нет
# 3  215351                 Снизилась   стандартт                 да
# 4  215352                 Снизилась   стандартт                нет
#
#    Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  Акционные_покупки  \
# 0                 3.4                     5           121               0.00
# 1                 4.4                     4           819               0.75
# 2                 4.9                     3           539               0.14
# 3                 3.2                     5           896               0.99
# 4                 5.1                     3          1064               0.94
#
#   Популярная_категория  Средний_просмотр_категорий_за_визит  \
# ...

# %% [markdown]
# Загрузим файл market_money

# %%
try:
    df_market_money = pd.read_csv('market_money.csv')
except:
    print('Ошибка чтения файла')

# %%
df_market_money.head()
# Out:
#        id               Период  Выручка
# 0  215348  препредыдущий_месяц      0.0
# 1  215348        текущий_месяц   3293.1
# 2  215348     предыдущий_месяц      0.0
# 3  215349  препредыдущий_месяц   4472.0
# 4  215349        текущий_месяц   4971.6

# %% [markdown]
# Загрузим файл market_time

# %%
try:
    df_market_time = pd.read_csv('market_time.csv')
except:
    print('Ошибка чтения файла')

# %%
df_market_time.head()
# Out:
#        id            Период  минут
# 0  215348     текущий_месяц     14
# 1  215348  предыдцщий_месяц     13
# 2  215349     текущий_месяц     10
# 3  215349  предыдцщий_месяц     12
# 4  215350     текущий_месяц     13

# %% [markdown]
# Загрузим файл money

# %%
try:
    df_money = pd.read_csv('money.csv', sep=';', decimal = ',')
except:
    print('Ошибка чтения файла')

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
#  Чтобы считывать запятую в разделителе цифр можно уже на этапе загрузки определить разделитель:
#
# `df_money = pd.read_csv('money.csv', sep=';', decimal = ',')`
#
#
# </div>

# %%
df_money.head()
# Out:
#        id  Прибыль
# 0  215348     0.98
# 1  215349     4.16
# 2  215350     3.13
# 3  215351     4.87
# 4  215352     4.21

# %% [markdown]
# ### 2. Обзор данных и переименование столбцов

# %% [markdown]
# Приведём столбцы в df_market_file к змеиному индексу, для чего создадим словарь.

# %%
df_market_file_columns = {
    'id': 'id', 
    'Покупательская активность': 'user_activity',
    'Тип сервиса': 'servis_type',
    'Разрешить сообщать': 'allow_to_report',
    'Маркет_актив_6_мес': '6_month_activity',
    'Маркет_актив_тек_мес': 'current_activity',
    'Длительность': 'duration',
    'Акционные_покупки': 'prom_buy',
    'Популярная_категория': 'popular_cat',
    'Средний_просмотр_категорий_за_визит': 'mean_watch_cat_per_visit',
    'Неоплаченные_продукты_штук_квартал': 'unpayed_prod',
    'Ошибка_сервиса': 'service_error',
    'Страниц_за_визит': 'pages_per_visit'
}

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Отлично по переименованию колонок. Нам будет удобнее работать с более короткими названиями признаков и латинскими буквами.
# </div>

# %% [markdown]
# Теперь переименуем

# %%
df_market_file = df_market_file.rename(columns=df_market_file_columns)

# %% [markdown]
# Проверим правильно ли произошло переименование, также рассмотрим этот датафрейм в целом

# %%
df_market_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        1300 non-null   int64
#  1   user_activity             1300 non-null   object
#  2   servis_type               1300 non-null   object
#  3   allow_to_report           1300 non-null   object
#  4   6_month_activity          1300 non-null   float64
#  5   current_activity          1300 non-null   int64
#  6   duration                  1300 non-null   int64
#  7   prom_buy                  1300 non-null   float64
#  8   popular_cat               1300 non-null   object
#  9   mean_watch_cat_per_visit  1300 non-null   int64
#  10  unpayed_prod              1300 non-null   int64
#  11  service_error             1300 non-null   int64
#  12  pages_per_visit           1300 non-null   int64
# dtypes: float64(2), int64(7), object(4)
# ...

# %% [markdown]
# Столбцы переименовались, следует отметить что пропусков в данных нет.

# %% [markdown]
# Поступим аналогично с остальными таблицами

# %% [markdown]
# Таблица df_market_money

# %%
df_market_money_columns = {
    'id': 'id',
    'Период': 'period',
    'Выручка': 'proceed'
}

# %%
df_market_money = df_market_money.rename(columns=df_market_money_columns)

# %%
df_market_money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   period   3900 non-null   object
#  2   proceed  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB

# %% [markdown]
# Переименование прошло успешно, пропусков нет.

# %% [markdown]
# Датафрейм df_market_time

# %%
df_market_time_columns = {
    'id': 'id',
    'Период': 'period',
    'минут': 'minutes'
}

# %%
df_market_time = df_market_time.rename(columns=df_market_time_columns)

# %%
df_market_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       2600 non-null   int64
#  1   period   2600 non-null   object
#  2   minutes  2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB

# %% [markdown]
# Тут как и в случае выше.

# %% [markdown]
# Датафрейм df_money

# %%
df_money_columns = {
    'id': 'id',
    'Прибыль': 'profit'
}

# %%
df_money = df_money.rename(columns=df_money_columns)

# %%
df_money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      1300 non-null   int64
#  1   profit  1300 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 20.4 KB

# %% [markdown]
# Здесь тоже пропусков нет

# %% [markdown]
# ## Часть 2. Предобработка данных

# %% [markdown]
# ### 1. Обработка пропусков и дубликатов

# %% [markdown]
# Выше мы рассмотрели датафреймы методом info и пропусков не обнаружили, поэтому проверим таблицы на дубликаты.

# %% [markdown]
# Рассмотрим датафрейм df_market_file.

# %%
duplicates_market_file = df_market_file[df_market_file.duplicated()]
duplicates_market_file.sum()
# Out:
# id                            0
# user_activity                 0
# servis_type                   0
# allow_to_report               0
# 6_month_activity            0.0
# current_activity              0
# duration                      0
# prom_buy                    0.0
# popular_cat                   0
# mean_watch_cat_per_visit      0
# unpayed_prod                  0
# service_error                 0
# pages_per_visit               0
# dtype: object

# %% [markdown]
# Дубликатов нет

# %% [markdown]
# Рассмотрим датафрейм df_market_money.

# %%
duplicates_market_money= df_market_money[df_market_money.duplicated()]
duplicates_market_money.sum()
# Out:
# id           0
# period       0
# proceed    0.0
# dtype: object

# %% [markdown]
# Дубликатов нет.

# %% [markdown]
# Рассмотрим датафрейм df_market_time

# %%
duplicates_market_time= df_market_time[df_market_time.duplicated()]
duplicates_market_time.sum()
# Out:
# id         0
# period     0
# minutes    0
# dtype: object

# %% [markdown]
# Дубликатов нет.

# %% [markdown]
# Рассмотрим датафрейм df_money

# %%
duplicates_market_money= df_money[df_money.duplicated()]
duplicates_market_money.sum()
# Out:
# id        0.0
# profit    0.0
# dtype: float64

# %% [markdown]
# Дубликатов нет.

# %% [markdown]
# Рассмотрим количество строк каждого датафрейма.

# %%
print(df_market_file.shape[0])
print(df_market_money.shape[0])
print(df_market_time.shape[0])
print(df_money.shape[0])
# Out:
# 1300
# 3900
# 2600
# 1300

# %% [markdown]
# Видно, что в датафреймах df_market_money и df_market_time строк больше, причём они кратны числу строк из первой таблицы.

# %% [markdown]
# Рассмотрим дубликаты датафрейма df_market_money.

# %% [markdown]
# Найдём дубликаты по id.

# %%
df_market_money.duplicated(subset=['id']).sum()
# Out:
# 2600

# %% [markdown]
# Найдём дубликаты по периоду.

# %%
df_market_money.duplicated(subset=['id', 'period']).sum()
# Out:
# 0

# %% [markdown]
# Видно, что за период дубликатов нет, что говорит о том что за разные периоды пользователи совершали разные покупки. Вернёмся к этому когда будем обрабатывать уникальные значения.

# %% [markdown]
# Рассмотрим датафрейм df_market_time

# %%
df_market_time.duplicated(subset=['id']).sum()
# Out:
# 1300

# %% [markdown]
# Найдём дубликаты по периоду.

# %%
df_market_time.duplicated(subset=['id', 'period']).sum()
# Out:
# 0

# %% [markdown]
# Всего два периода, при этом количество строк в два раза больше чем в датафрейме df_market_file. Это также говорит о том, что у пользователей разное значение среднего времени проведённого в минутах за разные интервалы времени.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 У нас данные внутренней аналитики, они действительно чаще бывают относительно чистыми. Дадасет качественный</div>

# %% [markdown]
# ### 2. Преобразование признаков

# %% [markdown]
# #### Датафрейм df_market_file

# %% [markdown]
# Воспользуемся методом info чтобы посмотреть какие признаки категориальные

# %%
df_market_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        1300 non-null   int64
#  1   user_activity             1300 non-null   object
#  2   servis_type               1300 non-null   object
#  3   allow_to_report           1300 non-null   object
#  4   6_month_activity          1300 non-null   float64
#  5   current_activity          1300 non-null   int64
#  6   duration                  1300 non-null   int64
#  7   prom_buy                  1300 non-null   float64
#  8   popular_cat               1300 non-null   object
#  9   mean_watch_cat_per_visit  1300 non-null   int64
#  10  unpayed_prod              1300 non-null   int64
#  11  service_error             1300 non-null   int64
#  12  pages_per_visit           1300 non-null   int64
# dtypes: float64(2), int64(7), object(4)
# ...

# %% [markdown]
# Найдём количество столбцов с таким типом.

# %%
(df_market_file.dtypes == 'object').sum()
# Out:
# 4

# %% [markdown]
# Создадим список категориальных переменных.

# %%
df_market_file_cat = df_market_file.select_dtypes(include=['object']).columns
df_market_file_cat
# Out:
# Index(['user_activity', 'servis_type', 'allow_to_report', 'popular_cat'], dtype='object')

# %% [markdown]
# Рассмотрим уникальные значения категориальных переменных.

# %%
for name in df_market_file_cat:
    print('Название колонки', name, 'значения', df_market_file[name].unique())
# Out:
# Название колонки user_activity значения ['Снизилась' 'Прежний уровень']
# Название колонки servis_type значения ['премиум' 'стандартт' 'стандарт']
# Название колонки allow_to_report значения ['да' 'нет']
# Название колонки popular_cat значения ['Товары для детей' 'Домашний текстиль' 'Косметика и аксесуары'
#  'Техника для красоты и здоровья' 'Кухонная посуда'
#  'Мелкая бытовая техника и электроника']

# %% [markdown]
# Видно, что в servis_type есть значения стандарт и стандартт, заменим стандартт.

# %%
df_market_file.loc[df_market_file['servis_type'] == 'стандартт', 'servis_type'] = 'стандарт'
df_market_file['servis_type'].unique()
# Out:
# array(['премиум', 'стандарт'], dtype=object)

# %% [markdown]
# #### Датафрейм df_market_money

# %% [markdown]
# Посмотрим на типы

# %%
df_market_money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   period   3900 non-null   object
#  2   proceed  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB

# %% [markdown]
# Рассмотрим уникальные значения столбца period.

# %%
df_market_money['period'].unique()
# Out:
# array(['препредыдущий_месяц', 'текущий_месяц', 'предыдущий_месяц'],
#       dtype=object)

# %% [markdown]
# Ещё раз посмотрим на дубликаты

# %%
df_market_money.duplicated(subset=['id', 'period']).sum()
# Out:
# 0

# %% [markdown]
# Может показаться, что препредыдущий_месяц и предыдущий_месяц это дубликаты, однако это не так, так как полных дубликатов нет, это статистика за три месяца, поэтому данные оставим без изменений.

# %% [markdown]
# В пропуске дубликатов выяснилось, что записей в три раза больше, чем в основном датафрейме, поэтому найдём дубликаты после преобразования признаков.

# %% [markdown]
# #### Датафрейм df_market_time

# %% [markdown]
# Посмотрим на типы

# %%
df_market_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       2600 non-null   int64
#  1   period   2600 non-null   object
#  2   minutes  2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB

# %% [markdown]
# Найдём уникальные значения столбца period.

# %%
df_market_time['period'].unique()
# Out:
# array(['текущий_месяц', 'предыдцщий_месяц'], dtype=object)

# %% [markdown]
# Заменим предыдцщий_месяц на предыдущий_месяц

# %%
df_market_time.loc[df_market_time['period'] == 'предыдцщий_месяц', 'period'] = 'предыдущий_месяц'
df_market_time['period'].unique()
# Out:
# array(['текущий_месяц', 'предыдущий_месяц'], dtype=object)

# %% [markdown]
# Здесь всё оставим без изменений.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Отлично по исправлению опечаток</div>

# %% [markdown]
# #### Датафрейм df_money

# %% [markdown]
# Посмотрим на типы

# %%
df_money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      1300 non-null   int64
#  1   profit  1300 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 20.4 KB

# %% [markdown]
# С типами всё хорошо.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍  Если при загрузке определить разделитель для чисел `decimal = ','`, то это действие будет излишним. Типы данных изначально встанут корректно.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Числа лучше сразу смотреть гистограммой ,а не выводить простыней. Нас никто не заругает за еще один график до исследовательской части. Главное − наше удобство и удобство читателя.

# %% [markdown]
# ## Часть 3. Исследовательский анализ данных

# %% [markdown]
# ### 1. Количественные признаки

# %% [markdown]
# #### Датафрейм df_market_file

# %% [markdown]
# Создадим список количественных признаков

# %%
df_market_file_quant = df_market_file.drop( df_market_file_cat, axis=1).drop('id', axis=1).columns
df_market_file_quant
# Out:
# Index(['6_month_activity', 'current_activity', 'duration', 'prom_buy',
#        'mean_watch_cat_per_visit', 'unpayed_prod', 'service_error',
#        'pages_per_visit'],
#       dtype='object')

# %% [markdown]
# Построим гистограммы длительности с момента регистрации на сайте, первая гистограмма покажет длительность со сниженной активностью, вторая с такой же.

# %%
plt.figure(figsize=(12,7))
ax = df_market_file.loc[df_market_file['user_activity']=='Прежний уровень', 'duration'].hist(
    bins=40, 
    grid=True,
    alpha=0.5
)
df_market_file.loc[df_market_file['user_activity']=='Снизилась', 'duration'].hist(
    bins=40, 
    grid=True,
    alpha=0.5
)
plt.legend(('Прежний уровень', 'Снизилась'))
ax.set_xlabel('Длительность, дни')
ax.set_ylabel('Количество покупателей с данной длительностью')
plt.suptitle('Гистограмма распределения длительности');

# %% [markdown]
# Гистограммы показывают, что снижение активности не зависит от времени с момента регистрации.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2><s> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Не уловил логику в рассуждении. Выбросов нет, поэтому давайте что-нибудь удалим?
#
# Здесь полностью реалистичные данные, оставляем все.
#
# (ну и при удалении сперва надо понять, сколько строк потеряем)

# %% [markdown]
# Гистограммы для среднемесячнего значения маркетинговых коммуникаций за 6 месяцев.

# %%
plt.figure(figsize=(12,7))
ax = df_market_file.loc[df_market_file['user_activity']=='Прежний уровень', '6_month_activity'].hist(
    bins=40, 
    grid=True,
    alpha=0.5
)
df_market_file.loc[df_market_file['user_activity']=='Снизилась', '6_month_activity'].hist(
    bins=40, 
    grid=True,
    alpha=0.5
)
plt.legend(('Прежний уровень', 'Снизилась'))
ax.set_xlabel('Среднее количество маркетинговых коммуникаций за последние 6 месяцев')
ax.set_ylabel('Количество покупателей')
plt.suptitle('Гистограмма распределения среднего значения маркетиногвых коммуникаций за последние 6 месяцев');

# %% [markdown]
# Гистограммы показывают, что у покупателей с прежнем уровнем активности среднее количество маркетинговых коммуникаций за 6 месяцев было больше.

# %% [markdown]
# Гистограммы для среднемесячнего значения маркетинговых коммуникаций за текущий месяц.

# %%
plt.figure(figsize=(12,7))
ax = df_market_file.loc[df_market_file['user_activity']=='Прежний уровень', 'current_activity'].hist(
    bins=40, 
    grid=True,
    alpha=0.5
)
df_market_file.loc[df_market_file['user_activity']=='Снизилась', 'current_activity'].hist(
    bins=40, 
    grid=True,
    alpha=0.5
)
plt.legend(('Прежний уровень', 'Снизилась'))
ax.set_xlabel('Среднее количество маркетинговых коммуникаций за текущий месяц')
ax.set_ylabel('Количество покупателей')
plt.suptitle('Гистограмма распределения среднего значения маркетиногвых коммуникаций за текущий месяц');

# %% [markdown]
# Гистограммы показывают, что среднее количество маркетинговых коммуникаций за текущий месяц у пользователей с разными уровнями активности одинаковое.

# %% [markdown]
# Гистограммы покупок по акции.

# %%
plt.figure(figsize=(12,7))
ax = df_market_file.loc[df_market_file['user_activity']=='Прежний уровень', 'prom_buy'].hist(
    bins=40, 
    grid=True,
    alpha=0.5
)
df_market_file.loc[df_market_file['user_activity']=='Снизилась', 'prom_buy'].hist(
    bins=40, 
    grid=True,
    alpha=0.5
)
plt.legend(('Прежний уровень', 'Снизилась'))
ax.set_xlabel('Среднее количество покупок по акции')
ax.set_ylabel('Количество покупателей')
plt.suptitle('Гистограмма распределения среднего значения покупок по акции');

# %% [markdown]
# Гистограммы показывают, что покупатели с прежнем уровнем активности совершали меньше покупок по акции.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 Снова привет. Спасибо за внимательную доработку.
#
# Да, но что интереснее, что акционщики почему-то снижают активность.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Хорошо бы прокомментировать ее.

# %% [markdown]
# Гистограммы среднего значения просмотренных категорий за визит.

# %%
plt.figure(figsize=(12,7))
ax = df_market_file.loc[df_market_file['user_activity']=='Прежний уровень', 'mean_watch_cat_per_visit'].hist(
    bins=40, 
    grid=True,
    alpha=0.5
)
df_market_file.loc[df_market_file['user_activity']=='Снизилась', 'mean_watch_cat_per_visit'].hist(
    bins=40, 
    grid=True,
    alpha=0.5
)
plt.legend(('Прежний уровень', 'Снизилась'))
ax.set_xlabel('Среднее количество просмотренных категорий за визит')
ax.set_ylabel('Количество покупателей')
plt.suptitle('Гистограмма распределения среднего значения просмотренных категорий за визит');

# %% [markdown]
# Гистограммы показывают, что покупатели с прежнем уровнем активности смотрели больше категорий.

# %% [markdown]
# Гистограммы страниц за визит.

# %%
plt.figure(figsize=(12,7))
ax = df_market_file.loc[df_market_file['user_activity']=='Прежний уровень', 'pages_per_visit'].hist(
    bins=40, 
    grid=True,
    alpha=0.5
)
df_market_file.loc[df_market_file['user_activity']=='Снизилась', 'pages_per_visit'].hist(
    bins=40, 
    grid=True,
    alpha=0.5
)
plt.legend(('Прежний уровень', 'Снизилась'))
ax.set_xlabel('Среднее количество просмотренных страниц за визит')
ax.set_ylabel('Количество покупателей')
plt.suptitle('Гистограмма распределения среднего значения просмотренных страниц за визит');

# %% [markdown]
# Гистограммы показывают, что покупатели с прежнем уровнем смотрели больше страниц.

# %% [markdown]
# Далее построим гистограммы для неоплаченных продуктов за квартал и ошибок сервиса чтобы найти аномалии.

# %% [markdown]
# Гистограммы ошибок сервиса.

# %%
plt.figure(figsize=(12,7))
ax = df_market_file.loc[df_market_file['user_activity']=='Прежний уровень', 'service_error'].hist(
    bins=40, 
    grid=True,
    alpha=0.5
)
df_market_file.loc[df_market_file['user_activity']=='Снизилась', 'service_error'].hist(
    bins=40, 
    grid=True,
    alpha=0.5
)
plt.legend(('Прежний уровень', 'Снизилась'))
ax.set_xlabel('Среднее количество ошибок сервиса')
ax.set_ylabel('Количество покупателей')
plt.suptitle('Гистограмма распределения ошибок сервиса');

# %% [markdown]
# Гистограммы показывают, что у пользователей со сниженной активностью меньше ошибок сервиса.

# %% [markdown]
# Гистограммы неоплаченных продуктов.

# %%
plt.figure(figsize=(12,7))
ax = df_market_file.loc[df_market_file['user_activity']=='Прежний уровень', 'unpayed_prod'].hist(
    bins=40, 
    grid=True,
    alpha=0.5
)
df_market_file.loc[df_market_file['user_activity']=='Снизилась', 'unpayed_prod'].hist(
    bins=40, 
    grid=True,
    alpha=0.5
)
plt.legend(('Прежний уровень', 'Снизилась'))
ax.set_xlabel('Среднее количество неоплаченных продуктов')
ax.set_ylabel('Количество покупателей')
plt.suptitle('Гистограмма распределения неоплаченных продуктов');

# %% [markdown]
# Гистограммы показывают, что у покупателей со сниженной активностью больше продуктов в корзине.

# %% [markdown]
# Вывод по гистограммам: пользователи со снижающейся активностью больше покупают продуктов по акции, при этом они просматривают меньше страниц, меньше категорий и оставляют больше неоплаченных продуктов в корзине. Получается пользователей привлекает продукция по акциям, возможно акций стало меньше, что повлияло на отток.

# %% [markdown]
# #### Датафрейм df_market_money

# %% [markdown]
# Здесь всего один количественный признак, однако как было выяснено выше датафрейм содержит записи за несколько периодов, поэтому построим гистограммы для каждого периода.

# %%
for i, period in enumerate(df_market_money['period'].unique()):
    plt.figure(figsize=(30, 7))
    ax = plt.subplot(1, len(df_market_money['period'].unique()), i+1)
    plt.grid()
    plt.hist(
        df_market_money.loc[df_market_money['period'] == period, 'proceed'],
        bins=100,
    )
    ax.set_xlabel(f'Выручка за {period}')
    ax.set_ylabel('Количество покупателей')
    plt.title(f'Гистограмма за период {period}')

# %% [markdown]
# Некоторые покупатели ничего не покупали, необходимо удалить данные о таких покупателях так как нам нужны покупатели которые приносят хотя бы что-то в магазин, плюс это плохо скажется на модели машинного обучения.

# %%
df_market_money = df_market_money.query('proceed > 0')

# %% [markdown]
# Наблюдается аномалия за текущий месяц. Найдём id с аномалией и сравним с другими периодами.

# %%
df_market_money.loc[df_market_money['proceed'] > 10000, 'id']
# Out:
# 98    215380
# Name: id, dtype: int64

# %%
df_market_money.loc[df_market_money['id'] == 215380, 'proceed']
# Out:
# 96      5051.0
# 97      6077.0
# 98    106862.2
# Name: proceed, dtype: float64

# %%
df_market_money['proceed'].describe()
# Out:
# count      3894.000000
# mean       5033.439805
# std        1768.082235
# min        2758.700000
# 25%        4592.000000
# 50%        4959.000000
# 75%        5363.300000
# max      106862.200000
# Name: proceed, dtype: float64

# %% [markdown]
# Посмотрим на покупательскую активность.

# %%
df_market_file.loc[df_market_file['id'] == 215380, 'user_activity']
# Out:
# 32    Снизилась
# Name: user_activity, dtype: object

# %% [markdown]
# Заменим это значение на среднее.

# %%
df_market_money.loc[df_market_money['proceed'] == 106862.2, 'proceed'] = 4955

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Отлично
# </div>

# %% [markdown]
# Построим гистограмму ещё раз.

# %%
for j, period in enumerate(df_market_money['period'].unique()):
    plt.figure(figsize=(30, 7))
    ax = plt.subplot(1, 4, j+1)
    plt.grid()
    plt.hist(
        df_market_money.loc[df_market_money['period'] == period, 'proceed'],
        bins=100,
    )
    ax.set_xlabel(f'Выручка за {period}')
    ax.set_ylabel('Количество покупателей')
    plt.title(f'Гистограмма за период {period}')

# %% [markdown]
# #### Датафрейм df_market_time

# %% [markdown]
# Построим гистограммы за периоды.

# %%
for i, period in enumerate(df_market_money['period'].unique()):
    plt.figure(figsize=(30, 7))
    ax = plt.subplot(1, len(df_market_money['period'].unique()), i+1)
    plt.grid()
    plt.hist(
        df_market_money.loc[df_market_money['period'] == period, 'proceed'],
        bins=100,
    )
    ax.set_xlabel(f'Время за {period}')
    ax.set_ylabel('Количество покупателей')
    plt.title(f'Гистограмма за период {period}');

# %% [markdown]
# Здесь также аномалий не наблюдается.

# %% [markdown]
# #### Датафрейм df_money

# %% [markdown]
# Тут только один количественный признак, построим его гистограмму.

# %%
ax = df_money['profit'].hist(
    bins=100, 
    figsize=(12,7),
    grid=True
)
ax.set_xlabel('Значение прибыли')
ax.set_ylabel('Количество покупателей')
plt.suptitle('Гистограмма распределения значения прибыли');

# %% [markdown]
# ### 2. Категориальные признаки

# %% [markdown]
# Здесь нам интересен только датафрейм df_market_file, построим pie-диаграммы для категориальных признаков.

# %% [markdown]
# Инвертируем словарь всех признаков, который мы использовали для переименования столбцов.

# %%
df_market_file_columns_inv = {k: v for v, k in df_market_file_columns.items()}

# %%
plt.figure(figsize=[18, 12])

for i, cat_sign in enumerate(df_market_file_cat):
    plt.subplot(1, 4, i+1)
    plt.pie(df_market_file[cat_sign].value_counts(), labels=df_market_file[cat_sign].unique(), radius=1)
    plt.title(df_market_file_columns_inv[cat_sign])

# %% [markdown]
# Диаграммы показывают, что в целом покупательская активность снизилась. Большинство пользователей предпочитают тип сервиса премиум. Также видно, что большинство покупателей разрешили присылать дополнительные предложения о товаре.

# %% [markdown]
# ## Часть 4. Объединение таблиц

# %% [markdown]
# Здесь необходимо объединить таблицы. В датафреймах df_market_money и df_market_time указаны данные за разные периоды для одинаковых id, это надо учитывать. Для удобства создадим новые датафреймы, в которых будут разные столбцы для разных категорий.

# %% [markdown]
# Создадим функцию для разбиения датафреймов.

# %%
def split_df(df, cat_name, quant_name, month_dict): #df - датафрейм, cat_name - название категориального признака
                                                    #quant_name - название количественного признака,month_dict - словарь
    df_list = {}                                    
    for name in df[cat_name].unique():
        df_list[month_dict[name]] = df.loc[df[cat_name] == name, ['id', quant_name]]
        df_list[month_dict[name]].columns = ['id', quant_name + '_for_' + month_dict[name]]
    return df_list

# %% [markdown]
# Создадим словарь с названиями колонок для перевода названия столбцов к змеиному регистру.

# %%
month_dict = {
    'препредыдущий_месяц': 'prevprev_month',
    'текущий_месяц': 'current_month',
    'предыдущий_месяц': 'prev_month'
}

# %% [markdown]
# Применим функцию к датафрейму df_market_money.

# %%
df_market_money_splited = split_df(
    df_market_money, 
    'period', 
    'proceed', 
    month_dict
)

# %% [markdown]
# Проверим грамотно ли работает функция.

# %%
df_market_money_splited['prevprev_month'].head()
# Out:
#         id  proceed_for_prevprev_month
# 3   215349                      4472.0
# 6   215350                      4826.0
# 11  215351                      4793.0
# 13  215352                      4594.0
# 16  215353                      5124.0

# %% [markdown]
# Функция работает правильно.

# %% [markdown]
# Применим функцию к другому датафрейму

# %%
df_market_time_splited = split_df(
    df_market_time, 
    'period', 
    'minutes', 
    month_dict
)

# %% [markdown]
# Объединим датафреймы.

# %%
month_list = ['prevprev_month', 'prev_month', 'current_month']

# %%
df_1 = df_market_file.join(df_market_money_splited['prevprev_month'].set_index('id'), on=['id'], how='inner')

# %%
df_1 = df_1.join(df_market_money_splited['prev_month'].set_index('id'), on=['id'], how='inner')

# %%
df_1 = df_1.join(df_market_money_splited['current_month'].set_index('id'), on=['id'], how='inner')

# %%
df_1 = df_1.join(df_market_time_splited['prev_month'].set_index('id'), on=['id'], how='inner')

# %%
df_full = df_1.join(df_market_time_splited['current_month'].set_index('id'), on=['id'], how='inner')

# %%
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1297 entries, 1 to 1299
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          1297 non-null   int64
#  1   user_activity               1297 non-null   object
#  2   servis_type                 1297 non-null   object
#  3   allow_to_report             1297 non-null   object
#  4   6_month_activity            1297 non-null   float64
#  5   current_activity            1297 non-null   int64
#  6   duration                    1297 non-null   int64
#  7   prom_buy                    1297 non-null   float64
#  8   popular_cat                 1297 non-null   object
#  9   mean_watch_cat_per_visit    1297 non-null   int64
#  10  unpayed_prod                1297 non-null   int64
#  11  service_error               1297 non-null   int64
#  12  pages_per_visit             1297 non-null   int64
# ...

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
#
# Здесь неоптимально объединяем таблицы. Есть способ, как в 4-5 строк и отфильтровать активных пользователей, и все объединить.
#
# Используем сводные таблицы, развернув наши таблицы с периодами так, чтобы в строках остались уникальные id, а в столбцах были периоды. Дальше просто отбираем строки, где ни в одном из столбцов нет нулей, после чего просто парой строк объединяем наши три таблицы - они уже все в готовом для этого формате.
#
# </div>

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# Изначально я пытался сделать через цикл, но у меня не получилось, поэтому выбрал такой топорный способ.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2><s> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Исследовательский анализ мы делаем для того, чтобы понять, какие закономерности заложены в наших данных. Здесь важно посмотреть на распределения признаков в разрезе целевого признака (снижения активности).
#
# Можно построить и наложить друг на друга гистограммы по данным в подвыборках с и без снижения активности. Можно расположить рядом два боксплота, для категориальных данных − две диаграммы.
#
# Думаю, так мы увидим гораздо больше интересной информации. Она нам особенно пригодится для части с исследованием сегмента покупателей.
#
# ***
#
# По итогам исследовательского анализа (кроме красивой таблицы) у нас должен быть вывод с портретом покупателя, который снижает активность: какие значения каких признаков для него будут характерны. Сколько страниц он в среднем просматривает, больше или меньше это, чем у активных пользователей, также с акционными покупками, временем на сайте и другими признаками.
#
# Фактически основной костяк выводов проекта делаем уже здесь. Модель нам нужна для перевода категориального признака (факт снижения активности) в вероятностный (вероятность снижения), чтобы дальше чуть более пластично исследовать выбранный сегмент.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера  #2 <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Не хватает промежуточного вывода с суммарной аналитикой по уходящим пользователям.
#
# </div>

# %% [markdown]
# ## Часть 5. Корреляционный анализ

# %% [markdown]
# Построим матрицу корреляции.

# %%
interval_cols = df_full.drop(['id'], axis=1).select_dtypes(['int64', 'float64']).columns
interval_cols
# Out:
# Index(['6_month_activity', 'current_activity', 'duration', 'prom_buy',
#        'mean_watch_cat_per_visit', 'unpayed_prod', 'service_error',
#        'pages_per_visit', 'proceed_for_prevprev_month',
#        'proceed_for_prev_month', 'proceed_for_current_month',
#        'minutes_for_prev_month', 'minutes_for_current_month'],
#       dtype='object')

# %%
len(interval_cols)
# Out:
# 13

# %%
cm1 = df_full.drop('id', axis=1).phik_matrix(interval_cols=interval_cols)

plt.figure(figsize=[12, 10])
plt.suptitle('Матрица корреляции между всеми признаками')
sns.heatmap(cm1, annot=True, fmt='.2f');
# Out:
# C:\Users\igsto\anaconda3\Lib\site-packages\phik\phik.py:150: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_binned.replace(defs.UF, np.nan, inplace=True)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2><s> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Оба признака важны. Если бы мы сами прогнозировали снижение активности, мы бы посмотрели на разницу в выручке между периодами.
#
# Да, корреляция высокая, но ниже 0.9. здесь мультиколлинеарности не будет, а оба признака будут важными.
#
# ***
#
# Даже если бы корреляция была выше 0.95, можно было бы сохранить оба признака. Один берем как есть, а второй заменяем на разность между первым и вторым. Так и информацию оставим, и корреляцию уберем. Но в нашем случае можно просто оставить признаки.

# %% [markdown]
# ## Часть 6. Использование пайплайнов

# %% [markdown]
# Разделим данные на тренеровочную и тестовую выборки.

# %% [markdown]
# Переведём столбец user_activity в числа, пусть прежний уровень это 1, а снизилась это 0.

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df_full.drop(['id', 'user_activity'], axis=1),
    df_full['user_activity'],
    test_size=TEST_SIZE,
    random_state=RANDOM_STATE 
)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍  Точно. id тоже удаляем.
# </div>

# %% [markdown]
# Создадим три списка с названиями для OHE, ORD и числовыми переменными.

# %%
ohe_columns = ['servis_type', 'allow_to_report']
ord_columns = ['popular_cat']
num_columns = X_train.select_dtypes(include=['int64', 'float64']).columns

# %% [markdown]
# Создадим пайплайн для OHE.

# %%
ohe_pipe = Pipeline(
    [('simpleImputer_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ohe', OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False))
    ]
    )

# %% [markdown]
# Создадим пайплайн для ORD.

# %%
ord_pipe = Pipeline(
    [('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ord',  OrdinalEncoder(
                categories=[
                    df_full['popular_cat'].unique()
                ], 
                handle_unknown='use_encoded_value', unknown_value=np.nan
            )
        ),
     ('simpleImputer_after_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))
    ]
)

# %% [markdown]
# Создадим общий пайплайн для подготовки данных.

# %%
data_preprocessor = ColumnTransformer(
    [('ohe', ohe_pipe, ohe_columns),
     ('ord', ord_pipe, ord_columns),
     #('lab_enc', LabelEncoder(), ['user_activity']),
     ('num', MinMaxScaler(), num_columns)
    ], 
    remainder='passthrough'
)

# %% [markdown]
# Создадим пайплайн для модели.

# %%
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
])

# %% [markdown]
# Создадим пайплайн, где будут использоваться модели как гиперпараметры.

# %%
param_grid = [
    # словарь для модели DecisionTreeClassifier()
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 5),
        'models__max_features': range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    
    # словарь для модели KNeighborsClassifier() 
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(1, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']   
    },

    # словарь для модели LogisticRegression()
    {
        'models': [LogisticRegression(
            random_state=RANDOM_STATE, 
            solver='liblinear', 
            penalty='l1'
        )],
        'models__C': range(1, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },

    # словарь для модели SVC()
    {
        'models': [SVC(probability=True)],
        'models__kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
        'models__degree': range(1, 6),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    }
    
]

# %% [markdown]
# Найдём лучшую модель. Так как я задал слишком много гиперпараметров воспользуемся RandomizedSearchCV. В качестве метрики выберем roc-auc так как признаков много и необходимо определять как TPR, так и FPR.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Лучше, конечно, чуть подробнее расписать аргументацию выбора метрики. Но в целом все верно. Нам нужно учесть и полноту, и точность, подойдет метрика, которая учтет их баланс.
# </div>

# %%
randomized_search = RandomizedSearchCV(
    pipe_final, 
    param_grid, 
    cv=5,
    scoring='roc_auc',
    random_state=RANDOM_STATE,
    n_jobs=-1,
    n_iter=15
    #error_score='raise'
)
randomized_search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('ohe',
#                                                                                Pipeline(steps=[('simpleImputer_ohe',
#                                                                                                 SimpleImputer(strategy='most_frequent')),
#                                                                                                ('ohe',
#                                                                                                 OneHotEncoder(drop='first',
#                                                                                                               handle_unknown='ignore',
# ...

# %% [markdown]
# Найдём лучшую модель.

# %%
print(randomized_search.best_estimator_)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['servis_type',
#                                                    'allow_to_report']),
#                                                  ('ord',
# ...

# %% [markdown]
# Лучшая модель это SVC с ядром poly.

# %% [markdown]
# Найдём метрику модели на тренировочной выборке.

# %%
randomized_search.best_score_
# Out:
# 0.9109788487683881

# %%
model = randomized_search.best_estimator_

# %% [markdown]
# Найдём метрику на тестовой выборке.

# %%
y_test_pred = model.predict_proba(X_test)[:, 1]
print('Метрика ROC-AUC на тестовой выборке:',roc_auc_score(y_test, y_test_pred) )
# Out:
# Метрика ROC-AUC на тестовой выборке: 0.8907977411914421

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Отлично, что используешь `remainder='passthrough'` . Хороший выбор гиперпараметров и значений для подбора. Отлично, что пробуем два типа масштабирования. Верно по вычислению метрики по вероятностям классов.
# </div>

# %% [markdown]
# ## Часть 7. Анализ важности признаков

# %% [markdown]
# Оценим важность признаков с помощью метода SHAP.

# %%
X_train_transformed = model.named_steps['preprocessor'].fit_transform(X_train)
X_test_transformed = model.named_steps['preprocessor'].transform(X_test)

# %%
X_train_df = pd.DataFrame(
    X_train_transformed,
    columns=model.named_steps['preprocessor'].get_feature_names_out()
)

X_test_df = pd.DataFrame(
    X_test_transformed,
    columns=model.named_steps['preprocessor'].get_feature_names_out()
)

# %%
explainer = shap.SamplingExplainer(
    lambda x: model.named_steps['models'].predict_proba(x)[:,1],
    X_train_transformed)

shap_values = explainer.shap_values(X_test_df)
shap.summary_plot(shap_values, X_test_df)
# Out:
#   0%|          | 0/325 [00:00<?, ?it/s]

# %% [markdown]
# Чтобы точно установить какой объект принадлежит к классу 0, а какой к 1 посмотрим на уникальные значения y_test.

# %%
y_test.unique()
# Out:
# array(['Прежний уровень', 'Снизилась'], dtype=object)

# %% [markdown]
# Получается класс 0 это прежний уровень, а класс 1 - снизилась.

# %% [markdown]
# Рассмотрим SHAP-диаграмму.
#
# Самыми значимыми будут первые 14 признаков, так как SHAP value у них достаточно велико. 11 из них коррелируют с целевой переменной положительно, 3 отрицательно, 2 не коррелирует. Выпишем эти признаки
#
# Положительная корреляция:
# 1. Количество страниц за визит
# 2. Время проведённое на сайте за предыдущий месяц
# 3. Среднее количество просмотренных категорий за визит
# 4. Время проведённое на сайте за текущий месяц
# 5. Выручка за предпредыдущий месяц
# 6. Маректинговая активность за 6 месяцев
# 7. Маркетинговая активность за текущий месяц
# 8. Ошибки сервиса
# 9. Выручка за текущий месяц
#
# Отрицательная корреляция:
# 1. Покупки по акции
# 2. Неоплаченные продукты
# 3. Длительность регистрации на сайте
#
# Отсутствие корреляции:
# 1. Популярные категории
# 2. Выручка за предыдущий месяц
#
# Далее необходимо провести сегментацию и сравнить с исследовательским анализом данных. Пока можно выдвинуть следующие гипотезы:
# 1. В магазине стало меньше продуктов по акциям
# 2. Покупатели забывают что они что-то заказывали и оставляют продукты в корзине
# 3. Необходима качественная реклама, раз новые пользователи проводят меньше времени на сайте

# %% [markdown]
# <div class="alert alert-success"  style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 По выводам в такой конфигурации все верно.
# </div>

# %% [markdown]
#  <div class="alert alert-block alert-danger">
# <h2><s> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# По графикам все верно.
#
# По формулировкам я, возозможно, недопонял. Давай уточнимся, чтобы не было сомнений в том, что мы оба понимаем графики одинаково.
#
# `Это говорит о том, что этот признак правильно классифицирует принадлежность целевой переменной к определённому классу` - а как у нас признак что-либо классифицирует? А что значит «неправильно классифицирует?
#
# У нас признак может влиять либо на увеличение вероятности прогноза класса «1», либо на уменьшение. Либо влиять сильно, либо не сильно.
#
# А еще по графику выше можем видеть, как именно влияют признаки с высокими значениями (красные) или низкими (синие).
#
# Думаю, стоит повторить то, как интерпретируем «осиное гнездо». Это важно, да и просто.
#
# `У некоторых приведённых выше признаков отличается толщина по вертикали относительно значения 0, однако различия небольшие, кроме признака популярные категории, там больше наблюдений, которые относятся к классу 1.` - а очем это нам говорит?
#
# `Далее рассмотрим признаки покупки по акции, популярные категории, неоплаченные товары в корзине и выручка за предыдущий месяц. Эти признаки не подходят так как они больше классифицируют к классу 1, SHAP value распределено несимметрично относительно значения 0, также несимметрична толщина по вертикали, следовательно такие признаки нам не подходят.` - вот здесь я точно ничего не понял. Почему эти признаки нам не подходят?
#
# ***
#
# Во-первых, выше мы должны будет исследовать наши данные, понять, как и какие признаки влияют на снижение активности. Например, как будут влиять акционные покупки (нужно сравнить гистограммы для активных и для снижающих активность пользователей).
#
# Давай разберем признак покупок по акции. Если признак у нас распределен далеко от нуля по горизонтальной оси, то он значим. Если признак правее − значит корреляция с таргетом будет положительная. Если признак красный − значит это признак с высоким значением. Тогда получается, что если покупатель почти все приобретает по акции, то это серьезный индикатор того, что он снизит активность. Если же покупатель по акции приобретает меньше 80% товаров, то он скорее будет лояльным, но здесь корреляция будет значительно более слабой.
#
# Ага. Тогда здесь уже можно будет попробовать выдвинуть гипотезу: как так выходит, что покупатели, которые почти все приобретают по акции, у нас оказываются склонными к оттоку? Кажется, должно быть наоборот.

# %% [markdown]
# ## Часть 8. Сегментация покупателей

# %% [markdown]
# ### 1. Составление сегментов

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# Я выдвинул три гипотезы, не совсем понял про сегментацию, получается надо сегментировать на основе этих гипотез?
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера  #2 <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Нет, необязательно. Единственное, что здесь нужно − выбрать сегмент и аргументировать его выбор.
#
# Логичнее всего выбирать тот сегмент, который будет наиболее полезно анализировать для заказчика. Либо это какая-то аномальная группа покупателей и нужно точнее понять причины их поведения. Либо это группа, которую нам будет выгоднее всего удерживать в первую очередь. Обычно первое и второе тут совпадает.
#
# Логично выбрать один сегмент.
#
# </div>

# %% [markdown]
# Было видвинуто три гипотезы, разобьём данные на сегменты для их проверки.
#
# Для первого сегмента проверим первую гипотезу, для чего построим несколько скаттерплотов. На оси $y$ пусть будет количество продуктов по акции, а на оси $x$ прибыль и выручка за каждый месяц.

# %% [markdown]
# Для второго сегмента на оси $y$ будет количество неоплаченных продуктов, а на оси $x$ маркетинговая активность за 6 месяцев и за текущий месяц.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2><s> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Выше мы должны понять, какие признаки коррелируют с оттоком. Сделать «портрет уходящего клиента».
#
# Здесь мы должны выбрать сегмент, удерживать который нам нужно будет в первую очередь. По заданию сегмент мы выбираем по вероятности снижения активности и еще какому-то признаку (например, высокой выручке или высокой доле акционных покупок или чему-то еще).
#
# ***
#
# `8.1 Выполните сегментацию покупателей. Используйте результаты моделирования и данные о прибыльности покупателей.`
#
# Попробую описать, что мы должны сделать:
#
# Самое важное − мы должны по заданию выбрать некоторый сегмент пользователей, обосновать выбор сегмента, обосновать то, как мы этот сегмент определяем (почему выбираем такие значения признаков для отбора пользователей в сегмент), а дальше исследовать только этот сегмент.
#
# 1) Под результаты моделирования здесь мы понимаем предсказания нашей модели, то есть, вероятности классов. Мы можем ранжировать клиентов по вероятности снижения активности и таким образом использовать эту информацию как одну из осей скаттерплота (для примера). Второй осью тогда будет какая-то категория, которая будет логичной после выбора сегмента. Например, если выбираем сегмент с высокой вероятностью снижения активности и высокой выручкой, то второй шкалой в скаттерплоте будет выручка.
#
#
# 2) Важно аргументировать выбор границ и для вероятности снижения активности, и для прибыльности. Как раз это будет удобно сделать, солавшись на график (думаю, скаттерплот тут в качестве типа визуализации будет выигрывать).
#
#
# Дальше следует провести исследование для выбранного сегмента: посмотреть на данные в разрезе периодов, в разрезе категорий товаров, акций итд. Нужно выявить факторы, которые сильнее всего влияют на снижение активности и предложить решения для минимизации негативного воздействия этих факторов.
#
# </div>

# %% [markdown]
# Добавим в датафрейм df_full среднюю выручку за покупателя.

# %%
df_full_money = df_full.join(df_money.set_index('id'), on=['id'])
df_full_money.head()
# Out:
#        id user_activity servis_type allow_to_report  6_month_activity  \
# 1  215349     Снизилась     премиум              да               4.4
# 2  215350     Снизилась    стандарт             нет               4.9
# 3  215351     Снизилась    стандарт              да               3.2
# 4  215352     Снизилась    стандарт             нет               5.1
# 5  215353     Снизилась    стандарт              да               3.3
#
#    current_activity  duration  prom_buy        popular_cat  \
# 1                 4       819      0.75   Товары для детей
# 2                 3       539      0.14  Домашний текстиль
# 3                 5       896      0.99   Товары для детей
# 4                 3      1064      0.94   Товары для детей
# 5                 4       762      0.26  Домашний текстиль
#
#    mean_watch_cat_per_visit  unpayed_prod  service_error  pages_per_visit  \
# 1                         4             4              2                5
# ...

# %% [markdown]
# Гистограмма df_money показывает среднюю выручку с клиента. Найдём второй квартиль столбца profit.

# %%
df_full_money['profit'].describe()
# Out:
# count    1297.000000
# mean        3.997610
# std         1.010813
# min         0.860000
# 25%         3.300000
# 50%         4.040000
# 75%         4.670000
# max         7.430000
# Name: profit, dtype: float64

# %% [markdown]
# Отберём клиентов, у которых profit больше или равен чем второй квартиль.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 Ок, логичный сегмент. Нужно добавить, почему он нам (и заказчику) интересен.
# </div>

# %%
df_full_money_prof = df_full_money.query('profit>=4.04')

# %% [markdown]
# ### Сегмент

# %% [markdown]
# Выделем два датафрейма: первый с покупательской активностью снизилась, второй - прежний уровень

# %%
df_full_money_prof_lower = df_full_money_prof.loc[df_full_money_prof['user_activity'] == 'Снизилась', :]
df_full_money_prof_same= df_full_money_prof.loc[df_full_money_prof['user_activity'] == 'Прежний уровень', :]

# %% [markdown]
# Построим две диаграммы рассеяния для каждого датафрейма. По оси $x$ отложим выручку, по $y$ - количество покупок по акции.

# %%
plt.figure(figsize=[12, 6])
sns.scatterplot(data=df_full_money_prof_lower, y='prom_buy', x='profit', hue='popular_cat');

# %%
plt.figure(figsize=[12, 6])
sns.scatterplot(data=df_full_money_prof_same, y='prom_buy', x='profit', hue='popular_cat');

# %% [markdown]
# Так как нам важно отследить какие категории товаров по акции следует оставить сегмент где среднее количество покупок по акции больше 0.8.

# %% [markdown]
# Создадим два датафрейма, в первом среднее покупок по акции будет больше 0.8, второе меньше.

# %%
df_full_money_prof_1 = df_full_money_prof.query('prom_buy >=0.8')
df_full_money_prof_1.head()
# Out:
#         id user_activity servis_type allow_to_report  6_month_activity  \
# 3   215351     Снизилась    стандарт              да               3.2
# 4   215352     Снизилась    стандарт             нет               5.1
# 26  215374     Снизилась    стандарт             нет               2.9
# 27  215375     Снизилась     премиум              да               3.0
# 28  215376     Снизилась    стандарт              да               2.4
#
#     current_activity  duration  prom_buy        popular_cat  \
# 3                  5       896      0.99   Товары для детей
# 4                  3      1064      0.94   Товары для детей
# 26                 5       268      0.98  Домашний текстиль
# 27                 4       558      0.89   Товары для детей
# 28                 3       534      0.98  Домашний текстиль
#
#     mean_watch_cat_per_visit  unpayed_prod  service_error  pages_per_visit  \
# 3                          5             0              6                4
# ...

# %%
df_full_money_prof_2 = df_full_money_prof.query('prom_buy <0.8')
df_full_money_prof_2.head()
# Out:
#         id user_activity servis_type allow_to_report  6_month_activity  \
# 1   215349     Снизилась     премиум              да               4.4
# 7   215355     Снизилась    стандарт             нет               4.7
# 8   215356     Снизилась    стандарт              да               4.2
# 12  215360     Снизилась     премиум              да               3.9
# 20  215368     Снизилась     премиум              да               3.8
#
#     current_activity  duration  prom_buy                     popular_cat  \
# 1                  4       819      0.75                Товары для детей
# 7                  4       284      0.17                Товары для детей
# 8                  4       192      0.14           Косметика и аксесуары
# 12                 3       623      0.35                 Кухонная посуда
# 20                 5       829      0.24  Техника для красоты и здоровья
#
#     mean_watch_cat_per_visit  unpayed_prod  service_error  pages_per_visit  \
# ...

# %% [markdown]
# Сгруппируем первый датафрейм по выручке за каждый месяц

# %%
df_full_money_prof_1_pivot_1 = df_full_money_prof_1.pivot_table(index='user_activity',
                                                          columns='popular_cat',
                                                          values=[
                                                              'proceed_for_prevprev_month',
                                                              'proceed_for_prev_month',
                                                              'proceed_for_current_month'
                                                          ],
                                                          aggfunc='mean'
                                                         )
df_full_money_prof_pivot.head()
# Out:
#                 proceed_for_current_month                        \
# popular_cat             Домашний текстиль Косметика и аксесуары
# user_activity
# Прежний уровень               5212.839024           5194.825397
# Снизилась                     5439.144186           5564.408475
#
#                                                                       \
# popular_cat     Кухонная посуда Мелкая бытовая техника и электроника
# user_activity
# Прежний уровень     5356.993023                          5321.820000
# Снизилась           5744.136667                          5329.176923
#
#                                                                  \
# popular_cat     Техника для красоты и здоровья Товары для детей
# user_activity
# Прежний уровень                    4965.340000      5063.483333
# Снизилась                          4847.758333      4948.280488
#
#                 proceed_for_prev_month                                        \
# ...

# %%
df_full_money_prof_1_pivot_1 = pd.concat(
    [
        df_full_money_prof_1_pivot_1['proceed_for_prevprev_month'],
        df_full_money_prof_1_pivot_1['proceed_for_prev_month'],
        df_full_money_prof_1_pivot_1['proceed_for_current_month']
    ]
).reset_index()
df_full_money_prof_1_pivot_1
# Out:
# popular_cat    user_activity  Домашний текстиль  Косметика и аксесуары  \
# 0            Прежний уровень        4999.500000            4615.000000
# 1                  Снизилась        4605.000000            4643.846154
# 2            Прежний уровень        5219.250000            4823.500000
# 3                  Снизилась        4978.535714            5159.653846
# 4            Прежний уровень        5539.700000            5134.200000
# 5                  Снизилась        5385.621429            5547.853846
#
# popular_cat  Кухонная посуда  Мелкая бытовая техника и электроника  \
# 0                5007.000000                               4935.00
# 1                4535.500000                               4720.50
# 2                5315.250000                               5623.50
# 3                5120.916667                               5372.25
# 4                5712.400000                               6350.20
# ...

# %%
plt.figure(figsize=(12,8))
for cat in df_full_money_prof_1_pivot_1.columns[1:]:
    plt.plot(
        df_full_money_prof_1_pivot_1.loc[df_full_money_prof_1_pivot_1['user_activity']=='Снизилась', cat]
    )
plt.legend(df_full_money_prof_1_pivot_1.columns[1:]);

# %%
plt.figure(figsize=(12,8))
for cat in df_full_money_prof_1_pivot_1.columns[1:]:
    plt.plot(
        df_full_money_prof_1_pivot_1.loc[df_full_money_prof_1_pivot_1['user_activity']=='Прежний уровень', cat]
    )
plt.legend(df_full_money_prof_1_pivot_1.columns[1:]);

# %% [markdown]
# Найдём разность категории с прежнем уровнем и со сниженным.

# %%
df_2 = df_full_money_prof_1_pivot_1.query('user_activity == "Снизилась"').reset_index()
df_2
# Out:
# popular_cat  index user_activity  Домашний текстиль  Косметика и аксесуары  \
# 0                1     Снизилась        4605.000000            4643.846154
# 1                3     Снизилась        4978.535714            5159.653846
# 2                5     Снизилась        5385.621429            5547.853846
#
# popular_cat  Кухонная посуда  Мелкая бытовая техника и электроника  \
# 0                4535.500000                               4720.50
# 1                5120.916667                               5372.25
# 2                5537.566667                               5950.10
#
# popular_cat  Техника для красоты и здоровья  Товары для детей
# 0                                   4523.80       4652.541667
# 1                                   3924.00       4684.375000
# 2                                   4382.64       4838.425000

# %%
df_3 = df_full_money_prof_1_pivot_1.query('user_activity == "Прежний уровень"').reset_index()
df_3
# Out:
# popular_cat  index    user_activity  Домашний текстиль  Косметика и аксесуары  \
# 0                0  Прежний уровень            4999.50                 4615.0
# 1                2  Прежний уровень            5219.25                 4823.5
# 2                4  Прежний уровень            5539.70                 5134.2
#
# popular_cat  Кухонная посуда  Мелкая бытовая техника и электроника  \
# 0                    5007.00                                4935.0
# 1                    5315.25                                5623.5
# 2                    5712.40                                6350.2
#
# popular_cat  Техника для красоты и здоровья  Товары для детей
# 0                                   4931.75       4983.333333
# 1                                   4563.00       4861.666667
# 2                                   5012.80       5097.400000

# %%
plt.figure(figsize=(12,8))
for cat in df_full_money_prof_pivot_1.columns[1:]:
    plt.plot(df_3[cat] - df_2[cat])
plt.legend(df_full_money_prof_pivot_1.columns[1:]);

# %% [markdown]
# Здесь видно, что категория косметика и аксессуары является самой непопулярной, также меньше прибыли в категории техника для красоты и здоровья.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #3 <a class="tocSkip"> </h2>
#
# 👍 Ага, сейчас видим интересное. Верно по комментариям.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2><s> Комментарий ревьюера #2 <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Ок, представим, что ты заказчик. Ты заплатил за исследование и получаешь «таким образом, необходимо увеличить число продуктов по акции». У тебя не бесконечное количество денег. Тебе нужно как минимум понимать, почему важно сейчас запускать акцию, на какие товары и для каких пользователей.
#
# Аналитика позволяет увеличить прибыль и снизить издержки до 10 раз за счет таргетированного воздействия на покупателей. Мы должны понять, кому и что мы будем предлагать.
#
# Здесь какого-то глубокого исследования от нас не ожидается, но боюсь, что вывод «надо делать акции для всех и на все» − не вариант совсем.
#
# ***
#
# `Графики показывают, что за предпредыдущий месяц было больше покупателей по акции среди тех у кого прежний уровень.` - а какие выводы мы можем из этого сделать? Почему так могло быть?
#
# Возможно, просто была выгодная акция, ну и люди ей пользовались. Как это связано с удержанием клиентов? Кажется, что в такой формулировке никак не связано.
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера  #2 <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Возможно, забывают. А возможно просто акция закончилась, товары подорожали, поэтому те, кто их добавляли в корзину, решили их не покупать.
#
# </div>

# %% [markdown]
# ## 9. Общий вывод

# %% [markdown]
# Было проведено исследование почему покупательская активность падает.

# %% [markdown]
# Исходные данные представляли собой четыре датафрейма. Датафреймы были хорошо составлены, предобработка и исследовательский анализ показали, что пропущенных данных нет, дубликатов тоже нет. Был небольшой выброс, но это несущественно

# %% [markdown]
# Для предсказания покупательской активности необходимо было выбрать модель машинного обучения. Самая лучшая модель это SVC с ядром poly, метрика roc-auc на тренировочной и тестовой выборках были около 91\%.

# %% [markdown]
# Сегментация показала, что покупатели стали меньше времени проводить на сайте, смотрели меньше категорий и тратили меньше денег.

# %% [markdown]
# Рекомендация бизнессу - увеличить товары по акции для мелкой бытовой техники, техники для красоты и здоровья, и товаров для детей.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #3 <a class="tocSkip"> </h2>
#
# 👍 Да, вполне!
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2><s> Комментарий ревьюера #2 <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Стоит дописать промежуточный вывод по исследовательскому анализу. Важно проговорить, что именно характерно для клиента со снижающейся активностью. Пока там пусто вместо вывода. Ну и в исследовании сегмента никак информация из исследовательского анализа не используется. Получается, что пользы из исследования не извлекли? А для чего это все делали?
#
# По сегменту:
#
# Попробуй сконцентрировать внимание на одном сегменте. Например, клиентах с большой прибылью и большой вероятностью оттока. Для них стоит посмотреть, какие категории товаров у них популярны. Можно сравнить с остальными пользователями, чтобы понять, что это именно особенность нашего сегмента.
#
# Также можем сгруппировать сумму выручки для нашего сегмента по каждому популярному товару по трем периодам. Можем посмотреть, есть ли у нас такие товары, выручка на которые для сегмента растет медленнее или вообще снижается от периода к периоду.
#
# Тогда на основе этого сможем сказать, что предположительно клиенты покупали по акции такие-то товары. Сейчас интерес к ним снизился. Если это товары длительного потребления, то можно порекомендовать таким пользователям выгодные предложения на смежные товары (опять же, можешь здесь сказать, на какие именно).
#
# В итоге у нас будет:
#
# * описание сегмента, которого нужно удерживать в первую очередь
# * описание товаров, которые интересны нашему сегменту
# * предложение конкретных товаров, для которых стоит делать акции.
#
# Так мы точечно воздействуем на сегмент, тратим меньше денег и получаем больше выгоды.
#
# Просто «увеличить число продуктов по акции» и «напомнить совершить покупку» - не подойдет. Наш заказчик все еще не будет счастлив, получив такой вывод. Это слишком широкая рекомендация, она не поможет бизнесу.
#
# ***
#
# Повторюсь, что исследование может быть совсем небольшим. Но итогом должны быть выводы, которые будут точечными, аргументированными, основанными на исследовании, полезными для бизнеса.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Главная задача и цель проекта − рекомендации бизнесу по удержанию сегмента пользователей.
#
# Мы должны изучить наших клиентов, понять, почему они уходят. Понять, какой сегмент стоит удерживать в первую очередь. А затем понять, как эффективнее всего будет удерживать именно наш сегмент.
#
# Здесь важно будет оставить 2-3 рекомендации на основе анализа.
#
# ***
#
# В компаниях модели DS часто не являются самоцелью (кроме случаев, когда зарабатываем на продаже доступа к модели). Часто она нужна для аналитики или чего-то еще. В нашем случае модель − просто способ лучше посмотреть на данные. Главное же − аналитика.
#
# Давай смоделируем ситуацию. К нам обратился заказчик, который хочет понять, как ему удерживать клиентов и как наиболее эффективно расходовать бюджет на удержание. Мы провели некоторую работу и ответили «Самая лучшая модель это SVC с ядром poly». Будет ли счастлив заказчик?

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту**
#
# Спасибо за твой проект! Эта работа также была достаточно объемной и требовала концентрации внимания. По структуре проекта, логичности действий и общему подходу все замечательно, что не может не радовать.
#
# **Отмечу положительные моменты проекта🚀**
#
# * Хорошие решения в коде, есть пояснения и аргументации.
# * Грамотная предобработка и подготовка признаков.
# * Корректное обучение моделей, использование пайплайнов.
#
#
# **На что стоит обратить внимание🤔**
#
# * Важно в исследовательском анализе рассмотреть отдельно подвыборки для клиентов со снижающейся и с постоянной активностью (делим по целевому признаку).
# * Необходимо отфильтровать данные, оставив только клиентов, активных в каждый из трех периодов.
# * Не стоит удалять признаки из периодов. Эти признаки нужны. При корреляции до 0.9 можно оставить оба признака.
# * Необходимо определить сегмент для анализа по результатам модели - вероятностям классов.
# * Важно провести исследование сегмента и дать рекомендации бизнесу.
# * Эти и остальные замечания я также написал по ходу проекта.
#
# **Желаю удачи и жду твой проект на повторное ревью!**😉
#
#
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Комментарий ко второй проверке**
#
# Спасибо за качественную доработку. Практически все верно. Однако еще кое-что осталось.
#
# * Важно доработать по исследовательскому анализу: дать промежуточный вывод, понять, что характерно для клиента со снижением активности.
# * Необходимо выбрать один сегмент для анализа, объяснить, почему покупателей этого сегмента стоит удерживать, дать рекомендации по удержанию клиентов, которые будут основанными на данных и полезными бизнесу.
#
# **Желаю удачи и жду твой проект на повторное ревью!**😉
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Комментарий к финальной проверке**
#
# Спасибо за доработку. Критичных комментариев нет.
#
# Возможно, будет полезно повторить тему со сводными таблицами. Почитать можно, например, здесь: https://habr.com/ru/articles/713506/
#
# Больше кода и схем, здесь: https://dfedorov.spb.ru/pandas/Сводная%20таблица%20в%20pandas.html
#
# Если что-то пропустил или остались вопросы, напиши в телеграм @kriill
#
# Желаю удачи в дальнейшей учебе!
#
# </div>
